# %%
# %run ../code/init_mooc_nb.ipy
# Out:
# Performing the necessary imports.
#
# from __future__ import division, print_function
# import numpy as np
# import matplotlib
# import kwant
#
# import ipywidgets
# from IPython.html.widgets import interact
# from ipywidgets import StaticInteract, RangeWidget, DropDownWidget
# from IPython.display import display_html
# from matplotlib import pyplot as plt
#
# import pfaffian as pf
# from edx_components import *
# <script type=text/javascript>
# /* Add a button for showing or hiding input */
# on = "Show input";
# off = "Hide input";
# function onoff(){
#   currentvalue = document.getElementById('onoff').value;
#   if(currentvalue == off){
#     document.getElementById("onoff").value=on;
#       $('div.input').hide();
#   }else{
#     document.getElementById("onoff").value=off;
#       $('div.input').show();
#   }
# }
#
# /* Launch first notebook cell on start */
# function launch_first_cell (evt) {
#   if (!launch_first_cell.executed
#       && IPython.notebook.kernel
#   ) {
# ...

# %% [markdown]
# #Table of Contents
# * &nbsp;
# 	* [$\pi-\textrm{flux}$ model](#$\pi-\textrm{flux}$-model)
# 	* [Function for dispersion plotting](#Function-for-dispersion-plotting)
# 	* [Chern](#Chern)

# %%
import kwant
import numpy as np
import scipy

from matplotlib import pyplot
# %matplotlib inline

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib
import numpy as np
from matplotlib import cm
from matplotlib import pyplot as plt

# %%
dag = lambda x: x.transpose().conj()

# %% [markdown]
# ## $\pi-\textrm{flux}$ model

# %%
# not working properly
# def pi_flux_2D():
#     """ 2D pi-flux system """
        
#     def onsite(par):
#         return np.array([[par.EpsA, par.t * np.exp(-1j * par.fi)], [par.t * np.exp(+1 * par.fi), par.EpsB]], dtype=complex)

#     def hopping_x(par):
def pi_flux_2D():
    """ 2D pi-flux system """
        
#         return np.array([[ - par.tprime, par.t * np.exp(+1j * par.fi)], [0.0, + par.tprime]], dtype=complex)
    
#     def hopping_y(par):
#         return np.array([[ + par.tprime, par.t * np.exp(+1j * par.fi)], [0.0, - par.tprime]], dtype=complex)
    
#     def hopping_xy(par):
#         return np.array([[0, par.t * np.exp(-1j * par.fi)], [0.0, 0.0]], dtype=complex)
    
#     def hamiltonian(site, par):
#         return onsite(par) \
#             + ( hopping_x(par) * np.exp(-1j * par.kx) + dag(hopping_x(par)) * np.exp(+1j * par.kx) ) \
#             + ( hopping_y(par) * np.exp(-1j * par.ky) + dag(hopping_y(par)) * np.exp(+1j * par.ky) ) \
#             + ( hopping_xy(par) * np.exp(-1j *(par.kx + par.ky)) + dag(hopping_xy(par)) * np.exp(+1j*(par.kx+par.ky)) )
    
#     lat = kwant.lattice.chain()
#     sys = kwant.Builder()
    
#     sys[lat(0)] = hamiltonian
#     return sys.finalized()


# working properly
    def onsite(site, par):
        mat = np.zeros((2,2), dtype=complex)

        mat[0,0] = par.EpsA + 2 * par.tprime * (np.cos(par.ky)-np.cos(par.kx))
        mat[1,1] = par.EpsB + 2 * par.tprime * (np.cos(par.kx)-np.cos(par.ky))
        mat[0,1] = par.t * np.exp(-1j*par.fi) + par.t*np.exp(1j*par.fi - 1j*par.ky) \
                    + par.t * np.exp(1j * par.fi - 1j * par.kx) \
                    + par.t * np.exp(-1j * par.fi - 1j * par.kx - 1j * par.ky) 
        mat[1,0] = mat[0,1].conjugate()
        return mat
    
    lat = kwant.lattice.chain()
    sys = kwant.Builder()
    
    sys[lat(0)] = onsite
    return sys.finalized()

# %% [markdown]
# ## Function for dispersion plotting

# %%
def evaluate_on_grid(X, Y, func):
    """ X, Y should be in np.meshgrid form. It's enough for func to work on floats. """
    data = []
    for xx, yy in zip(KX, KY):
        row = []
        for i,j in zip(xx, yy):
            row.append(func(i,j))
        data.append(row)
    data = np.array(data)
    data = [np.array(data[:,:,i]) for i in range(np.shape(data)[2])]
    return data

# %%
def diagonalize(sys, par):
    mat = sys.hamiltonian_submatrix(args=[par])
    ev, evec = scipy.linalg.eigh(mat)
    indx = np.argsort(ev)
    ev = ev[indx]
    evec = evec[:,indx]
    return ev, evec

# %%
def get_energies(sys, par):
    return diagonalize(sys, par)[0]

# %%
def dispersion_func(sys, par):
    def func(kx, ky):
        par.kx = kx
        par.ky = ky
        return get_energies(sys, par)
    return func

# %%
def plot_two(X,Y,Z, angle):
    fig = plt.figure(figsize=(14,10))
    ax = fig.add_subplot(111, projection='3d')

    ax.plot_surface(X, Y, Z[0], rstride=1, cstride=1, cmap=cm.YlGnBu_r)
    ax.plot_wireframe(X, Y, Z[1], rstride=1, cstride=1, cmap=cm.YlGnBu_r)

    ax.set_xlabel('kx')
    ax.set_ylabel('ky')

#     ax.set_xlim3d(-.4,.4)
#     ax.set_ylim3d(-.4,.4)
#     ax.set_zlim3d(60, 110)   
    
    ax.view_init(*angle)

# %%
par = SimpleNamespace(t=1.0, tprime=1/np.sqrt(2), fi=np.pi/4, EpsA=0.0, EpsB=0.0)
sys = pi_flux_2D()

KX = np.linspace(-np.pi, np.pi, 51)
KY = KX

KX, KY = np.meshgrid(KX, KY)
energies = evaluate_on_grid(KX, KY, dispersion_func(sys, par))

plot_two(KX, KY, [energies[0], energies[1]], angle=(30,20))

# %% [markdown]
# ## Chern

# %%
def plot_2D(X,Y,Z, angle=(30,20)):
    fig = plt.figure(figsize=(14,10))
    ax = fig.add_subplot(111, projection='3d')

    ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.YlGnBu_r)

    ax.set_xlabel('kx')
    ax.set_ylabel('ky')

#     ax.set_xlim3d(-.4,.4)
#     ax.set_ylim3d(-.4,.4)
#     ax.set_zlim3d(60, 110)   
    
    ax.view_init(*angle)   
    return fig, ax

# %%
def get_eigenvector(sys, par):
    def func(kx, ky):
        par.kx = kx
        par.ky = ky
        return diagonalize(sys, par)[1]
    return func

# %%
def get_plaquette_coord(KX, KY, x,y):
    """ Return coordinates if (i,j) plaquette for a given mesh. """
    def get_pos(i, j):
        ind = (j, i)
        return KX[ind], KY[ind]

    data = []
    data.append(get_pos(x  , y  ))
    data.append(get_pos(x+1, y  ))
    data.append(get_pos(x+1, y+1))
    data.append(get_pos(x  , y+1))
    return data

# %%
def dot00(evec1, evec2):
    return np.vdot(evec1[:, 0], evec2[:, 0])

# %%
# par = SimpleNamespace(t=1.0, tprime=1/np.sqrt(2), fi=np.pi/4, EpsA=0.0, EpsB=0.0)
# sys = pi_flux_2D()
# eigen = get_eigenvector(sys, par)

# %%
# coord = get_plaquette_coord(KX, KY, 0, 0)
# for c1, c2 in zip(coord, np.roll(coord,-1, axis=0)):
#     print np.round(c1, 2), np.round(c2, 2)

# %%
# np.array(coord)

# %%
# np.roll(coord, -2)

# %%
sigma_0 = np.array([[1, 0], [0, 1]])
sigma_x = np.array([[0, 1], [1, 0]])
sigma_y = np.array([[0, 1j], [-1j, 0]])
sigma_z = np.array([[1, 0], [0, -1]])

def eval_bhz(kx, ky):
    h = sigma_x * np.sin(kx) + sigma_y * np.sin(ky) + sigma_z * (np.cos(kx) + np.cos(ky) - 1.8)
    return scipy.linalg.eigh(h)[0]

def eigen_bhz(kx, ky):
    h = sigma_x * np.sin(kx) + sigma_y * np.sin(ky) + sigma_z * (np.cos(kx) + np.cos(ky) - 1.8)
    return scipy.linalg.eigh(h)[1]


par = SimpleNamespace(t=1.0, tprime=1/np.sqrt(2), fi=np.pi/4, EpsA=0.0, EpsB=0.0)


def eval_piflux(kx, ky):
    par.kx = kx
    par.ky = ky
    
    h = + 2 * par.tprime * (np.cos(ky) - np.cos(kx)) * sigma_z \
        + 4 * par.t * np.cos(par.fi) * np.cos(0.5*kx) * np.cos(0.5*ky) * sigma_x \
        - 4 * par.t * np.sin(par.fi) * np.sin(0.5*kx) * np.sin(0.5*ky) * sigma_y
        
    return scipy.linalg.eigh(h)[0]


def eigen_piflux(kx, ky):
    h = + 2 * par.tprime * (np.cos(ky) - np.cos(kx)) * sigma_z \
        + 4 * par.t * np.cos(par.fi) * np.cos(0.5*kx) * np.cos(0.5*ky) * sigma_x \
        - 4 * par.t * np.sin(par.fi) * np.sin(0.5*kx) * np.sin(0.5*ky) * sigma_y
        
    return scipy.linalg.eigh(h)[1]

# %%
KX = np.linspace(-np.pi, np.pi, 51)
KY = KX

KX, KY = np.meshgrid(KX, KY)

energies = evaluate_on_grid(KX, KY, eval_piflux)
print np.shape(energies)


plot_two(KX, KY, [energies[0], energies[1]], angle=(30,20))
# Out:
# (2, 51, 51)

# %%
def get_bc(eigen):
    num_filled_bands = 1
    num_points = 51
    K = np.linspace(-np.pi, np.pi, num_points, endpoint=False)

    vectors = np.array([[eigen(kx, ky)[:, :num_filled_bands] for kx in K] for ky in K])

    vectors_x = np.roll(vectors, 1, 0)
    vectors_xy = np.roll(vectors_x, 1, 1)
    vectors_y = np.roll(vectors, 1, 1)

    shifted_vecs = [vectors, vectors_x, vectors_xy, vectors_y]

    v_shape = vectors.shape

    shifted_vecs = [i.reshape(-1, v_shape[-2], v_shape[-1]) for i in shifted_vecs]

    dets = np.ones(len(shifted_vecs[0]), dtype=complex)
    for vec, shifted in zip(shifted_vecs, np.roll(shifted_vecs, 1, 0)):
        dets *= [np.linalg.det(a.T.conj().dot(b)) for a, b in zip(vec, shifted)]
    bc = np.angle(dets).reshape(int(np.sqrt(len(dets))), -1)    
    
    return K, bc

# %%
K, bc = get_bc(eigen_piflux)
print np.sum(bc)
# Out:
# 8.881784197e-16

# %%
Kx, Ky = np.meshgrid(K,K)

# %%
fig, ax = plot_2D(Kx, Ky, bc)
# ax.set_zlim3d(-.5,.1)
