# %%
# %run ../code/init_mooc_nb.ipy

from matplotlib import cm
import scipy

class SimpleNamespace(object):
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)

        
def haldane_ribbon(w, armchair = False):
    def ribbon_shape_zigzag(pos):
        fac = np.sqrt(3)/2
        (x, y) = pos
        return (-0.5 / np.sqrt(3) - 0.1 <= y < fac * w + 0.01 ) 
    
    def ribbon_shape_armchair(pos):
        fac = np.sqrt(3)/2
        (x, y) = pos
        return (-1 <= x < w )
    
    def onsite(site, par):
        if site.family == a:
            return par.m
        else:
            return -par.m

    def nn_hopping(target, source, par):
        return par.t

    def nnn_hopping(target, source, par):
        return 1j*par.t_nnn        
        
    graphene = kwant.lattice.honeycomb()
    a, b = graphene.sublattices
    nnn_hoppings_a = (((-1, 0), a, a), ((0, 1), a, a), ((1, -1), a, a))
    nnn_hoppings_b = (((1, 0), b, b), ((0, -1), b, b), ((-1, 1), b, b))

    if armchair == False:
        sym = kwant.TranslationalSymmetry((1, 0))
    else:
        sym = kwant.TranslationalSymmetry((0, np.sqrt(3)))
        
    sys = kwant.Builder(sym)
    
    if armchair == False:
        sys[graphene.shape(ribbon_shape_zigzag, (0, 0))] = onsite
    else:
        sys[graphene.shape(ribbon_shape_armchair, (0, 0))] = onsite
    
    sys[graphene.neighbors()] = nn_hopping
    sys[[kwant.builder.HoppingKind(*hopping) for hopping in nnn_hoppings_a]] = nnn_hopping
    sys[[kwant.builder.HoppingKind(*hopping) for hopping in nnn_hoppings_b]] = nnn_hopping
    
    return sys#.finalized()

#returns a kwant system, that resembles the momentum subblock of the Hamiltonian
def Haldane_infinite():
    lat = kwant.lattice.chain()
    sys = kwant.Builder()
    
    def onsite0(site, par):
        phases_nnn = np.array([np.sqrt(3) * par.ky, 1.5 * par.kx + np.sqrt(3) / 2 * par.ky, 1.5 * par.kx - np.sqrt(3) / 2 * par.ky])
        temp = np.sum(np.exp(1j * phases_nnn + 1j * par.phi))
        temp = temp + temp.conjugate()
        return par.m + par.t_nnn * temp
    
    def onsite1(site, par):
        phases_nnn = np.array([np.sqrt(3) * par.ky, 1.5 * par.kx + np.sqrt(3) / 2 * par.ky, 1.5 * par.kx - np.sqrt(3) / 2 * par.ky])
        temp = np.sum(np.exp(-1j * phases_nnn + 1j * par.phi))
        temp = temp + temp.conjugate()
        return - par.m + par.t_nnn * temp
    
    def hopping (site1, site2, par):
        phases = np.array([par.kx, (np.sqrt(3) * par.ky - par.kx) / 2, -(np.sqrt(3) * par.ky + par.kx)/2])
        return par.t * np.sum(np.exp(1j * phases)) 

    sys[lat(0)] = onsite0
    sys[lat(1)] = onsite1
    sys[kwant.HoppingKind((1,), lat)] = hopping
                                                 
    return sys.finalized()

def plot_two(X,Y,Z, angle):
    fig = plt.figure(figsize=(14,10))
    ax = fig.add_subplot(111, projection='3d')

    ax.plot_surface(X, Y, Z[0], rstride=1, cstride=1, cmap=cm.YlGnBu_r, shade=True)
    ax.plot_surface(X, Y, Z[1], rstride=1, cstride=1, cmap=cm.YlGnBu_r)

    ax.set_xlabel('kx')
    ax.set_ylabel('ky')

#     ax.set_xlim3d(-.4,.4)
#     ax.set_ylim3d(-.4,.4)
#     ax.set_zlim3d(60, 110)   
    
    ax.view_init(*angle)   
    
def evaluate_on_grid(X, Y, func):
    """ X, Y should be in np.meshgrid form. It's enough for func to work on floats. """
    data = []
    for xx, yy in zip(KX, KY):
        row = []
        for i,j in zip(xx, yy):
            row.append(func(i,j))
        data.append(row)
    data = np.array(data)
    data = [np.array(data[:,:,i]) for i in range(np.shape(data)[2])]
    return data

def diagonalize(sys, par):
    mat = sys.hamiltonian_submatrix(args=[par])
    ev, evec = scipy.linalg.eigh(mat)  # Automatically sorted
    return ev, evec

def get_energies(sys, par):
    return diagonalize(sys, par)[0]

def dispersion_func(sys, par):
    def func(kx, ky):
        par.kx = kx
        par.ky = ky
        return get_energies(sys, par)
    return func
# Out:
# Performing the necessary imports.
#
# from __future__ import division, print_function
# import numpy as np
# import matplotlib
# import kwant
#
# import ipywidgets
# from IPython.html.widgets import interact
# from ipywidgets import StaticInteract, RangeWidget, DropDownWidget
# from IPython.display import display_html
# from matplotlib import pyplot as plt
#
# import pfaffian as pf
# from edx_components import *
# <script type=text/javascript>
# /* Add a button for showing or hiding input */
# on = "Show input";
# off = "Hide input";
# function onoff(){
#   currentvalue = document.getElementById('onoff').value;
#   if(currentvalue == off){
#     document.getElementById("onoff").value=on;
#       $('div.input').hide();
#   }else{
#     document.getElementById("onoff").value=off;
#       $('div.input').show();
#   }
# }
#
# /* Launch first notebook cell on start */
# function launch_first_cell (evt) {
#   if (!launch_first_cell.executed
#       && IPython.notebook.kernel
#   ) {
# ...

# %% [markdown]
# #Table of Contents
# * [Intro](#Intro)
# * [Dirac cones in graphene](#Dirac-cones-in-graphene)
# * [Making graphene topological](#Making-graphene-topological)
# * [The Berry phase](#The-Berry-phase)
# * [Berry curvature and Chern number: magnetic field and Gauss' law in momentum space](#Berry-curvature-and-Chern-number:-magnetic-field-and-Gauss'-law-in-momentum-space)
# * [Gap closings are sources of Berry flux](#Gap-closings-are-sources-of-Berry-flux)
# * [Chern number: recap](#Chern-number:-recap)
# * [Summary: extending the model to spinful electrons and photons](#Summary:-extending-the-model-to-spinful-electrons-and-photons)

# %% [markdown]
# # Intro

# %% [markdown]
# Duncan Haldane from Princeton University will teach us about an interesting two dimensional toy-model which he [introduced](http://faculty.washington.edu/cobden/papers/haldane88.pdf) in 1988, and which has become a prototype for the anomalous quantum Hall effect.

# %%
MoocVideo("7nVO4uMm-do", src_location='4.2-intro')
# Out:
# MoocVideo(**{'download_video': 'true', 'display_name': '', 'sub': '7nVO4uMm-do', 'youtube': '1.00:7nVO4uMm-do', 'show_captions': 'true', 'youtube_id_1_0': '7nVO4uMm-do', 'source': 'http://delftxdownloads.tudelft.nl/TOPOCMx-QuantumKnots/TOPOCMx-4.2-intro-video.720.mp4', 'download_track': 'true'})

# %% [markdown]
# In the lecture, we will now study the model in detail, starting from the beginning.  Along the way, we will also learn what's the Chern number, the bulk topological invariant of a quantum Hall state.

# %% [markdown]
# # Dirac cones in graphene

# %% [markdown]
# In the last chapter we saw how it is possible to obtain a quantum Hall state by coupling one-dimensional systems. At the end, our recipe was to first obtain a Dirac cone, add a mass term to it and finally to make this mass change sign. Following this recipe we were able to obtain chiral edge states without applying an external magnetic field.
#
# Now, notoriously there is a real two-dimensional system which has Dirac cones: [graphene](http://en.wikipedia.org/wiki/Graphene). So in this chapter we will take graphene and make it into a topological system with chiral edge states.
#
# Graphene is a single layer of carbon atoms disposed in a hexagonal lattice. The latter is a triangular lattice with two atoms per unit cell, type $A$ and type $B$, represented by red and blue sites in the figure:
#
# ![](figures/graphene.png)

# %% [markdown]
# Hence, the wave funciton in a unit cell can be written as a vector $(\Psi_A, \Psi_B)^T$ of amplitudes on the two sites $A$ and $B$. Taking a simple tight-binding model where electrons can hop between neighboring sites with hopping strength $t$, one obtains the following Bloch Hamiltonian:
#
# $$
# H_0(\mathbf{k})= \begin{pmatrix} 0 & h(\mathbf{k}) \\ h^\dagger(\mathbf{k}) & 0 \end{pmatrix}\,,
# $$
#
# with $\mathbf{k}=(k_x, k_y)$ and
#
# $$h(\mathbf{k}) = t_1\,\sum_i\,\exp\,\left(i\,\mathbf{k}\cdot\mathbf{a}_i\right)\,.$$
#
# Here $\mathbf{a}_i$ are the three vectors in the figure, connecting nearest neighbors of the lattice [we set the lattice spacing to one, so that for instance $\mathbf{a}_1=(1,0)$].  Introducing a set of Pauli matrices $\sigma$ which act on the sublattice degree of freedom, we can write the Hamiltonian in a compact form as
#
# $$H_0(\mathbf{k}) = t_1\,\sum_i\,\left[\sigma_x\,\cos(\mathbf{k}\cdot\mathbf{a}_i)+\sigma_y \,\sin(\mathbf{k}\cdot\mathbf{a}_i)\right]\,.$$
#
# The energy spectrum $E(\mathbf{k}) = \pm \,\left|h(\mathbf{k})\right|$ gives rise to the famous band structure of graphene, with the two bands touching at the six corners of the Brillouin zone:

# %%
par = SimpleNamespace(t=1.0, t_nnn=0., m=0.0, phi=np.pi/2, kx=0.0, ky=0.0)
sys = Haldane_infinite()

KX = np.linspace(-np.pi, np.pi, 150)
KY = KX

KX, KY = np.meshgrid(KX, KY)
energies = evaluate_on_grid(KX, KY, dispersion_func(sys, par))

plot_two(KX, KY, [energies[0], energies[1]], angle=(8,20))

# %% [markdown]
# Only two of these six Dirac cones are really distinct, let's say those located at $\mathbf{K}=(2\pi/3, 2\pi/3\sqrt{3})$ and $\mathbf{K}'=(2\pi/3, -2\pi/3\sqrt{3})$. All the others can be obtained by adding some reciprocal lattice vector to $\mathbf{K}$ and $\mathbf{K}'$.

# %% [markdown]
# ## Discrete symmetries of graphene
#
# The symmetries of graphene were discussed intensively in the video, so let's review them.
#
# As we already say in our first week, graphene is the prototype of a system with sublattice symmetry, which makes the Hamiltonian block off-diagonal with respect to the two sublattices. The sublattice symmetry reads
#
# $$\sigma_z\,H_0(\mathbf{k})\,\sigma_z = -H_0(\mathbf{k})\,,$$
#
# The sublattice symmetry is for our purposes equivalent to the inversion symmetry which was mentioned in the video: both exchange $A$ and $B$ lattice, and need to be broken in order to open a gap at the Dirac point.
#
# Beyond inversion symmetry, the honeycomb lattice also has a three-fold rotation symmetry around the center of the unit cell. This symmetry is important to make the Dirac cones appear in the first place, but it will not play a role in all that follows.
#
# Finally, there is time-reversal symmetry, which at the moment is perfectly preserved in our tight-binding model. Since we are not considering the spin degree of freedom of the electrons, the time-reversal symmetry operator in real space is just complex conjugation. In the momentum space representation, time-reversal symmetry reads
#
# $$ H_0(\mathbf{k}) = H_0^*(-\mathbf{k})\,.$$
#
# It's important to note that time-reversal symmetry sends $\mathbf{K}$ into $\mathbf{K}'$ and therefore it exchanges the two Dirac cones.
#
# The product of sublattice and time-reversal symmetry yields a further discrete symmetry - a particle-hole symmetry, $\sigma_z H^*(-\mathbf{k})\,\sigma_z = -H_0(\mathbf{k})$. Unlike what happens for superconductors, however, this symmetry is unphysical, and is only there because we have a simplified tight-binding model.

# %% [markdown]
# # Making graphene topological

# %% [markdown]
# Let's recall that our goal is to make our graphene sheet enter a quantum Hall state, with chiral edge states. The first necessary step is to make the bulk of the system gapped.
#
# How can we open a gap in graphene? The Dirac points are protected by both sublattice (inversion) and time-reversal symmetry. So there are many ways we can think of to open an energy gap at $\mathbf{K}$ and $\mathbf{K}'$.

# %% [markdown]
# ## First try
#
# The easiest way to break sublattice symmetry is to assign an opposite onsite energy $M$ or $-M$ to the $A$ or $B$ sites respectively. The Hamiltonian is then given by
#
# $$ H_0(\mathbf{k}) + M\,\sigma_z\,.$$
#
# This leads to a gapped spectrum
#
# $$E(\mathbf{k})=\pm \sqrt{\left|h(\mathbf{k})\right|^2 + M^2}\,.$$
#
# We can quickly realize that in this way we end up in a rather boring situation though. Taking the limit $\left|M\right| \gg t_1$, we obtain electronic states which are localized in one of the two sublattices $A$ or $B$, independently of the sign of $M$. Most of all, there is no trace of edge states.
#
# It's easy to see why this mass term is hopeless: it preserves time-reversal symmetry. And with the latter present, it is definitely impossible to obtain chiral edge states.

# %% [markdown]
# ## Second try
#
# There is another, more ingenious way to gap out the Dirac cones in graphene, which is the essence of the model introduced by Duncan Haldane. It involves adding second-nearest neighbor hoppings, with the following distinctive pattern:
#
# ![](figures/haldane_hoppings.png)
#
# Note the following things about these hoppings:
#
#
# * they are purely imaginary and, furthermore, they all have the same chirality, in the sense that they all follow the orientation of your right hand, if the thumb points out from the screen.
# * they couple sites of same type $A$ and $B$, with opposite signs for sites on the same unit cell.
#
#
# These characteristics tell us that in this way we break both time-reversal symmetry and sublattice symmetry. In fact, the full Hamiltonian becomes
#
# $$
# H(\mathbf{k}) = H_0(\mathbf{k})+ M\sigma_z + 2t_2\sum_i\,\sigma_z\,\sin(\mathbf{k}\cdot\mathbf{b}_i)\,.
# $$
#
# The last term changes sign under time-reversal symmetry, breaking it.
#
# Let's see what happens to the system when these special second neighbor hoppings are turned on. When $t_2=0$ and at a finite $M$, the system is in a boring gapped phase, with generically no zero energy states. As you heard in the video, there might be zero energy states for some specific termination of the lattice, but these are not particularly interested.
#
# Adding a small $t_2$ initially does not change the situation, but when $t_2$ passes through a value $\pm M/3\sqrt{3}$ the gap closes and changes sign.
#
# Keep note of the following important fact: the gap closes *only at one of the two Dirac points*: at $\mathbf{K}'$ for $t_2=M/3\sqrt{3}$ and at $\mathbf{K}$ for $t_2=-M/3\sqrt{3}$.
#
# And when it does, chiral edge states appear!
#
# **TO DO: ADD DOS PLOT FOR A GRAPHENE RIBBON AS A FUNCTION OF t_2 (if not too expensive?)**

# %% [markdown]
# To convince you that they are of topological origin, we show them here for a graphene ribbon with a different lattice termination than the one discussed in the video: the so-called armchair edge instead of the zigzag edge.
#
# The appearance of edge states means that graphene has entered a topological phase after the gap closing. This phase is akin to the quantum Hall phase - the edge states are of the same kind. However, as Duncan Haldane explained in the introduction, it is realized without a strong magnetic field.
#
# This topological phase of matter is known as a **Chern insulator**. The reason for this name will become obvious in the second part of this lecture, when will learn what it the bulk invariant which gives rise to the chiral edge states.

# %% [markdown]
# # The Berry phase

# %% [markdown]
# It's finally time to introduce the Berry phase, an important character in the story of this course. In short, the Berry phase is the phase acquired by a quantum state during an adiabatic process.
#
# By now you have encountered various examples of such processes in the course - for instance, the Thouless pump and the exchange of Majoranas in a nanowire T-junction. In both of these cases, we could have computed a Berry phase to arrive at the final result. Furthermore, more often than not in condensed matter cool effects and quantization properties can be reconduced to the presence of a Berry phase. You should therefore be convinced that it's a topic worth knowing.

# %% [markdown]
# To see what the Berry phase is, we have to consider a Hamiltonian which depends on parameters. We did so already in the Thouless pump chapter. Given that our present interest is in Chern insulators, which are two-dimensional systems, we will now consider a Hamiltonian $H(\mathbf{k})$ which depends on two parameters - in our case, the momenta in the Brillouin zone.

# %% [markdown]
# Let's take an eigenstate $\left|\psi(\mathbf{k})\right\rangle$ of this Hamiltonian, with energy $E(\mathbf{k})$, and let's start changing $\mathbf{k}$ very slowly. As usual, it's crucial that $E(\mathbf{k})$ is an isolated energy level, or in other words that the Hamiltonian is gapped. After a while, let's say a time $T$, we bring $\mathbf{k}$ back to its initial value.
#
# **TO DO: DRAW TWO EXAMPLES OF CLOSED PATHS IN THE BRILLOUIN ZONE OF GRAPHENE**
#
# We then ask: what is the quantum state at a time $T$? For a long time people guessed that it would just be given by the initial state times the usual phase $\exp\left(i \int_0^T E[\mathbf{k}(t)]\,d t\right)$ which an eigenstate of the Hamiltonian accumulates with time.

# %% [markdown]
# This would be rather boring. Berry instead realized that for a **closed path** $C$ there is an additional phase $\gamma$,
#
# $$\gamma(C) = \oint_C\,\mathbf{A}(\mathbf{k})\,\cdot d\mathbf{k}\,$$
#
# with $\mathbf{A}(\mathbf{k})=i\left\langle\,\psi(\mathbf{k}) \,|\,\nabla_\mathbf{k}\,\psi(\mathbf{k})\right\rangle$ a vector with two complex entries, which are obtained by taking the derivatives of $\left|\psi(\mathbf{k})\right\rangle$ with respect to $k_x$ and $k_y$ and then taking the inner product with $\left\langle\psi(\mathbf{k})\right|$. This vector goes by the rather obscure name of Berry connection. Hence, the final quantum state at the end of the cycle is
#
# $$\exp\,\left[i\gamma(C)\right]\,\exp\,\left(i \int_0^T E[\mathbf{k}(t)]\,d t\right)\,\left|\psi(\mathbf{k})\right\rangle\,.$$

# %% [markdown]
# We will not derive the formula for the Berry phase, something which can be done directly from the Schroedinger equation, see for instance [here](http://arxiv.org/abs/0907.2021). What is important to know about it is that $\gamma$ only depends on the path, so it is a **geometric phase**. We'll soon see that it can have an even stronger, topological character.

# %% [markdown]
# # Berry curvature and Chern number: magnetic field and Gauss' law in momentum space

# %% [markdown]
# We did not denote the Berry connection as $\mathbf{A}(\mathbf{k})$ just by chance. We picked that letter because this vector reminds us a lot of the vector potential $\mathbf{A}(\mathbf{r})$ that you use in electromagnetism.
#
# Just like the vector potential, the definition of $\mathbf{A}(\mathbf{k})$ depends on a particular choice of the person making the calculation. Because if you decide to multiply the quantum state by a phase, $\left|\psi(\mathbf{k})\right\rangle\,\to \exp\,[i\lambda(\mathbf{k})]\,\left|\psi(\mathbf{k}\right\rangle$, which you are always allowed to, then you get that the Berry connection transforms as $\mathbf{A}(\mathbf{k})\,\to\,\mathbf{A}(\mathbf{k})+\nabla_\mathbf{k} \,\lambda$. However, when you take the integral of $\mathbf{A}(\mathbf{k})$ on a closed path, the result is independent of $\lambda$. That's why the Berry phase is only meaningful for closed paths.
#
# Now that we have established an analogy with the vector potential, we cannot avoid the idea of taking the curl of the Berry connection, which is known as the **Berry curvature**:
#
# $$\mathbf{\Omega}(\mathbf{k}) = \nabla \times \mathbf{A}(\mathbf{k})\,.$$
#
# The Berry curvature is like a *magnetic field in momentum space*. Just like the magnetic field $\mathbf{B}(\mathbf{r})=\nabla\times\mathbf{A}(\mathbf{r})$ in electromagnetism, it is a local quantity which does not suffer from the ambiguities of the vector potential (it is gauge independent).
#
# Using Stokes' theorem, you can now write the Berry phase as a surface integral,
#
# $$\gamma(C) = \iint_A \mathbf{\Omega}(\mathbf{k})\,\cdot\,d\mathbf{S}\,$$
#
# where $A$ is the portion of the Brillouin zone which is enclosed by the path $C$. In other words the Berry phase is equal to the total flux of the Berry curvature through the surface $A$.
#
# ** TO DO: DRAW THE SAME PATHS AS BEFORE, INDICATING THE SURFACE OF INTEGRATION AND DRAWING SOME "FLUX" **
#
# You can in fact use the above formula in any number of dimensions. In the case of two dimensions, it reads:
#
# $$\gamma(C) = i\,\iint_A\,\left[\left\langle \frac{\partial \psi(\mathbf{k})}{\partial k_x}\,\Bigg|\,\frac{\partial\,\psi(\mathbf{k})}{\partial k_y}\right\rangle-\left\langle \frac{\partial \psi(\mathbf{k})}{\partial k_y}\,\Bigg|\,\frac{\partial\,\psi(\mathbf{k})}{\partial k_x}\right\rangle\right]\,dk_x\,dk_y$$
#
# After all this math, now comes the interesting part. You should remember Gauss' law: if you integrate the magnetic flux over a closed surface in space, let's say a sphere, than you get that (in Gaussian units...)
#
# $$\frac{1}{4\pi}\,\iint_\textrm{sphere}\,\mathbf{B}(\mathbf{r})\cdot\,d\mathbf{S}=n$$
#
# with $n$ an integer number, corresponding to the *number of magnetic monopoles which are inside the sphere*. Now, the reason you have that the right side is an integer is really just that the sphere is a closed surface with no boundaries, so it catches all the flux that's created by the sources inside it.
#
# In momentum space we naturally have such a surface the Brillouin zone. The Brillouin zone is a [torus](http://en.wikipedia.org/wiki/Torus) and not a sphere, but it still has no boundaries. And so it turns out that the integral of the Berry curvature through the Brillouin zone must be an integer:
#
# $$\mathcal{C}\equiv\frac{1}{4\pi}\,\iint_\textrm{BZ}\,\mathbf{\Omega}(\mathbf{k})\cdot\,d\mathbf{S}=n$$
#
#
# > The integer $\mathcal{C}$ is referred to as the **Chern number**. Because it is an integer, it cannot be changed by any continuous deformation of the Hamiltonian, provided the gap does not close. The Chern number is the bulk topological invariant of insulators with broken time-reversal symmetry. If $\mathcal{C}=0$, we have a topologically trivial insulator with no chiral edge states. If $\mathcal{C}=n$ there are $n$ chiral edge states at the boundary of the insulator.
#
# Now, you probably know that experimentally a magnetic monopole was never observed, so that in all textbooks of electromagnetism you will in fact find the above formula with $n=0$. For our Chern number in the Brillouin zone the situation is more exciting, as sitiations with $n$ different from zero are realized in nature.
#
# To see how this can happen, we first have to understand the following: if there is Berry curvature in the Brillouin zone, what are its sources?

# %% [markdown]
# # Gap closings are sources of Berry flux

# %% [markdown]
# The Berry phase can only be computed only if the Hamiltonian has a gap. For a Hamiltonian $H(\mathbf{k})$ with many bands $E_n(\mathbf{k})$, this means that we can compute the Chern number only for an isolated band $E_n(\mathbf{k})$ which does not touch any other band. If there is a band touching, the Berry phase is undefined.
#
# Now let's go back to our analogy with electromagnetism. We know that we cannot compute the electric or magnetic flux through a surface if there are electric or magnetic charges sitting exactly on it. That's because the electric or magnetic fields are *not defined* at the points where their sources are.
#
# This analogy suggests the following: that the sources and sinks for Berry flux in momentum space are points where two bands touch, just like the Dirac points at the $\mathbf{K}$ and $\mathbf{K}'$ points of the Brillouin zone in graphene.
#
# Now, this may sound a bit abstract and confusing: where are these points located? It's easy to understand in the case of a sphere surrounding a charge in real space, less in momentum space. In fact, just like you do with a sphere in real space surrounding a charge in the origin, you have to think of the Brillouin zone as lying in a three-dimensional space, with two directions given by $k_x$ and $k_y$ and the third given by the *magnitude of the energy gap*.
#
# The situation is explained by the following sketch:
#
# ![](figures/phasediagram.png)

# %% [markdown]
# We can see this effect by directly looking at the Berry curvature for the Haldane model. Let's look at it in the trivial phase, for $t_2=0$.
#
# **TO DO: PLOT BERRY CURVATURE AT $t_2=0$**
#
# You can see two distinct contributions to the Berry curvature, close to the two Dirac points, which cancels out and give zero. Let's now look at the topological phase with edge states:
#
# **TO DO: PLOT BERRY CURVATURE AT $t_2> M/3\sqrt{3}$**
#
# Now one of the two contributions has changed sign! This is because the gap closes at that point when we increase $t_2$ from zero to $M/3\sqrt{3}$.
#
# From both the plots above, you should also each Dirac point always contributes a Berry curvature equal to $\pm 1/2$, depending on the sign of the mass in the effective Dirac Hamiltonian. We always obtain an integer number because the number of Dirac points in the Brillouin zone is even. It also implies that when the gap changes sign at a Dirac point, the Chern number changes by exactly one!
#
# Now, at the same time it's important to know that the particular distribution of the Berry curvature depends on all the details of the eigenstates of the Hamiltonian, so it changes a lot from model to model. And in fact, it is a special feature of the Haldane model that the Berry curvature is focused around two distinct points in the Brillouin zone.
#
# For instance, here is how the Berry curvature looks like in the topological phase of the previous chapter:
#
# **TO DO: PLOT BERRY CURVATURE FOR TOPOLOGICAL PHASE OF QWZ MODEL**

# %% [markdown]
# # Chern number: recap

# %% [markdown]
# Before we conclude, let's recap all that's important with the Chern number:
#
# **TO DO: write concisely all the crucial points**

# %% [markdown]
# # Summary: extending the model to spinful electrons and photons

# %% [markdown]
# * Trying to computing the Chern number of the massive Dirac model we see that the Berry curvature is non-zero only near the Dirac points and has a sign that depends on the mass. Since a change of mass leads to a change of 1 in the Chern number, the berry flux of a massive Dirac point must be a half-integer.
#
# * For the topologically trivial mass term in graphene - the Berry fluxes from the two Dirac cones cancel. On the other hand in the
# Haldane model the Berry fluxes add.
#
# * For the QWZ model with one Dirac one half of the Berry flux is generated far from the Dirac point.

# %%
MoocVideo("0gxE68kvdmw", src_location='4.2-summary')
# Out:
# MoocVideo(**{'download_video': 'true', 'display_name': '', 'sub': '0gxE68kvdmw', 'youtube': '1.00:0gxE68kvdmw', 'show_captions': 'true', 'youtube_id_1_0': '0gxE68kvdmw', 'source': 'http://delftxdownloads.tudelft.nl/TOPOCMx-QuantumKnots/TOPOCMx-4.2-summary-video.720.mp4', 'download_track': 'true'})

# %% [markdown]
# **Questions about what you just learned? Ask them below!**

# %%
("Questions", "Haldane model")
# Out:
# ('Questions', 'Haldane model')
