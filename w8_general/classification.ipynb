# %%
# %run ../code/init_mooc_nb.ipy

from IPython.display import HTML
from IPython.nbconvert.filters import markdown2html_pandoc

displaymd = lambda markdown: display_html(HTML(markdown2html_pandoc(markdown)))

# Markdown tables are ugly, and Mathjax doesn't support \tabular,
# therefore we use math mode + \array + add a command \T to make 
# the \array rows less dense.

table_header = r"""$$
\require{color}
colordefs
\newcommand\T{\Rule{0pt}{1em}{.3em}}
\begin{array}{fmt}
\hline
body\\
\hline
\end{array}
$$"""

replacements = [('{', '{{'), ('}', '}}'), ('colordefs', '{colordefs}'),
                ('fmt', '{fmt}'), ('body', '{body}')]
for i, j in replacements:
    table_header = table_header.replace(i, j)

# Symmetry classes names and their symmetry properties
symmetry_classes = ("A", "AIII", "AI", "BDI", "D", "DIII", "AII", "CII", "C", "CI")
chiralsym = 5 * ('', '1')
phs = 3 * ('',) + 3 * ('1',) + ('',) + 3 * ('-1',)
trs = 2 * ('',) + 2 * ('1',) + ('',) + 3 * ('-1',) + ('', '1')

# Locations of non-empty entries in the periodic table
primary_seq = lambda n: np.arange(n) % 2
z_descendant = lambda n: np.arange(n) % 8
z2_descendant = lambda n: np.arange(1, n+1) % 8
z2_descendant2 = lambda n: np.arange(2, n+2) % 8
twoz_descendant = lambda n: np.arange(4, n+4) % 8

line_end = '\\T\\\\\n'
sep = ' & '

def make_table(n=4, show_symmetries=True, sort_order=None):
    """Create an array of entries forming the periodic table.
    
    Parameters:
    -----------
    n : int
        Number of dimensions to show.
    show_symmetries : bool
        Show symmetry information for each symmetry class.
    sort_order : int array or None
        Ordering to apply to the symmetry classes 
        (can be trivially used to discard entries).
    
    Returns:
    --------
    data : np.ndarray
        A string array with the entries of the periodic table.
    format_string : str
        An alignment string that can be used to feed the resulting
        table to a Latex \array environment. 
    """

    dimensions = np.array([[str(i) for i in range(n)]], dtype='S100')
    if dimensions.shape[1]:
        dimensions[0, 0] = r'd=' + dimensions[0, 0]

    complex_entries = np.zeros((2, n), dtype='S100')
    complex_entries[primary_seq(n), np.arange(n)] = r'\mathbb{Z}'

    real_entries = np.zeros((8, n), dtype='S100')
    real_entries[z_descendant(n), np.arange(n)] = r'\mathbb{Z}'
    real_entries[z2_descendant(n), np.arange(n)] = r'\mathbb{Z}_2'
    real_entries[z2_descendant2(n), np.arange(n)] = r'\mathbb{Z}_2'
    real_entries[twoz_descendant(n), np.arange(n)] = r'2\mathbb{Z}'


    entries = np.r_[complex_entries, real_entries]

    sym_classes_rm = tuple(r'\textrm{{{}}}'.format(cl) for cl in symmetry_classes)

    sym = np.array([sym_classes_rm] + show_symmetries * [chiralsym, phs, trs], dtype='S100').T
    sym_header = np.array([[r'\textrm{class}'] + 
                           show_symmetries * [r'\mathcal{C}', r'\mathcal{P}', r'\mathcal{T}']], dtype='S100')
    header = np.c_[sym_header, dimensions]

    table = np.c_[sym, entries]
    if sort_order is not None:
        table = table[sort_order]

    format_string = 'c|' + show_symmetries * 'rrr' + n * show_symmetries * '|' + n * 'c'
    return np.r_[header, table], format_string


def color_table(table, color_array):
    """Apply rgb colors to table entries.
    
    `color_array[i, j]` is the rgb color of the entry `(i, j)`.
    
    Returns the string of color definitions required for coloring the table.
    """
    apply_color = lambda text, color: r'\color{{{}}}{{{}}}'.format(color, text)

    colors = {}
    for idx in np.indices(table.shape).reshape(2, -1).T:
        idx = tuple(idx)
        if not any(color_array[idx]):
            pass
        color = ','.join('{:.2}'.format(i) for i in color_array[idx])
        val = str(abs(hash(color)))[:4]
        colors[color] = val
        table[idx] = apply_color(table[idx], val)

    defs = []
    for color, code in colors.iteritems():
        defs.append(r'\definecolor{{{}}}{{rgb}}{{{}}}'.format(code, color))
    return '\n'.join(defs)
# Out:
# Performing the necessary imports.
#
# from __future__ import division, print_function
# import numpy as np
# import matplotlib
# import kwant
#
# import ipywidgets
# from IPython.html.widgets import interact
# from ipywidgets import StaticInteract, RangeWidget, DropDownWidget
# from IPython.display import display_html
# from matplotlib import pyplot as plt
#
# import pfaffian as pf
# from edx_components import *
# <script type=text/javascript>
# /* Add a button for showing or hiding input */
# on = "Show input";
# off = "Hide input";
# function onoff(){
#   currentvalue = document.getElementById('onoff').value;
#   if(currentvalue == off){
#     document.getElementById("onoff").value=on;
#       $('div.input').hide();
#   }else{
#     document.getElementById("onoff").value=off;
#       $('div.input').show();
#   }
# }
#
# /* Launch first notebook cell on start */
# function launch_first_cell (evt) {
#   if (!launch_first_cell.executed
#       && IPython.notebook.kernel
#   ) {
#     IPython.notebook.get_cells()[0].execute();
#     launch_first_cell.executed = true;
#   }
# }
#
# $([IPython.events]).on('status_started.Kernel notebook_loaded.Notebook', launch_first_cell);
# </script>
#
# <p>Press this button to show/hide the code used in the notebook:
# <input type="button" class="ui-button ui-widget ui-state-default ui-corner-all ui-button-text-only" value="Hide input" id="onoff" onclick="onoff();"></p>
# <script type=text/javascript>
# $(document).ready(function (){if(!("IPython" in window)){onoff();}})
# </script>

# %% [markdown]
# #Table of Contents
# * [Introduction](#Introduction)
# * [At a glance: periodic table](#At-a-glance:-periodic-table)
# * [Symmetry classes](#Symmetry-classes)
# * [What we learned so far](#What-we-learned-so-far)
# * [Complex case: Chern and winding numbers](#Complex-case:-Chern-and-winding-numbers)
# * [Periodic structure](#Periodic-structure)
# * [Conclusions](#Conclusions)

# %% [markdown]
# **No content above this line is visible in edX**

# %% [markdown]
# # Introduction

# %% [markdown]
# This topic is introduced by XXX

# %%
MoocVideo("", src_location="8.1-intro")

# %% [markdown]
# # At a glance: periodic table

# %% [markdown]
# Let us now look at all the possible symmetry classes in dimensions from $0$ to $3$, and see what kind of topological insulators are possible.
#
# There are quite a few, here is the full list:

# %%
full_table, format_string = make_table(show_symmetries=False, sort_order=np.argsort(symmetry_classes))

rows = [sep.join(line) for line in full_table]
rows[1] = r'\hline ' + rows[1]

block = line_end.join(rows)

displaymd(table_header.format(colordefs=colordefs, fmt=format_string, body=block))
# Out:
# <p><span class="math">\[
# \require{color}
# \definecolor{5054}{rgb}{0.93,0.81,0.04}
# \definecolor{3115}{rgb}{0.85,0.81,0.11}
# \definecolor{5140}{rgb}{0.48,0.92,0.72}
# \definecolor{1522}{rgb}{0.1,0.02,0.7}
# \definecolor{5407}{rgb}{0.61,0.27,0.9}
# \definecolor{8821}{rgb}{0.48,0.67,0.16}
# \definecolor{1399}{rgb}{0.32,0.25,0.42}
# \definecolor{1011}{rgb}{0.7,0.43,0.05}
# \definecolor{7848}{rgb}{0.56,0.83,0.4}
# \definecolor{3206}{rgb}{0.79,0.41,0.21}
# \definecolor{7329}{rgb}{0.8,0.13,0.07}
# \definecolor{8570}{rgb}{0.48,0.55,0.73}
# \definecolor{8075}{rgb}{0.79,0.89,0.66}
# \definecolor{4671}{rgb}{0.75,0.58,0.42}
# \definecolor{5039}{rgb}{0.77,0.61,0.42}
# \definecolor{6815}{rgb}{0.83,0.14,0.84}
# \definecolor{8465}{rgb}{0.21,0.12,0.84}
# \definecolor{2288}{rgb}{0.18,0.27,0.8}
# \definecolor{7245}{rgb}{0.03,0.47,0.22}
# \definecolor{9174}{rgb}{0.11,0.17,0.84}
# \definecolor{5051}{rgb}{0.16,0.81,0.68}
# \definecolor{5764}{rgb}{0.78,0.61,0.82}
# \definecolor{1407}{rgb}{0.58,0.87,0.24}
# \definecolor{8791}{rgb}{0.79,0.55,0.75}
# \definecolor{4378}{rgb}{0.59,0.6,0.81}
# \definecolor{2301}{rgb}{0.09,0.09,0.92}
# \definecolor{8262}{rgb}{0.41,0.57,0.42}
# \definecolor{5250}{rgb}{0.83,0.27,0.05}
# \definecolor{7593}{rgb}{0.02,0.87,0.45}
# \definecolor{2260}{rgb}{0.53,0.05,0.59}
# \definecolor{3487}{rgb}{0.82,0.78,0.65}
# \definecolor{6802}{rgb}{0.2,0.98,0.19}
# \definecolor{4123}{rgb}{0.95,0.23,0.16}
# \definecolor{7453}{rgb}{0.98,0.51,0.41}
# \definecolor{2782}{rgb}{0.82,0.53,0.01}
# \definecolor{4493}{rgb}{0.13,0.59,0.13}
# \definecolor{6432}{rgb}{0.28,0.01,0.37}
# \definecolor{3510}{rgb}{0.87,0.24,0.96}
# \definecolor{4206}{rgb}{0.28,0.91,0.41}
# \definecolor{4034}{rgb}{0.71,0.13,0.55}
# \definecolor{1168}{rgb}{0.74,0.27,0.71}
# \definecolor{8702}{rgb}{0.75,0.16,0.92}
# \definecolor{2688}{rgb}{0.43,0.84,0.12}
# \definecolor{4325}{rgb}{0.65,0.44,0.13}
# \definecolor{2128}{rgb}{0.99,0.62,0.14}
# \definecolor{2823}{rgb}{0.98,0.27,0.18}
# \definecolor{7776}{rgb}{0.07,0.16,0.34}
# \definecolor{2981}{rgb}{0.06,0.77,0.35}
# \definecolor{8959}{rgb}{0.07,0.04,0.64}
# \definecolor{8100}{rgb}{0.05,0.4,0.9}
# \definecolor{7013}{rgb}{0.57,0.22,0.62}
# \definecolor{1728}{rgb}{0.33,0.03,0.22}
# \definecolor{1727}{rgb}{0.03,0.52,0.24}
# \definecolor{7048}{rgb}{0.54,0.42,0.6}
# \definecolor{3062}{rgb}{0.75,0.26,0.78}
# \definecolor{5866}{rgb}{0.05,0.68,0.06}
# \definecolor{8583}{rgb}{0.43,0.83,0.49}
# \definecolor{4558}{rgb}{0.27,0.94,0.09}
# \definecolor{1878}{rgb}{0.19,0.82,0.62}
# \definecolor{4485}{rgb}{0.18,0.03,0.71}
# \definecolor{1848}{rgb}{0.77,0.45,0.69}
# \definecolor{1131}{rgb}{0.02,0.17,0.96}
# \definecolor{6421}{rgb}{0.22,0.48,0.78}
# \definecolor{8687}{rgb}{0.25,0.52,0.17}
# \definecolor{1123}{rgb}{0.39,0.72,0.09}
# \definecolor{9201}{rgb}{0.04,0.64,0.18}
# \definecolor{1856}{rgb}{0.23,0.76,0.08}
# \definecolor{7494}{rgb}{0.99,0.02,0.64}
# \definecolor{3910}{rgb}{0.38,0.04,0.82}
# \definecolor{4826}{rgb}{0.24,0.62,0.19}
# \definecolor{2780}{rgb}{0.12,0.4,0.61}
# \definecolor{2298}{rgb}{0.5,0.69,0.23}
# \definecolor{2871}{rgb}{0.41,0.9,0.02}
# \definecolor{7021}{rgb}{0.69,0.93,0.87}
# \definecolor{1611}{rgb}{0.97,0.13,0.91}
# \definecolor{5316}{rgb}{0.51,0.62,0.61}
# \definecolor{8862}{rgb}{0.71,0.38,0.36}
# \definecolor{9175}{rgb}{0.75,0.94,0.94}
# \definecolor{4454}{rgb}{0.58,0.32,0.07}
# \definecolor{3623}{rgb}{0.52,0.82,0.38}
# \definecolor{3291}{rgb}{0.59,0.54,0.46}
# \definecolor{2352}{rgb}{0.28,0.95,0.8}
# \definecolor{1784}{rgb}{0.39,0.57,0.9}
# \definecolor{7576}{rgb}{0.29,0.76,0.79}
# \definecolor{1006}{rgb}{0.32,0.23,0.25}
# \definecolor{2521}{rgb}{0.83,0.16,0.14}
# \definecolor{5653}{rgb}{0.06,0.63,0.7}
# \definecolor{2677}{rgb}{0.76,0.42,0.85}
# \newcommand\T{\Rule{0pt}{1em}{.3em}}
# \begin{array}{c|cccc}
# \hline
# \textrm{class} &amp; d=0 &amp; 1 &amp; 2 &amp; 3\T\\
# \hline \textrm{A} &amp; \mathbb{Z} &amp;  &amp; \mathbb{Z} &amp; \T\\
# \textrm{AI} &amp; \mathbb{Z} &amp;  &amp;  &amp; \T\\
# \textrm{AII} &amp; 2\mathbb{Z} &amp;  &amp; \mathbb{Z}_2 &amp; \mathbb{Z}_2\T\\
# \textrm{AIII} &amp;  &amp; \mathbb{Z} &amp;  &amp; \mathbb{Z}\T\\
# \textrm{BDI} &amp; \mathbb{Z}_2 &amp; \mathbb{Z} &amp;  &amp; \T\\
# \textrm{C} &amp;  &amp;  &amp; 2\mathbb{Z} &amp; \T\\
# \textrm{CI} &amp;  &amp;  &amp;  &amp; 2\mathbb{Z}\T\\
# \textrm{CII} &amp;  &amp; 2\mathbb{Z} &amp;  &amp; \mathbb{Z}_2\T\\
# \textrm{D} &amp; \mathbb{Z}_2 &amp; \mathbb{Z}_2 &amp; \mathbb{Z} &amp; \T\\
# \textrm{DIII} &amp;  &amp; \mathbb{Z}_2 &amp; \mathbb{Z}_2 &amp; \mathbb{Z}\\
# \hline
# \end{array}
# \]</span></p>

# %% [markdown]
# This table has a lot of logic in it, but to you it most likely looks not better than this:

# %%
full_table, format_string = make_table(sort_order=np.argsort(symmetry_classes))

color_array = np.round(np.random.rand(*(full_table.shape + (3,))), 2)
#color_array = np.zeros((full_table.shape + (3,)))
colordefs = color_table(full_table, color_array)

rows = [sep.join(line) for line in full_table]
rows[1] = r'\hline ' + rows[1]
#rows[3] = r'\hline ' + rows[3]

block = line_end.join(rows)

displaymd(table_header.format(colordefs=colordefs, fmt=format_string, body=block))
# Out:
# <p><span class="math">\[
# \require{color}
# \definecolor{3353}{rgb}{0.88,0.79,0.7}
# \definecolor{5809}{rgb}{0.92,0.78,0.43}
# \definecolor{7729}{rgb}{0.3,0.4,0.75}
# \definecolor{6683}{rgb}{0.97,0.51,0.55}
# \definecolor{1437}{rgb}{0.42,0.2,0.29}
# \definecolor{1491}{rgb}{0.78,0.71,0.84}
# \definecolor{3256}{rgb}{0.92,0.08,0.71}
# \definecolor{3994}{rgb}{0.23,0.37,0.97}
# \definecolor{1312}{rgb}{0.68,0.58,0.22}
# \definecolor{9163}{rgb}{0.24,0.17,0.61}
# \definecolor{1851}{rgb}{0.2,0.93,0.46}
# \definecolor{3139}{rgb}{0.05,0.45,0.86}
# \definecolor{7971}{rgb}{0.67,0.88,0.66}
# \definecolor{7104}{rgb}{0.58,0.12,0.08}
# \definecolor{8098}{rgb}{0.33,0.93,0.34}
# \definecolor{1791}{rgb}{0.29,0.84,0.41}
# \definecolor{7216}{rgb}{0.05,0.81,0.85}
# \definecolor{6421}{rgb}{0.22,0.48,0.83}
# \definecolor{5766}{rgb}{0.82,0.26,0.62}
# \definecolor{4997}{rgb}{0.04,0.89,0.57}
# \definecolor{2793}{rgb}{0.55,0.51,0.53}
# \definecolor{3883}{rgb}{0.16,0.99,0.62}
# \definecolor{1259}{rgb}{0.22,0.04,0.55}
# \definecolor{8108}{rgb}{0.02,0.13,0.26}
# \definecolor{1741}{rgb}{0.39,0.36,0.59}
# \definecolor{8235}{rgb}{0.09,0.93,0.16}
# \definecolor{4673}{rgb}{0.33,0.67,0.81}
# \definecolor{3548}{rgb}{0.15,0.43,0.55}
# \definecolor{2582}{rgb}{0.66,0.88,0.64}
# \definecolor{8079}{rgb}{0.89,0.06,0.6}
# \definecolor{4706}{rgb}{0.85,0.94,0.63}
# \definecolor{5713}{rgb}{0.04,0.53,0.75}
# \definecolor{6981}{rgb}{0.14,0.51,0.3}
# \definecolor{7815}{rgb}{0.66,0.83,0.37}
# \definecolor{3601}{rgb}{0.21,0.82,0.47}
# \definecolor{4461}{rgb}{0.34,0.05,0.11}
# \definecolor{2670}{rgb}{0.87,0.68,0.1}
# \definecolor{2687}{rgb}{0.57,0.54,0.56}
# \definecolor{3911}{rgb}{0.89,0.69,0.43}
# \definecolor{2454}{rgb}{0.84,0.53,0.12}
# \definecolor{9132}{rgb}{0.14,0.85,0.35}
# \definecolor{8085}{rgb}{0.78,0.3,0.22}
# \definecolor{2660}{rgb}{0.47,0.54,0.33}
# \definecolor{5132}{rgb}{0.9,0.68,0.62}
# \definecolor{6719}{rgb}{0.04,0.23,0.61}
# \definecolor{6028}{rgb}{0.49,0.7,0.37}
# \definecolor{7875}{rgb}{0.57,0.16,0.1}
# \definecolor{7217}{rgb}{0.57,0.27,0.03}
# \definecolor{8952}{rgb}{0.42,0.31,0.16}
# \definecolor{8692}{rgb}{0.63,0.25,0.26}
# \definecolor{4547}{rgb}{0.23,0.68,0.47}
# \definecolor{4427}{rgb}{0.85,0.66,0.04}
# \definecolor{8502}{rgb}{0.95,0.05,0.42}
# \definecolor{5336}{rgb}{0.8,0.04,0.42}
# \definecolor{2688}{rgb}{0.65,0.38,0.19}
# \definecolor{3644}{rgb}{0.51,0.44,0.91}
# \definecolor{7375}{rgb}{0.37,0.93,0.79}
# \definecolor{7662}{rgb}{0.98,0.43,0.42}
# \definecolor{3787}{rgb}{0.58,0.57,0.72}
# \definecolor{2535}{rgb}{0.13,0.64,0.12}
# \definecolor{6961}{rgb}{0.07,0.37,0.76}
# \definecolor{6602}{rgb}{0.59,0.44,0.46}
# \definecolor{4211}{rgb}{0.42,0.68,0.01}
# \definecolor{5289}{rgb}{0.53,0.35,0.65}
# \definecolor{3811}{rgb}{0.37,0.62,0.15}
# \definecolor{5049}{rgb}{0.95,0.06,0.83}
# \definecolor{1365}{rgb}{0.75,0.86,0.54}
# \definecolor{8642}{rgb}{0.8,0.82,0.67}
# \definecolor{5822}{rgb}{0.67,0.95,0.55}
# \definecolor{1430}{rgb}{0.93,0.58,1.0}
# \definecolor{3474}{rgb}{0.46,0.76,0.98}
# \definecolor{7490}{rgb}{0.47,0.3,0.18}
# \definecolor{1993}{rgb}{0.1,0.97,0.08}
# \definecolor{3599}{rgb}{0.51,0.93,0.74}
# \definecolor{3224}{rgb}{0.58,0.66,0.55}
# \definecolor{2337}{rgb}{0.36,0.91,0.85}
# \definecolor{8023}{rgb}{0.48,0.77,0.43}
# \definecolor{8741}{rgb}{0.26,0.57,0.26}
# \definecolor{8794}{rgb}{0.99,0.42,0.89}
# \definecolor{8741}{rgb}{0.26,0.57,0.29}
# \definecolor{5258}{rgb}{0.44,0.49,0.94}
# \definecolor{8851}{rgb}{0.46,0.44,0.33}
# \definecolor{4910}{rgb}{0.53,0.13,0.95}
# \definecolor{8393}{rgb}{0.44,0.73,0.38}
# \definecolor{9097}{rgb}{0.03,0.57,0.06}
# \definecolor{6998}{rgb}{0.5,0.46,0.58}
# \definecolor{5763}{rgb}{0.49,0.33,0.6}
# \definecolor{6358}{rgb}{0.2,0.92,0.17}
# \newcommand\T{\Rule{0pt}{1em}{.3em}}
# \begin{array}{c|rrr||||cccc}
# \hline
# \color{6961}{\textrm{class}} &amp; \color{1437}{\mathcal{C}} &amp; \color{3256}{\mathcal{P}} &amp; \color{6981}{\mathcal{T}} &amp; \color{1993}{d=0} &amp; \color{1259}{1} &amp; \color{8692}{2} &amp; \color{1741}{3}\T\\
# \hline \color{5809}{\textrm{A}} &amp; \color{9097}{} &amp; \color{7217}{} &amp; \color{5132}{} &amp; \color{6998}{\mathbb{Z}} &amp; \color{4427}{} &amp; \color{1312}{\mathbb{Z}} &amp; \color{1365}{}\T\\
# \color{8079}{\textrm{AI}} &amp; \color{5289}{} &amp; \color{1430}{} &amp; \color{7104}{1} &amp; \color{6719}{\mathbb{Z}} &amp; \color{3548}{} &amp; \color{5336}{} &amp; \color{7375}{}\T\\
# \color{3883}{\textrm{AII}} &amp; \color{1851}{} &amp; \color{8085}{} &amp; \color{8023}{-1} &amp; \color{1791}{2\mathbb{Z}} &amp; \color{5763}{} &amp; \color{7662}{\mathbb{Z}_2} &amp; \color{2535}{\mathbb{Z}_2}\T\\
# \color{9163}{\textrm{AIII}} &amp; \color{3601}{1} &amp; \color{2687}{} &amp; \color{5822}{} &amp; \color{3474}{} &amp; \color{8851}{\mathbb{Z}} &amp; \color{4997}{} &amp; \color{8235}{\mathbb{Z}}\T\\
# \color{5766}{\textrm{BDI}} &amp; \color{4461}{1} &amp; \color{8952}{1} &amp; \color{6421}{1} &amp; \color{2454}{\mathbb{Z}_2} &amp; \color{3353}{\mathbb{Z}} &amp; \color{3911}{} &amp; \color{7875}{}\T\\
# \color{2660}{\textrm{C}} &amp; \color{6683}{} &amp; \color{3139}{-1} &amp; \color{7815}{} &amp; \color{6602}{} &amp; \color{7216}{} &amp; \color{3599}{2\mathbb{Z}} &amp; \color{4673}{}\T\\
# \color{2670}{\textrm{CI}} &amp; \color{2793}{1} &amp; \color{4211}{-1} &amp; \color{2688}{1} &amp; \color{3787}{} &amp; \color{3811}{} &amp; \color{1491}{} &amp; \color{2337}{2\mathbb{Z}}\T\\
# \color{5713}{\textrm{CII}} &amp; \color{5049}{1} &amp; \color{8502}{-1} &amp; \color{3644}{-1} &amp; \color{4547}{} &amp; \color{5258}{2\mathbb{Z}} &amp; \color{3994}{} &amp; \color{8098}{\mathbb{Z}_2}\T\\
# \color{8393}{\textrm{D}} &amp; \color{4910}{} &amp; \color{7490}{1} &amp; \color{6358}{} &amp; \color{9132}{\mathbb{Z}_2} &amp; \color{8741}{\mathbb{Z}_2} &amp; \color{3224}{\mathbb{Z}} &amp; \color{8794}{}\T\\
# \color{4706}{\textrm{DIII}} &amp; \color{8108}{1} &amp; \color{2582}{1} &amp; \color{8741}{-1} &amp; \color{6028}{} &amp; \color{8642}{\mathbb{Z}_2} &amp; \color{7729}{\mathbb{Z}_2} &amp; \color{7971}{\mathbb{Z}}\\
# \hline
# \end{array}
# \]</span></p>

# %% [markdown]
# # Symmetry classes

# %% [markdown]
# # What we learned so far

# %% [markdown]
# # Complex case: Chern and winding numbers

# %% [markdown]
# # Periodic structure

# %% [markdown]
# # Dimensional reduction

# %% [markdown]
# # Conclusions

# %%
MoocVideo("", src_location="8.1-summary")

# %% [markdown]
# Questions about what you just learned? Ask them below!

# %%
MoocDiscussion("Questions", "Periodic table")
# Out:
# MoocDiscussion(**{'discussion_category': 'Questions', 'discussion_target': 'Periodic table', 'display_name': 'Periodic table', 'discussion_id': 'a673e4cfbe6926ff2c727e2b890b04ba'})
