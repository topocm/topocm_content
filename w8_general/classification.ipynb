# %%
# %run ../code/init_mooc_nb.ipy

from IPython.display import HTML
from IPython.nbconvert.filters import markdown2html_pandoc

displaymd = lambda markdown: display_html(HTML(markdown2html_pandoc(markdown)))

# Markdown tables are ugly, and Mathjax doesn't support \tabular,
# therefore we use math mode + \array + add a command \T to make 
# the \array rows less dense.

table_header = r"""$$
\require{color}
colordefs
\newcommand\T{\Rule{0pt}{1em}{.3em}}
\begin{array}{fmt}
\hline
body\\
\hline
\end{array}
$$"""

replacements = [('{', '{{'), ('}', '}}'), ('colordefs', '{colordefs}'),
                ('fmt', '{fmt}'), ('body', '{body}')]
for i, j in replacements:
    table_header = table_header.replace(i, j)

# Symmetry classes names and their symmetry properties
symmetry_classes = ("A", "AIII", "AI", "BDI", "D", "DIII", "AII", "CII", "C", "CI")
chiralsym = 5 * ('', '1')
phs = 3 * ('',) + 3 * ('1',) + ('',) + 3 * ('-1',)
trs = 2 * ('',) + 2 * ('1',) + ('',) + 3 * ('-1',) + ('', '1')

# Locations of non-empty entries in the periodic table
primary_seq = lambda n: np.arange(n) % 2
z_descendant = lambda n: np.arange(n) % 8
z2_descendant = lambda n: np.arange(1, n+1) % 8
z2_descendant2 = lambda n: np.arange(2, n+2) % 8
twoz_descendant = lambda n: np.arange(4, n+4) % 8

line_end = '\\T\\\\\n'
sep = ' & '

def make_table(n=4, show_symmetries=True, sort_order=None):
    """Create an array of entries forming the periodic table.
    
    Parameters:
    -----------
    n : int
        Number of dimensions to show.
    show_symmetries : bool
        Show symmetry information for each symmetry class.
    sort_order : int array or None
        Ordering to apply to the symmetry classes 
        (can be trivially used to discard entries).
    
    Returns:
    --------
    data : np.ndarray
        A string array with the entries of the periodic table.
    format_string : str
        An alignment string that can be used to feed the resulting
        table to a Latex \array environment. 
    """

    dimensions = np.array([[str(i) for i in range(n)]], dtype='S100')
    if dimensions.shape[1]:
        dimensions[0, 0] = r'd=' + dimensions[0, 0]

    complex_entries = np.zeros((2, n), dtype='S100')
    complex_entries[primary_seq(n), np.arange(n)] = r'\mathbb{Z}'

    real_entries = np.zeros((8, n), dtype='S100')
    real_entries[z_descendant(n), np.arange(n)] = r'\mathbb{Z}'
    real_entries[z2_descendant(n), np.arange(n)] = r'\mathbb{Z}_2'
    real_entries[z2_descendant2(n), np.arange(n)] = r'\mathbb{Z}_2'
    real_entries[twoz_descendant(n), np.arange(n)] = r'2\mathbb{Z}'


    entries = np.r_[complex_entries, real_entries]

    sym_classes_rm = tuple(r'\textrm{{{}}}'.format(cl) for cl in symmetry_classes)

    sym = np.array([sym_classes_rm] + show_symmetries * [chiralsym, phs, trs], dtype='S100').T
    sym_header = np.array([[r'\textrm{class}'] + 
                           show_symmetries * [r'\mathcal{C}', r'\mathcal{P}', r'\mathcal{T}']], dtype='S100')
    header = np.c_[sym_header, dimensions]

    table = np.c_[sym, entries]
    if sort_order is not None:
        table = table[sort_order]

    format_string = 'c|' + show_symmetries * 'rrr' + n * show_symmetries * '|' + n * 'c'
    return np.r_[header, table], format_string


def color_table(table, color_array):
    """Apply rgb colors to table entries.
    
    `color_array[i, j]` is the rgb color of the entry `(i, j)`.
    
    Returns the string of color definitions required for coloring the table.
    """
    apply_color = lambda text, color: r'\color{{{}}}{{{}}}'.format(color, text)

    colors = {}
    for idx in np.indices(table.shape).reshape(2, -1).T:
        idx = tuple(idx)
        if not any(color_array[idx]):
            pass
        color = ','.join('{:1.2}'.format(i) for i in color_array[idx])
        val = str(abs(hash(color)))[:8]
        colors[color] = val
        table[idx] = apply_color(table[idx], val)

    defs = []
    for color, code in colors.iteritems():
        defs.append(r'\definecolor{{{}}}{{rgb}}{{{}}}'.format(code, color))
    return '\n'.join(defs)
# Out:
# Performing the necessary imports.
#
# from __future__ import division, print_function
# import numpy as np
# import matplotlib
# import kwant
#
# import ipywidgets
# from IPython.html.widgets import interact
# from ipywidgets import StaticInteract, RangeWidget, DropDownWidget
# from IPython.display import display_html
# from matplotlib import pyplot as plt
#
# import pfaffian as pf
# from edx_components import *
# <script type=text/javascript>
# /* Add a button for showing or hiding input */
# on = "Show input";
# off = "Hide input";
# function onoff(){
#   currentvalue = document.getElementById('onoff').value;
#   if(currentvalue == off){
#     document.getElementById("onoff").value=on;
#       $('div.input').hide();
#   }else{
#     document.getElementById("onoff").value=off;
#       $('div.input').show();
#   }
# }
#
# /* Launch first notebook cell on start */
# function launch_first_cell (evt) {
#   if (!launch_first_cell.executed
#       && IPython.notebook.kernel
#   ) {
#     IPython.notebook.get_cells()[0].execute();
#     launch_first_cell.executed = true;
#   }
# }
#
# $([IPython.events]).on('status_started.Kernel notebook_loaded.Notebook', launch_first_cell);
# </script>
#
# <p>Press this button to show/hide the code used in the notebook:
# <input type="button" class="ui-button ui-widget ui-state-default ui-corner-all ui-button-text-only" value="Hide input" id="onoff" onclick="onoff();"></p>
# <script type=text/javascript>
# $(document).ready(function (){if(!("IPython" in window)){onoff();}})
# </script>

# %% [markdown]
# #Table of Contents
# * [Introduction](#Introduction)
# * [At a glance: periodic table](#At-a-glance:-periodic-table)
# * [Symmetry classes](#Symmetry-classes)
# * [What we learned so far](#What-we-learned-so-far)
# * [Periodic structure](#Periodic-structure)
# * [Dimensional reduction](#Dimensional-reduction)
# * [Conclusions](#Conclusions)

# %% [markdown]
# **No content above this line is visible in edX**

# %% [markdown]
# # Introduction

# %% [markdown]
# Shinsei Ryu from the university of Illinois will introduce the general classification of topological insulators and superconductors

# %%
MoocVideo("", src_location="8.1-intro")

# %% [markdown]
# # At a glance: periodic table

# %% [markdown]
# Let us now look at all the possible symmetry classes in dimensions from $0$ to $3$, and see what kind of topological insulators are possible.
#
# There are quite a few, here is the full list:

# %%
full_table, format_string = make_table(show_symmetries=False, sort_order=np.argsort(symmetry_classes))

rows = [sep.join(line) for line in full_table]
rows[1] = r'\hline ' + rows[1]
block = line_end.join(rows)
colordefs='{}'

displaymd(table_header.format(colordefs=colordefs, fmt=format_string, body=block))
# Out:
# <p><span class="math">\[
# \require{color}
# {}
# \newcommand\T{\Rule{0pt}{1em}{.3em}}
# \begin{array}{c|cccc}
# \hline
# \textrm{class} &amp; d=0 &amp; 1 &amp; 2 &amp; 3\T\\
# \hline \textrm{A} &amp; \mathbb{Z} &amp;  &amp; \mathbb{Z} &amp; \T\\
# \textrm{AI} &amp; \mathbb{Z} &amp;  &amp;  &amp; \T\\
# \textrm{AII} &amp; 2\mathbb{Z} &amp;  &amp; \mathbb{Z}_2 &amp; \mathbb{Z}_2\T\\
# \textrm{AIII} &amp;  &amp; \mathbb{Z} &amp;  &amp; \mathbb{Z}\T\\
# \textrm{BDI} &amp; \mathbb{Z}_2 &amp; \mathbb{Z} &amp;  &amp; \T\\
# \textrm{C} &amp;  &amp;  &amp; 2\mathbb{Z} &amp; \T\\
# \textrm{CI} &amp;  &amp;  &amp;  &amp; 2\mathbb{Z}\T\\
# \textrm{CII} &amp;  &amp; 2\mathbb{Z} &amp;  &amp; \mathbb{Z}_2\T\\
# \textrm{D} &amp; \mathbb{Z}_2 &amp; \mathbb{Z}_2 &amp; \mathbb{Z} &amp; \T\\
# \textrm{DIII} &amp;  &amp; \mathbb{Z}_2 &amp; \mathbb{Z}_2 &amp; \mathbb{Z}\\
# \hline
# \end{array}
# \]</span></p>

# %% [markdown]
# This table has a lot of logic in it, but to you it most likely looks not better than this:

# %%
np.random.seed(1)

full_table, format_string = make_table(show_symmetries=False, sort_order=np.random.permutation(10))

color_array = np.round(np.random.rand(*(full_table.shape + (3,))), 2)
colordefs = color_table(full_table, color_array)

rows = [sep.join(line) for line in full_table]
rows[1] = r'\hline ' + rows[1]
block = line_end.join(rows)

displaymd(table_header.format(colordefs=colordefs, fmt=format_string, body=block))
# Out:
# <p><span class="math">\[
# \require{color}
# \definecolor{2068}{rgb}{0.36,0.15,0.94}
# \definecolor{2430}{rgb}{0.79,0.06,0.36}
# \definecolor{8668}{rgb}{0.14,0.79,0.03}
# \definecolor{2130}{rgb}{0.75,0.43,0.43}
# \definecolor{4813}{rgb}{0.47,0.27,0.83}
# \definecolor{5463}{rgb}{0.01,0.5,0.07}
# \definecolor{7888}{rgb}{0.64,0.13,0.69}
# \definecolor{7125}{rgb}{0.12,0.52,0.08}
# \definecolor{8491}{rgb}{0.78,0.41,0.03}
# \definecolor{5809}{rgb}{0.92,0.78,0.62}
# \definecolor{1826}{rgb}{0.2,0.29,0.14}
# \definecolor{7997}{rgb}{0.72,0.61,0.43}
# \definecolor{5721}{rgb}{0.45,0.22,0.07}
# \definecolor{7862}{rgb}{0.77,0.3,0.77}
# \definecolor{3496}{rgb}{0.54,0.77,0.05}
# \definecolor{5863}{rgb}{0.88,0.54,0.45}
# \definecolor{1651}{rgb}{0.98,0.89,0.76}
# \definecolor{4780}{rgb}{0.55,0.07,0.47}
# \definecolor{1742}{rgb}{0.91,0.46,0.43}
# \definecolor{4566}{rgb}{0.59,0.67,0.41}
# \definecolor{2782}{rgb}{0.94,0.38,0.76}
# \definecolor{8295}{rgb}{0.05,0.52,0.17}
# \definecolor{1743}{rgb}{0.87,0.83,0.83}
# \definecolor{1151}{rgb}{0.65,0.04,0.81}
# \definecolor{8095}{rgb}{0.97,0.28,0.23}
# \definecolor{7739}{rgb}{0.92,0.91,0.3}
# \definecolor{6931}{rgb}{0.09,0.57,0.42}
# \definecolor{8473}{rgb}{0.23,0.51,0.21}
# \definecolor{3999}{rgb}{0.65,0.35,0.76}
# \definecolor{3688}{rgb}{0.39,0.67,0.94}
# \definecolor{1584}{rgb}{0.47,0.1,0.9}
# \definecolor{8365}{rgb}{0.27,0.06,0.67}
# \definecolor{4276}{rgb}{0.8,0.09,0.52}
# \definecolor{5363}{rgb}{0.74,0.3,0.2}
# \definecolor{4657}{rgb}{0.96,0.26,0.23}
# \definecolor{8710}{rgb}{0.65,0.36,0.57}
# \definecolor{6710}{rgb}{0.4,0.11,0.51}
# \definecolor{5776}{rgb}{0.07,0.15,0.16}
# \definecolor{2913}{rgb}{0.15,0.58,0.01}
# \definecolor{2058}{rgb}{0.36,0.75,0.88}
# \definecolor{2329}{rgb}{0.94,0.78,0.72}
# \definecolor{4971}{rgb}{0.94,0.37,0.05}
# \definecolor{3481}{rgb}{0.44,0.23,0.53}
# \definecolor{3787}{rgb}{0.58,0.57,0.61}
# \definecolor{4405}{rgb}{0.76,0.46,0.53}
# \definecolor{6762}{rgb}{0.1,0.29,0.23}
# \definecolor{7338}{rgb}{0.62,0.66,0.3}
# \definecolor{9916}{rgb}{0.04,0.65,0.13}
# \definecolor{8117}{rgb}{0.29,0.36,0.27}
# \definecolor{7946}{rgb}{0.89,0.38,0.54}
# \definecolor{3316}{rgb}{0.71,0.47,0.76}
# \definecolor{5627}{rgb}{0.53,0.95,0.49}
# \definecolor{3924}{rgb}{0.85,0.31,0.52}
# \definecolor{8567}{rgb}{0.37,0.81,0.29}
# \definecolor{5269}{rgb}{0.74,0.19,0.46}
# \newcommand\T{\Rule{0pt}{1em}{.3em}}
# \begin{array}{c|cccc}
# \hline
# \color{3688}{\textrm{class}} &amp; \color{3924}{d=0} &amp; \color{3481}{1} &amp; \color{1742}{2} &amp; \color{2329}{3}\T\\
# \hline \color{4276}{\textrm{AI}} &amp; \color{1743}{\mathbb{Z}} &amp; \color{8365}{} &amp; \color{4566}{} &amp; \color{1826}{}\T\\
# \color{8491}{\textrm{CI}} &amp; \color{7338}{} &amp; \color{5721}{} &amp; \color{1584}{} &amp; \color{7125}{2\mathbb{Z}}\T\\
# \color{7739}{\textrm{AII}} &amp; \color{3787}{2\mathbb{Z}} &amp; \color{4657}{} &amp; \color{5627}{\mathbb{Z}_2} &amp; \color{3496}{\mathbb{Z}_2}\T\\
# \color{8668}{\textrm{D}} &amp; \color{5863}{\mathbb{Z}_2} &amp; \color{7946}{\mathbb{Z}_2} &amp; \color{8710}{\mathbb{Z}} &amp; \color{7888}{}\T\\
# \color{3999}{\textrm{A}} &amp; \color{2058}{\mathbb{Z}} &amp; \color{5463}{} &amp; \color{2430}{\mathbb{Z}} &amp; \color{2782}{}\T\\
# \color{7862}{\textrm{BDI}} &amp; \color{2913}{\mathbb{Z}_2} &amp; \color{3316}{\mathbb{Z}} &amp; \color{4813}{} &amp; \color{4780}{}\T\\
# \color{5269}{\textrm{AIII}} &amp; \color{8473}{} &amp; \color{8295}{\mathbb{Z}} &amp; \color{6710}{} &amp; \color{6762}{\mathbb{Z}}\T\\
# \color{8095}{\textrm{CII}} &amp; \color{6931}{} &amp; \color{8567}{2\mathbb{Z}} &amp; \color{7997}{} &amp; \color{2130}{\mathbb{Z}_2}\T\\
# \color{2068}{\textrm{C}} &amp; \color{5809}{} &amp; \color{9916}{} &amp; \color{8117}{2\mathbb{Z}} &amp; \color{5776}{}\T\\
# \color{4971}{\textrm{DIII}} &amp; \color{5363}{} &amp; \color{1651}{\mathbb{Z}_2} &amp; \color{1151}{\mathbb{Z}_2} &amp; \color{4405}{\mathbb{Z}}\\
# \hline
# \end{array}
# \]</span></p>

# %% [markdown]
# But don't worry, we are going to learn exactly what these mean

# %% [markdown]
# # Symmetry classes

# %% [markdown]
# First, let's see what the different symmetry classes mean

# %%
np.random.seed(1)

full_table, format_string = make_table(n=0, show_symmetries=True, sort_order=np.argsort(symmetry_classes))

rows = [sep.join(line) for line in full_table]
rows[1] = r'\hline ' + rows[1]

block = line_end.join(rows)

displaymd(table_header.format(colordefs=colordefs, fmt=format_string, body=block))
# Out:
# <p><span class="math">\[
# \require{color}
# \definecolor{2068}{rgb}{0.36,0.15,0.94}
# \definecolor{2430}{rgb}{0.79,0.06,0.36}
# \definecolor{8668}{rgb}{0.14,0.79,0.03}
# \definecolor{2130}{rgb}{0.75,0.43,0.43}
# \definecolor{4813}{rgb}{0.47,0.27,0.83}
# \definecolor{5463}{rgb}{0.01,0.5,0.07}
# \definecolor{7888}{rgb}{0.64,0.13,0.69}
# \definecolor{7125}{rgb}{0.12,0.52,0.08}
# \definecolor{8491}{rgb}{0.78,0.41,0.03}
# \definecolor{5809}{rgb}{0.92,0.78,0.62}
# \definecolor{1826}{rgb}{0.2,0.29,0.14}
# \definecolor{7997}{rgb}{0.72,0.61,0.43}
# \definecolor{5721}{rgb}{0.45,0.22,0.07}
# \definecolor{7862}{rgb}{0.77,0.3,0.77}
# \definecolor{3496}{rgb}{0.54,0.77,0.05}
# \definecolor{5863}{rgb}{0.88,0.54,0.45}
# \definecolor{1651}{rgb}{0.98,0.89,0.76}
# \definecolor{4780}{rgb}{0.55,0.07,0.47}
# \definecolor{1742}{rgb}{0.91,0.46,0.43}
# \definecolor{4566}{rgb}{0.59,0.67,0.41}
# \definecolor{2782}{rgb}{0.94,0.38,0.76}
# \definecolor{8295}{rgb}{0.05,0.52,0.17}
# \definecolor{1743}{rgb}{0.87,0.83,0.83}
# \definecolor{1151}{rgb}{0.65,0.04,0.81}
# \definecolor{8095}{rgb}{0.97,0.28,0.23}
# \definecolor{7739}{rgb}{0.92,0.91,0.3}
# \definecolor{6931}{rgb}{0.09,0.57,0.42}
# \definecolor{8473}{rgb}{0.23,0.51,0.21}
# \definecolor{3999}{rgb}{0.65,0.35,0.76}
# \definecolor{3688}{rgb}{0.39,0.67,0.94}
# \definecolor{1584}{rgb}{0.47,0.1,0.9}
# \definecolor{8365}{rgb}{0.27,0.06,0.67}
# \definecolor{4276}{rgb}{0.8,0.09,0.52}
# \definecolor{5363}{rgb}{0.74,0.3,0.2}
# \definecolor{4657}{rgb}{0.96,0.26,0.23}
# \definecolor{8710}{rgb}{0.65,0.36,0.57}
# \definecolor{6710}{rgb}{0.4,0.11,0.51}
# \definecolor{5776}{rgb}{0.07,0.15,0.16}
# \definecolor{2913}{rgb}{0.15,0.58,0.01}
# \definecolor{2058}{rgb}{0.36,0.75,0.88}
# \definecolor{2329}{rgb}{0.94,0.78,0.72}
# \definecolor{4971}{rgb}{0.94,0.37,0.05}
# \definecolor{3481}{rgb}{0.44,0.23,0.53}
# \definecolor{3787}{rgb}{0.58,0.57,0.61}
# \definecolor{4405}{rgb}{0.76,0.46,0.53}
# \definecolor{6762}{rgb}{0.1,0.29,0.23}
# \definecolor{7338}{rgb}{0.62,0.66,0.3}
# \definecolor{9916}{rgb}{0.04,0.65,0.13}
# \definecolor{8117}{rgb}{0.29,0.36,0.27}
# \definecolor{7946}{rgb}{0.89,0.38,0.54}
# \definecolor{3316}{rgb}{0.71,0.47,0.76}
# \definecolor{5627}{rgb}{0.53,0.95,0.49}
# \definecolor{3924}{rgb}{0.85,0.31,0.52}
# \definecolor{8567}{rgb}{0.37,0.81,0.29}
# \definecolor{5269}{rgb}{0.74,0.19,0.46}
# \newcommand\T{\Rule{0pt}{1em}{.3em}}
# \begin{array}{c|rrr}
# \hline
# \textrm{class} &amp; \mathcal{C} &amp; \mathcal{P} &amp; \mathcal{T}\T\\
# \hline \textrm{A} &amp;  &amp;  &amp; \T\\
# \textrm{AI} &amp;  &amp;  &amp; 1\T\\
# \textrm{AII} &amp;  &amp;  &amp; -1\T\\
# \textrm{AIII} &amp; 1 &amp;  &amp; \T\\
# \textrm{BDI} &amp; 1 &amp; 1 &amp; 1\T\\
# \textrm{C} &amp;  &amp; -1 &amp; \T\\
# \textrm{CI} &amp; 1 &amp; -1 &amp; 1\T\\
# \textrm{CII} &amp; 1 &amp; -1 &amp; -1\T\\
# \textrm{D} &amp;  &amp; 1 &amp; \T\\
# \textrm{DIII} &amp; 1 &amp; 1 &amp; -1\\
# \hline
# \end{array}
# \]</span></p>

# %% [markdown]
# Here we see which class has which symmetry. Most of them have either PHS or TRS. Either of these symmetries imposes a relation between $H(k)$ and $H^*(-k)$.

# %% [markdown]
# # What we learned so far

# %%
tooltips = {(1, 6): "Chern insulator: no symmetries, d=2",
            (9, 5): "Majorana wire: spinful particle-hole, d=1",
            (4, 5): "Polyacetilene/SSH chain: sublattice symmetry, d=1",
            (3, 6): "QSHE: spinful TRS, d=2",
            (3, 7): "3D strong TI: spinful TRS, d=3",
            (9, 6): "p-wave superconductor: PHS, d=2",
            (9, 4): "Superconducting quantum dot: d=0, PHS",
            (2, 4): "Quantum dot: d=0, spinless TRS",
            (1, 4): "Quantum dot: d=0, no symmetries",
            (3, 4): "Quantum dot: d=0, spinful TRS and Kramers degeneracy"}

table, format_string = make_table(show_symmetries=True, sort_order=np.argsort(symmetry_classes))

colors = np.zeros(shape=table.shape+(3,))
colors[1:, 4:] = [0.7, 0.7, 0.7]

for pos in tooltips:
    colors[pos] = [1., 0., 0.]

colordefs = color_table(table, colors)

for pos, val in tooltips.items():
    table[pos] = r'\texttip{{{}}}{{{}}}'.format(table[pos], val)

rows = [sep.join(line) for line in table]
rows[1] = r'\hline ' + rows[1]
block = line_end.join(rows)

HTML(markdown2html_pandoc( table_header.format(colordefs=('\\require{action}\n' + colordefs), fmt=format_string, body=block)))
# Out:
# <p><span class="math">\[
# \require{color}
# \require{action}
# \definecolor{2770}{rgb}{0.0,0.0,0.0}
# \definecolor{9113}{rgb}{0.7,0.7,0.7}
# \definecolor{3830}{rgb}{1.0,0.0,0.0}
# \newcommand\T{\Rule{0pt}{1em}{.3em}}
# \begin{array}{c|rrr||||cccc}
# \hline
# \color{2770}{\textrm{class}} &amp; \color{2770}{\mathcal{C}} &amp; \color{2770}{\mathcal{P}} &amp; \color{2770}{\mathcal{T}} &amp; \color{2770}{d=0} &amp; \color{2770}{1} &amp; \color{2770}{2} &amp; \color{2770}{3}\T\\
# \hline \color{2770}{\textrm{A}} &amp; \color{2770}{} &amp; \color{2770}{} &amp; \color{2770}{} &amp; \texttip{\color{3830}{\mathbb{Z}}}{Quantum dot: d=0, no symmetries} &amp; \color{9113}{} &amp; \texttip{\color{3830}{\mathbb{Z}}}{Chern insulator: no symmetries, d=2} &amp; \color{9113}{}\T\\
# \color{2770}{\textrm{AI}} &amp; \color{2770}{} &amp; \color{2770}{} &amp; \color{2770}{1} &amp; \texttip{\color{3830}{\mathbb{Z}}}{Quantum dot: d=0, spinless TRS} &amp; \color{9113}{} &amp; \color{9113}{} &amp; \color{9113}{}\T\\
# \color{2770}{\textrm{AII}} &amp; \color{2770}{} &amp; \color{2770}{} &amp; \color{2770}{-1} &amp; \texttip{\color{3830}{2\mathbb{Z}}}{Quantum dot: d=0, spinful TRS and Kramers degeneracy} &amp; \color{9113}{} &amp; \texttip{\color{3830}{\mathbb{Z}_2}}{QSHE: spinful TRS, d=2} &amp; \texttip{\color{3830}{\mathbb{Z}_2}}{3D strong TI: spinful TRS, d=3}\T\\
# \color{2770}{\textrm{AIII}} &amp; \color{2770}{1} &amp; \color{2770}{} &amp; \color{2770}{} &amp; \color{9113}{} &amp; \texttip{\color{3830}{\mathbb{Z}}}{Polyacetilene/SSH chain: sublattice symmetry, d=1} &amp; \color{9113}{} &amp; \color{9113}{\mathbb{Z}}\T\\
# \color{2770}{\textrm{BDI}} &amp; \color{2770}{1} &amp; \color{2770}{1} &amp; \color{2770}{1} &amp; \color{9113}{\mathbb{Z}_2} &amp; \color{9113}{\mathbb{Z}} &amp; \color{9113}{} &amp; \color{9113}{}\T\\
# \color{2770}{\textrm{C}} &amp; \color{2770}{} &amp; \color{2770}{-1} &amp; \color{2770}{} &amp; \color{9113}{} &amp; \color{9113}{} &amp; \color{9113}{2\mathbb{Z}} &amp; \color{9113}{}\T\\
# \color{2770}{\textrm{CI}} &amp; \color{2770}{1} &amp; \color{2770}{-1} &amp; \color{2770}{1} &amp; \color{9113}{} &amp; \color{9113}{} &amp; \color{9113}{} &amp; \color{9113}{2\mathbb{Z}}\T\\
# \color{2770}{\textrm{CII}} &amp; \color{2770}{1} &amp; \color{2770}{-1} &amp; \color{2770}{-1} &amp; \color{9113}{} &amp; \color{9113}{2\mathbb{Z}} &amp; \color{9113}{} &amp; \color{9113}{\mathbb{Z}_2}\T\\
# \color{2770}{\textrm{D}} &amp; \color{2770}{} &amp; \color{2770}{1} &amp; \color{2770}{} &amp; \texttip{\color{3830}{\mathbb{Z}_2}}{Superconducting quantum dot: d=0, PHS} &amp; \texttip{\color{3830}{\mathbb{Z}_2}}{Majorana wire: spinful particle-hole, d=1} &amp; \texttip{\color{3830}{\mathbb{Z}}}{p-wave superconductor: PHS, d=2} &amp; \color{9113}{}\T\\
# \color{2770}{\textrm{DIII}} &amp; \color{2770}{1} &amp; \color{2770}{1} &amp; \color{2770}{-1} &amp; \color{9113}{} &amp; \color{9113}{\mathbb{Z}_2} &amp; \color{9113}{\mathbb{Z}_2} &amp; \color{9113}{\mathbb{Z}}\\
# \hline
# \end{array}
# \]</span></p>

# %% [markdown]
# # Periodic structure

# %% [markdown]
# ![](figures/bott_clock.png)

# %%
periodic_table, format_string = make_table(n=8, show_symmetries=True, sort_order=None)
rows = [sep.join(line) for line in periodic_table]
rows[1] = r'\hline ' + rows[1]
rows[3] = r'\hline ' + rows[3]
block = line_end.join(rows)
colordefs='{}'
displaymd(table_header.format(colordefs=colordefs, fmt=format_string, body=block))
# Out:
# <p><span class="math">\[
# \require{color}
# {}
# \newcommand\T{\Rule{0pt}{1em}{.3em}}
# \begin{array}{c|rrr||||||||cccccccc}
# \hline
# \textrm{class} &amp; \mathcal{C} &amp; \mathcal{P} &amp; \mathcal{T} &amp; d=0 &amp; 1 &amp; 2 &amp; 3 &amp; 4 &amp; 5 &amp; 6 &amp; 7\T\\
# \hline \textrm{A} &amp;  &amp;  &amp;  &amp; \mathbb{Z} &amp;  &amp; \mathbb{Z} &amp;  &amp; \mathbb{Z} &amp;  &amp; \mathbb{Z} &amp; \T\\
# \textrm{AIII} &amp; 1 &amp;  &amp;  &amp;  &amp; \mathbb{Z} &amp;  &amp; \mathbb{Z} &amp;  &amp; \mathbb{Z} &amp;  &amp; \mathbb{Z}\T\\
# \hline \textrm{AI} &amp;  &amp;  &amp; 1 &amp; \mathbb{Z} &amp;  &amp;  &amp;  &amp; 2\mathbb{Z} &amp;  &amp; \mathbb{Z}_2 &amp; \mathbb{Z}_2\T\\
# \textrm{BDI} &amp; 1 &amp; 1 &amp; 1 &amp; \mathbb{Z}_2 &amp; \mathbb{Z} &amp;  &amp;  &amp;  &amp; 2\mathbb{Z} &amp;  &amp; \mathbb{Z}_2\T\\
# \textrm{D} &amp;  &amp; 1 &amp;  &amp; \mathbb{Z}_2 &amp; \mathbb{Z}_2 &amp; \mathbb{Z} &amp;  &amp;  &amp;  &amp; 2\mathbb{Z} &amp; \T\\
# \textrm{DIII} &amp; 1 &amp; 1 &amp; -1 &amp;  &amp; \mathbb{Z}_2 &amp; \mathbb{Z}_2 &amp; \mathbb{Z} &amp;  &amp;  &amp;  &amp; 2\mathbb{Z}\T\\
# \textrm{AII} &amp;  &amp;  &amp; -1 &amp; 2\mathbb{Z} &amp;  &amp; \mathbb{Z}_2 &amp; \mathbb{Z}_2 &amp; \mathbb{Z} &amp;  &amp;  &amp; \T\\
# \textrm{CII} &amp; 1 &amp; -1 &amp; -1 &amp;  &amp; 2\mathbb{Z} &amp;  &amp; \mathbb{Z}_2 &amp; \mathbb{Z}_2 &amp; \mathbb{Z} &amp;  &amp; \T\\
# \textrm{C} &amp;  &amp; -1 &amp;  &amp;  &amp;  &amp; 2\mathbb{Z} &amp;  &amp; \mathbb{Z}_2 &amp; \mathbb{Z}_2 &amp; \mathbb{Z} &amp; \T\\
# \textrm{CI} &amp; 1 &amp; -1 &amp; 1 &amp;  &amp;  &amp;  &amp; 2\mathbb{Z} &amp;  &amp; \mathbb{Z}_2 &amp; \mathbb{Z}_2 &amp; \mathbb{Z}\\
# \hline
# \end{array}
# \]</span></p>

# %%
n = 8

periodic_table, format_string = make_table(n=n, show_symmetries=True, sort_order=None)
colors = np.zeros(shape=periodic_table.shape+(3,))
colors[1:3, 4:] = [0.8, 0.8, 0.8]
colors[1, 4:] = [1, 0, 0]
colors[2, 4:] = [0, 0, 1]
colordefs = color_table(periodic_table, colors)
rows = [sep.join(line) for line in periodic_table]
rows[1] = r'\hline ' + rows[1]
rows[3] = r'\hline ' + rows[3]
block = line_end.join(rows)
displaymd(table_header.format(colordefs=colordefs, fmt=format_string, body=block))
# Out:
# <p><span class="math">\[
# \require{color}
# \definecolor{27706081}{rgb}{0.0,0.0,1.0}
# \definecolor{27706091}{rgb}{0.0,0.0,0.0}
# \definecolor{38302097}{rgb}{1.0,0.0,0.0}
# \newcommand\T{\Rule{0pt}{1em}{.3em}}
# \begin{array}{c|rrr||||||||cccccccc}
# \hline
# \color{27706091}{\textrm{class}} &amp; \color{27706091}{\mathcal{C}} &amp; \color{27706091}{\mathcal{P}} &amp; \color{27706091}{\mathcal{T}} &amp; \color{27706091}{d=0} &amp; \color{27706091}{1} &amp; \color{27706091}{2} &amp; \color{27706091}{3} &amp; \color{27706091}{4} &amp; \color{27706091}{5} &amp; \color{27706091}{6} &amp; \color{27706091}{7}\T\\
# \hline \color{27706091}{\textrm{A}} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{38302097}{\mathbb{Z}} &amp; \color{38302097}{} &amp; \color{38302097}{\mathbb{Z}} &amp; \color{38302097}{} &amp; \color{38302097}{\mathbb{Z}} &amp; \color{38302097}{} &amp; \color{38302097}{\mathbb{Z}} &amp; \color{38302097}{}\T\\
# \color{27706091}{\textrm{AIII}} &amp; \color{27706091}{1} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706081}{} &amp; \color{27706081}{\mathbb{Z}} &amp; \color{27706081}{} &amp; \color{27706081}{\mathbb{Z}} &amp; \color{27706081}{} &amp; \color{27706081}{\mathbb{Z}} &amp; \color{27706081}{} &amp; \color{27706081}{\mathbb{Z}}\T\\
# \hline \color{27706091}{\textrm{AI}} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{1} &amp; \color{27706091}{\mathbb{Z}} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{2\mathbb{Z}} &amp; \color{27706091}{} &amp; \color{27706091}{\mathbb{Z}_2} &amp; \color{27706091}{\mathbb{Z}_2}\T\\
# \color{27706091}{\textrm{BDI}} &amp; \color{27706091}{1} &amp; \color{27706091}{1} &amp; \color{27706091}{1} &amp; \color{27706091}{\mathbb{Z}_2} &amp; \color{27706091}{\mathbb{Z}} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{2\mathbb{Z}} &amp; \color{27706091}{} &amp; \color{27706091}{\mathbb{Z}_2}\T\\
# \color{27706091}{\textrm{D}} &amp; \color{27706091}{} &amp; \color{27706091}{1} &amp; \color{27706091}{} &amp; \color{27706091}{\mathbb{Z}_2} &amp; \color{27706091}{\mathbb{Z}_2} &amp; \color{27706091}{\mathbb{Z}} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{2\mathbb{Z}} &amp; \color{27706091}{}\T\\
# \color{27706091}{\textrm{DIII}} &amp; \color{27706091}{1} &amp; \color{27706091}{1} &amp; \color{27706091}{-1} &amp; \color{27706091}{} &amp; \color{27706091}{\mathbb{Z}_2} &amp; \color{27706091}{\mathbb{Z}_2} &amp; \color{27706091}{\mathbb{Z}} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{2\mathbb{Z}}\T\\
# \color{27706091}{\textrm{AII}} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{-1} &amp; \color{27706091}{2\mathbb{Z}} &amp; \color{27706091}{} &amp; \color{27706091}{\mathbb{Z}_2} &amp; \color{27706091}{\mathbb{Z}_2} &amp; \color{27706091}{\mathbb{Z}} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{}\T\\
# \color{27706091}{\textrm{CII}} &amp; \color{27706091}{1} &amp; \color{27706091}{-1} &amp; \color{27706091}{-1} &amp; \color{27706091}{} &amp; \color{27706091}{2\mathbb{Z}} &amp; \color{27706091}{} &amp; \color{27706091}{\mathbb{Z}_2} &amp; \color{27706091}{\mathbb{Z}_2} &amp; \color{27706091}{\mathbb{Z}} &amp; \color{27706091}{} &amp; \color{27706091}{}\T\\
# \color{27706091}{\textrm{C}} &amp; \color{27706091}{} &amp; \color{27706091}{-1} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{2\mathbb{Z}} &amp; \color{27706091}{} &amp; \color{27706091}{\mathbb{Z}_2} &amp; \color{27706091}{\mathbb{Z}_2} &amp; \color{27706091}{\mathbb{Z}} &amp; \color{27706091}{}\T\\
# \color{27706091}{\textrm{CI}} &amp; \color{27706091}{1} &amp; \color{27706091}{-1} &amp; \color{27706091}{1} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{2\mathbb{Z}} &amp; \color{27706091}{} &amp; \color{27706091}{\mathbb{Z}_2} &amp; \color{27706091}{\mathbb{Z}_2} &amp; \color{27706091}{\mathbb{Z}}\\
# \hline
# \end{array}
# \]</span></p>

# %%
np.random.seed(15)
n = 8

periodic_table, format_string = make_table(n=n, show_symmetries=True, sort_order=None)
colors = np.zeros(shape=periodic_table.shape+(3,))
colors[1:, 4:] = [0.9, 0.9, 0.9]
palette = np.random.rand(n, 3)**2
colors[primary_seq(n) + 1, np.arange(n) + 4] = 0.8 * palette
colors[z_descendant(n) + 3, np.arange(n) + 4] = 1 - .6 * (1 - palette)
colors[twoz_descendant(n) + 3, np.arange(n) + 4] = 1 - .6 * (1 - palette)
colordefs = color_table(periodic_table, colors)
rows = [sep.join(line) for line in periodic_table]
rows[1] = r'\hline ' + rows[1]
rows[3] = r'\hline ' + rows[3]
block = line_end.join(rows)

displaymd(table_header.format(colordefs=colordefs, fmt=format_string, body=block))
# Out:
# <p><span class="math">\[
# \require{color}
# \definecolor{89033065}{rgb}{0.4,0.42,1.0}
# \definecolor{27706091}{rgb}{0.0,0.0,0.0}
# \definecolor{25452523}{rgb}{0.11,0.46,0.18}
# \definecolor{19406818}{rgb}{0.9,0.9,0.9}
# \definecolor{53381531}{rgb}{0.41,0.6,0.52}
# \definecolor{20809640}{rgb}{0.48,0.75,0.53}
# \definecolor{91941271}{rgb}{0.05,0.67,0.056}
# \definecolor{18492229}{rgb}{0.71,0.85,0.79}
# \definecolor{34025615}{rgb}{0.44,0.91,0.44}
# \definecolor{76578667}{rgb}{0.83,0.42,0.4}
# \definecolor{78063187}{rgb}{0.035,0.022,0.0017}
# \definecolor{89801879}{rgb}{0.1,0.061,0.22}
# \definecolor{83486069}{rgb}{0.58,0.026,0.0024}
# \definecolor{86388062}{rgb}{0.46,0.46,0.41}
# \definecolor{36501247}{rgb}{0.075,0.074,0.01}
# \definecolor{57248277}{rgb}{0.43,0.42,0.4}
# \definecolor{21662774}{rgb}{0.0012,0.032,0.8}
# \definecolor{39167962}{rgb}{0.48,0.45,0.57}
# \newcommand\T{\Rule{0pt}{1em}{.3em}}
# \begin{array}{c|rrr||||||||cccccccc}
# \hline
# \color{27706091}{\textrm{class}} &amp; \color{27706091}{\mathcal{C}} &amp; \color{27706091}{\mathcal{P}} &amp; \color{27706091}{\mathcal{T}} &amp; \color{27706091}{d=0} &amp; \color{27706091}{1} &amp; \color{27706091}{2} &amp; \color{27706091}{3} &amp; \color{27706091}{4} &amp; \color{27706091}{5} &amp; \color{27706091}{6} &amp; \color{27706091}{7}\T\\
# \hline \color{27706091}{\textrm{A}} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{83486069}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{36501247}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{53381531}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{21662774}{\mathbb{Z}} &amp; \color{19406818}{}\T\\
# \color{27706091}{\textrm{AIII}} &amp; \color{27706091}{1} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{19406818}{} &amp; \color{89801879}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{91941271}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{78063187}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{25452523}{\mathbb{Z}}\T\\
# \hline \color{27706091}{\textrm{AI}} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{1} &amp; \color{76578667}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{18492229}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{\mathbb{Z}_2} &amp; \color{19406818}{\mathbb{Z}_2}\T\\
# \color{27706091}{\textrm{BDI}} &amp; \color{27706091}{1} &amp; \color{27706091}{1} &amp; \color{27706091}{1} &amp; \color{19406818}{\mathbb{Z}_2} &amp; \color{39167962}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{57248277}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{\mathbb{Z}_2}\T\\
# \color{27706091}{\textrm{D}} &amp; \color{27706091}{} &amp; \color{27706091}{1} &amp; \color{27706091}{} &amp; \color{19406818}{\mathbb{Z}_2} &amp; \color{19406818}{\mathbb{Z}_2} &amp; \color{86388062}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{89033065}{2\mathbb{Z}} &amp; \color{19406818}{}\T\\
# \color{27706091}{\textrm{DIII}} &amp; \color{27706091}{1} &amp; \color{27706091}{1} &amp; \color{27706091}{-1} &amp; \color{19406818}{} &amp; \color{19406818}{\mathbb{Z}_2} &amp; \color{19406818}{\mathbb{Z}_2} &amp; \color{34025615}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{20809640}{2\mathbb{Z}}\T\\
# \color{27706091}{\textrm{AII}} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{-1} &amp; \color{76578667}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{\mathbb{Z}_2} &amp; \color{19406818}{\mathbb{Z}_2} &amp; \color{18492229}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{}\T\\
# \color{27706091}{\textrm{CII}} &amp; \color{27706091}{1} &amp; \color{27706091}{-1} &amp; \color{27706091}{-1} &amp; \color{19406818}{} &amp; \color{39167962}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{\mathbb{Z}_2} &amp; \color{19406818}{\mathbb{Z}_2} &amp; \color{57248277}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{}\T\\
# \color{27706091}{\textrm{C}} &amp; \color{27706091}{} &amp; \color{27706091}{-1} &amp; \color{27706091}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{86388062}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{\mathbb{Z}_2} &amp; \color{19406818}{\mathbb{Z}_2} &amp; \color{89033065}{\mathbb{Z}} &amp; \color{19406818}{}\T\\
# \color{27706091}{\textrm{CI}} &amp; \color{27706091}{1} &amp; \color{27706091}{-1} &amp; \color{27706091}{1} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{34025615}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{\mathbb{Z}_2} &amp; \color{19406818}{\mathbb{Z}_2} &amp; \color{20809640}{\mathbb{Z}}\\
# \hline
# \end{array}
# \]</span></p>

# %% [markdown]
# # Dimensional reduction

# %%
np.random.seed(4)
n = 8

periodic_table, format_string = make_table(n=8, show_symmetries=True, sort_order=None)
colors = np.zeros(shape=periodic_table.shape+(3,))
colors[1:, 4:] = [0.9, 0.9, 0.9]
palette = np.random.rand(n, 3)
colors[z_descendant(n) + 3, np.arange(n) + 4] = 0.8 * palette
colors[z2_descendant(n-1) + 3, np.arange(n-1) + 4] = 1 - .8 * (1 - palette[1:])
colors[z2_descendant2(n-2) + 3, np.arange(n-2) + 4] = 1 - .5 * (1 - palette[2:])
colordefs = color_table(periodic_table, colors)
rows = [sep.join(line) for line in periodic_table]
rows[1] = r'\hline ' + rows[1]
rows[3] = r'\hline ' + rows[3]
block = line_end.join(rows)

displaymd(table_header.format(colordefs=colordefs, fmt=format_string, body=block))
# Out:
# <p><span class="math">\[
# \require{color}
# \definecolor{25997181}{rgb}{0.57,0.56,0.17}
# \definecolor{21614599}{rgb}{0.76,0.63,0.69}
# \definecolor{49691149}{rgb}{0.48,0.0072,0.31}
# \definecolor{69288897}{rgb}{0.035,0.77,0.35}
# \definecolor{40076655}{rgb}{0.93,0.99,0.58}
# \definecolor{48890877}{rgb}{0.52,0.98,0.72}
# \definecolor{84767404}{rgb}{0.69,0.79,0.13}
# \definecolor{78738988}{rgb}{0.89,0.99,0.33}
# \definecolor{61684838}{rgb}{0.78,0.005,0.2}
# \definecolor{10888569}{rgb}{0.97,0.89,0.93}
# \definecolor{41492878}{rgb}{0.35,0.62,0.16}
# \definecolor{27706091}{rgb}{0.0,0.0,0.0}
# \definecolor{70899120}{rgb}{0.99,0.5,0.63}
# \definecolor{19406818}{rgb}{0.9,0.9,0.9}
# \definecolor{50362546}{rgb}{0.55,0.82,0.36}
# \definecolor{65009656}{rgb}{0.77,0.76,0.37}
# \definecolor{30859423}{rgb}{0.96,0.83,0.89}
# \definecolor{63611382}{rgb}{0.77,0.44,0.78}
# \definecolor{73900905}{rgb}{0.8,0.5,0.69}
# \definecolor{71295686}{rgb}{0.98,0.2,0.4}
# \definecolor{87603991}{rgb}{0.24,0.97,0.55}
# \definecolor{44349757}{rgb}{0.68,0.21,0.51}
# \definecolor{30413410}{rgb}{0.72,0.89,0.6}
# \newcommand\T{\Rule{0pt}{1em}{.3em}}
# \begin{array}{c|rrr||||||||cccccccc}
# \hline
# \color{27706091}{\textrm{class}} &amp; \color{27706091}{\mathcal{C}} &amp; \color{27706091}{\mathcal{P}} &amp; \color{27706091}{\mathcal{T}} &amp; \color{27706091}{d=0} &amp; \color{27706091}{1} &amp; \color{27706091}{2} &amp; \color{27706091}{3} &amp; \color{27706091}{4} &amp; \color{27706091}{5} &amp; \color{27706091}{6} &amp; \color{27706091}{7}\T\\
# \hline \color{27706091}{\textrm{A}} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{19406818}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{\mathbb{Z}} &amp; \color{19406818}{}\T\\
# \color{27706091}{\textrm{AIII}} &amp; \color{27706091}{1} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{19406818}{} &amp; \color{19406818}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{\mathbb{Z}}\T\\
# \hline \color{27706091}{\textrm{AI}} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{1} &amp; \color{63611382}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{\mathbb{Z}_2} &amp; \color{19406818}{\mathbb{Z}_2}\T\\
# \color{27706091}{\textrm{BDI}} &amp; \color{27706091}{1} &amp; \color{27706091}{1} &amp; \color{27706091}{1} &amp; \color{65009656}{\mathbb{Z}_2} &amp; \color{25997181}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{\mathbb{Z}_2}\T\\
# \color{27706091}{\textrm{D}} &amp; \color{27706091}{} &amp; \color{27706091}{1} &amp; \color{27706091}{} &amp; \color{70899120}{\mathbb{Z}_2} &amp; \color{71295686}{\mathbb{Z}_2} &amp; \color{61684838}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{2\mathbb{Z}} &amp; \color{19406818}{}\T\\
# \color{27706091}{\textrm{DIII}} &amp; \color{27706091}{1} &amp; \color{27706091}{1} &amp; \color{27706091}{-1} &amp; \color{19406818}{} &amp; \color{30413410}{\mathbb{Z}_2} &amp; \color{50362546}{\mathbb{Z}_2} &amp; \color{41492878}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{2\mathbb{Z}}\T\\
# \color{27706091}{\textrm{AII}} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{-1} &amp; \color{19406818}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{40076655}{\mathbb{Z}_2} &amp; \color{78738988}{\mathbb{Z}_2} &amp; \color{84767404}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{}\T\\
# \color{27706091}{\textrm{CII}} &amp; \color{27706091}{1} &amp; \color{27706091}{-1} &amp; \color{27706091}{-1} &amp; \color{19406818}{} &amp; \color{19406818}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{73900905}{\mathbb{Z}_2} &amp; \color{44349757}{\mathbb{Z}_2} &amp; \color{49691149}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{}\T\\
# \color{27706091}{\textrm{C}} &amp; \color{27706091}{} &amp; \color{27706091}{-1} &amp; \color{27706091}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{48890877}{\mathbb{Z}_2} &amp; \color{87603991}{\mathbb{Z}_2} &amp; \color{69288897}{\mathbb{Z}} &amp; \color{19406818}{}\T\\
# \color{27706091}{\textrm{CI}} &amp; \color{27706091}{1} &amp; \color{27706091}{-1} &amp; \color{27706091}{1} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{10888569}{\mathbb{Z}_2} &amp; \color{30859423}{\mathbb{Z}_2} &amp; \color{21614599}{\mathbb{Z}}\\
# \hline
# \end{array}
# \]</span></p>

# %%
np.random.seed(5)
n = 8

periodic_table, format_string = make_table(n=8, show_symmetries=True, sort_order=None)
colors = np.zeros(shape=periodic_table.shape+(3,))
colors[1:, 4:] = [0.9, 0.9, 0.9]
palette = np.linspace(.6, 1.2, n).reshape(1, -1, 1) * np.random.rand(5, 1, 3)
palette = np.minimum(palette, 1)
colors[primary_seq(n) + 1, np.arange(n) + 4] = palette[0]
colors[z_descendant(n) + 3, np.arange(n) + 4] = palette[1]
colors[z2_descendant(n) + 3, np.arange(n) + 4] = palette[2]
colors[z2_descendant2(n) + 3, np.arange(n) + 4] = palette[3]
colors[twoz_descendant(n) + 3, np.arange(n) + 4] = palette[4]
colordefs = color_table(periodic_table, colors)
rows = [sep.join(line) for line in periodic_table]
rows[1] = r'\hline ' + rows[1]
rows[3] = r'\hline ' + rows[3]
block = line_end.join(rows)

displaymd(table_header.format(colordefs=colordefs, fmt=format_string, body=block))
# Out:
# <p><span class="math">\[
# \require{color}
# \definecolor{67892480}{rgb}{0.79,0.53,0.31}
# \definecolor{47136939}{rgb}{0.21,0.09,0.82}
# \definecolor{79201964}{rgb}{0.19,0.083,0.76}
# \definecolor{87737412}{rgb}{1.0,0.54,0.68}
# \definecolor{22647681}{rgb}{0.11,0.048,0.44}
# \definecolor{60023283}{rgb}{0.72,0.49,0.28}
# \definecolor{84637407}{rgb}{0.85,0.58,0.33}
# \definecolor{13242353}{rgb}{0.15,0.6,0.14}
# \definecolor{40968303}{rgb}{0.53,0.19,1.0}
# \definecolor{71890971}{rgb}{0.13,0.52,0.12}
# \definecolor{47303403}{rgb}{0.94,0.5,0.63}
# \definecolor{15648970}{rgb}{0.25,0.97,0.23}
# \definecolor{54414142}{rgb}{0.26,0.095,0.53}
# \definecolor{26798665}{rgb}{0.23,0.9,0.21}
# \definecolor{73847896}{rgb}{0.16,0.069,0.63}
# \definecolor{90699732}{rgb}{0.46,0.31,0.18}
# \definecolor{27309198}{rgb}{0.17,0.67,0.16}
# \definecolor{19138633}{rgb}{0.23,0.097,0.89}
# \definecolor{30260001}{rgb}{0.18,0.076,0.7}
# \definecolor{27706091}{rgb}{0.0,0.0,0.0}
# \definecolor{65128102}{rgb}{0.53,0.36,0.2}
# \definecolor{43419335}{rgb}{0.66,0.44,0.25}
# \definecolor{19406818}{rgb}{0.9,0.9,0.9}
# \definecolor{14653313}{rgb}{1.0,0.59,0.73}
# \definecolor{54370601}{rgb}{0.45,0.16,0.91}
# \definecolor{40087173}{rgb}{0.63,0.33,0.42}
# \definecolor{39309900}{rgb}{0.49,0.18,0.98}
# \definecolor{69504151}{rgb}{0.27,1.0,0.25}
# \definecolor{14801342}{rgb}{0.42,0.15,0.83}
# \definecolor{36590461}{rgb}{0.13,0.055,0.51}
# \definecolor{70521939}{rgb}{0.92,0.62,0.36}
# \definecolor{81565492}{rgb}{0.79,0.42,0.52}
# \definecolor{67038529}{rgb}{0.87,0.46,0.58}
# \definecolor{38190667}{rgb}{0.34,0.12,0.68}
# \definecolor{88628693}{rgb}{0.71,0.38,0.47}
# \definecolor{72403654}{rgb}{0.38,0.14,0.75}
# \definecolor{47314099}{rgb}{0.59,0.4,0.23}
# \definecolor{21800970}{rgb}{0.3,0.11,0.6}
# \definecolor{47519986}{rgb}{0.55,0.29,0.37}
# \definecolor{94758974}{rgb}{0.14,0.062,0.57}
# \definecolor{11908221}{rgb}{0.19,0.75,0.18}
# \definecolor{36017108}{rgb}{0.21,0.82,0.19}
# \newcommand\T{\Rule{0pt}{1em}{.3em}}
# \begin{array}{c|rrr||||||||cccccccc}
# \hline
# \color{27706091}{\textrm{class}} &amp; \color{27706091}{\mathcal{C}} &amp; \color{27706091}{\mathcal{P}} &amp; \color{27706091}{\mathcal{T}} &amp; \color{27706091}{d=0} &amp; \color{27706091}{1} &amp; \color{27706091}{2} &amp; \color{27706091}{3} &amp; \color{27706091}{4} &amp; \color{27706091}{5} &amp; \color{27706091}{6} &amp; \color{27706091}{7}\T\\
# \hline \color{27706091}{\textrm{A}} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{71890971}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{27309198}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{36017108}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{15648970}{\mathbb{Z}} &amp; \color{19406818}{}\T\\
# \color{27706091}{\textrm{AIII}} &amp; \color{27706091}{1} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{19406818}{} &amp; \color{13242353}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{11908221}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{26798665}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{69504151}{\mathbb{Z}}\T\\
# \hline \color{27706091}{\textrm{AI}} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{1} &amp; \color{47519986}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{14801342}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{47136939}{\mathbb{Z}_2} &amp; \color{70521939}{\mathbb{Z}_2}\T\\
# \color{27706091}{\textrm{BDI}} &amp; \color{27706091}{1} &amp; \color{27706091}{1} &amp; \color{27706091}{1} &amp; \color{90699732}{\mathbb{Z}_2} &amp; \color{40087173}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{54370601}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19138633}{\mathbb{Z}_2}\T\\
# \color{27706091}{\textrm{D}} &amp; \color{27706091}{} &amp; \color{27706091}{1} &amp; \color{27706091}{} &amp; \color{22647681}{\mathbb{Z}_2} &amp; \color{65128102}{\mathbb{Z}_2} &amp; \color{88628693}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{39309900}{2\mathbb{Z}} &amp; \color{19406818}{}\T\\
# \color{27706091}{\textrm{DIII}} &amp; \color{27706091}{1} &amp; \color{27706091}{1} &amp; \color{27706091}{-1} &amp; \color{19406818}{} &amp; \color{36590461}{\mathbb{Z}_2} &amp; \color{47314099}{\mathbb{Z}_2} &amp; \color{81565492}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{40968303}{2\mathbb{Z}}\T\\
# \color{27706091}{\textrm{AII}} &amp; \color{27706091}{} &amp; \color{27706091}{} &amp; \color{27706091}{-1} &amp; \color{54414142}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{94758974}{\mathbb{Z}_2} &amp; \color{43419335}{\mathbb{Z}_2} &amp; \color{67038529}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{}\T\\
# \color{27706091}{\textrm{CII}} &amp; \color{27706091}{1} &amp; \color{27706091}{-1} &amp; \color{27706091}{-1} &amp; \color{19406818}{} &amp; \color{21800970}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{73847896}{\mathbb{Z}_2} &amp; \color{60023283}{\mathbb{Z}_2} &amp; \color{47303403}{\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{19406818}{}\T\\
# \color{27706091}{\textrm{C}} &amp; \color{27706091}{} &amp; \color{27706091}{-1} &amp; \color{27706091}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{38190667}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{30260001}{\mathbb{Z}_2} &amp; \color{67892480}{\mathbb{Z}_2} &amp; \color{87737412}{\mathbb{Z}} &amp; \color{19406818}{}\T\\
# \color{27706091}{\textrm{CI}} &amp; \color{27706091}{1} &amp; \color{27706091}{-1} &amp; \color{27706091}{1} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{19406818}{} &amp; \color{72403654}{2\mathbb{Z}} &amp; \color{19406818}{} &amp; \color{79201964}{\mathbb{Z}_2} &amp; \color{84637407}{\mathbb{Z}_2} &amp; \color{14653313}{\mathbb{Z}}\\
# \hline
# \end{array}
# \]</span></p>

# %% [markdown]
# # Conclusions

# %%
MoocVideo("", src_location="8.1-summary")

# %% [markdown]
# Questions about what you just learned? Ask them below!

# %%
MoocDiscussion("Questions", "Periodic table")
# Out:
# MoocDiscussion(**{'discussion_category': 'Questions', 'discussion_target': 'Periodic table', 'display_name': 'Periodic table', 'discussion_id': 'a673e4cfbe6926ff2c727e2b890b04ba'})
