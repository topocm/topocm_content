# %%
# %run ../code/init_mooc_nb.ipy

import scipy as sc
randn = np.random.randn

sigma0 = np.array([[1, 0], [0, 1]])
sigmax = np.array([[0, 1], [1, 0]])
sigmay = np.array([[0, -1j], [1j, 0]])
sigmaz = np.array([[1, 0], [0, -1]])

class SimpleNamespace(object):
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)

        
def chern_torus(w=5, l=5):
    
    disorder_potential = randn(w, l)
    
    def shape(pos):
        (x, y) = pos
        return (0 <= x < w) * (0 <= y < l)
    
    def onsite(site, par):
        t, mu, dis_amplitude = par.t, par.mu, par.disorder
        (x, y) = site.pos
        return (4 * t - mu) * sigmaz #+ dis_amplitude * disorder_potential[x, y] * sigma0
    
    def hopx(site1, site2, par):
        t, delta = par.t, par.delta
        return -t * sigmaz + 1j * par.delta * sigmax

    def hopy(site1, site2, par):
        t, delta = par.t, par.delta
        return -t * sigmaz - 1j * par.delta * sigmay
    
    lat = kwant.lattice.square()
    sys = kwant.Builder()
    sys[lat.shape(shape, (0, 0))] = onsite
    sys[kwant.HoppingKind((1, 0), lat)] = hopx
    sys[kwant.HoppingKind((0, 1), lat)] = hopy
    sys[kwant.HoppingKind((-w+1, 0), lat)] = hopx
    sys[kwant.HoppingKind((0, -l+1), lat)] = hopy
    return sys.finalized()

def projected_operators(sys, par):
    pos = np.array([sys.pos(i) for i in range(sys.graph.num_nodes)])
    x, y = pos.T
    # Double all entries to take orbitals into account.
    x = np.resize(x, (2, len(x))).T.flatten()
    y = np.resize(y, (2, len(y))).T.flatten()
    x *= 2 * np.pi / (np.max(x) + 1)
    y *= 2 * np.pi / (np.max(y) + 1)
    op_x = np.diag(np.exp(1j * x))
    op_y = np.diag(np.exp(1j * y))

    ham = sys.hamiltonian_submatrix(args = [par,])
    ham -= 0 * np.identity(len(ham))
    energies, states = np.linalg.eigh(ham)
    
    #gap_cutoff=1.01e-7
    #if min(abs(energies)) < gap_cutoff:
    #    print('Warning: The system might not be gapped (gap $ < $' + scientific_number(gap_cutoff) + ')')
    
    projector = states[:, energies < 0]

    op_x = projector.T.conj().dot(op_x).dot(projector)
    op_y = projector.T.conj().dot(op_y).dot(projector)
    return op_x, op_y

def evaluate_m(op_x, op_y):
    temp = op_x.dot(op_y).dot(op_x.T.conj()).dot(op_y.T.conj())
    eigs = np.linalg.eigvals(temp)
    #get rid of the four zero eigenvalues
    res = np.sum(np.log(eigs))
    res = np.imag(res)/(2 * np.pi)
    #This calculation is only correct to numerical accuracy.
    #When the Chern number is zero the result might be a very small negative number. 
    #We make them positive so that the out put is never -0, because that does not look nice.
    if abs(res)<0.5:
        res=abs(res)
    fig = plt.figure(figsize=(4, 3.5))
    ax = fig.add_subplot(111)
    xs = np.real(np.cumsum(np.log(eigs)))
    ys = np.imag(np.cumsum(np.log(eigs)))
    x = [0]
    for x0 in xs:
        x.append(x0)
    x = np.array(x)
    y = [0]
    for y0 in ys:
        y.append(y0)
    y = np.array(y)
    window_widening = (max(x)-min(x)) * 0.05
    ax.plot(x, y, 'b-')
    ax.plot(x, y, 'bo')
    ax.set_title('$\mu = %1.2f$, Chern number $=%1.0f$' %(par.mu, res))
    ax.set_ylim(-2 * np.pi -0.5, 0.5)
    ax.set_xlim(min(x)-window_widening, max(x)+window_widening)
    ax.set_yticks([-2*np.pi, 0.0])
    ax.set_xticks([min(x), max(x)])
    ax.set_yticklabels(['$-2\pi$', '$0$'])
    return fig
# Out:
# Performing the necessary imports.
#
# from __future__ import division, print_function
# import numpy as np
# import matplotlib
# import kwant
#
# import ipywidgets
# from IPython.html.widgets import interact
# from ipywidgets import StaticInteract, RangeWidget, DropDownWidget
# from IPython.display import display_html
# from matplotlib import pyplot as plt
#
# import pfaffian as pf
# from edx_components import *
# <script type=text/javascript>
# /* Add a button for showing or hiding input */
# on = "Show input";
# off = "Hide input";
# function onoff(){
#   currentvalue = document.getElementById('onoff').value;
#   if(currentvalue == off){
#     document.getElementById("onoff").value=on;
#       $('div.input').hide();
#   }else{
#     document.getElementById("onoff").value=off;
#       $('div.input').show();
#   }
# }
#
# /* Launch first notebook cell on start */
# function launch_first_cell (evt) {
#   if (!launch_first_cell.executed
#       && IPython.notebook.kernel
#   ) {
# ...

# %% [markdown]
# #Table of Contents
# * [Introduction](#Introduction)
# * [What good are topological invariants](#What-good-are-topological-invariants)
# * [Disorder](#Disorder)
# * [The costs of every operation](#The-costs-of-every-operation)
# * [A special thing about 1D](#A-special-thing-about-1D)
# * [Differences between approaches](#Differences-between-approaches)
# * [Conclusions](#Conclusions)

# %% [markdown]
# **No content above this line is visible in edX**

# %% [markdown]
# # Introduction

# %% [markdown]
# Fabian Hassler from RWTH Aachen will present the topological invariants

# %%
MoocVideo("ceyus0cRBi0", src_location="8.2-intro")
# Out:
# MoocVideo(**{'download_video': 'true', 'display_name': '', 'sub': 'ceyus0cRBi0', 'youtube': '1.00:ceyus0cRBi0', 'show_captions': 'true', 'youtube_id_1_0': 'ceyus0cRBi0', 'source': 'http://delftxdownloads.tudelft.nl/TOPOCMx-QuantumKnots/TOPOCMx-8.2-intro-video.720.mp4', 'download_track': 'true'})

# %% [markdown]
# # What good are topological invariants

# %% [markdown]
# Throughout the course you saw us compute a topological invariant. Let's think what purpose they serve.

# %% [markdown]
# # Disorder

# %%
par = SimpleNamespace(t=1.0, mu=0.1, delta=0.1, disorder=0.5)
sys = chern_torus(12, 12)

def show_results(mu, args):
    args.mu = mu
    op_x, op_y = projected_operators(sys, par)
    return evaluate_m(op_x, op_y)
    
StaticInteract(lambda mu: show_results(mu=mu*0.05-1e-5, args=par), mu=RangeWidget(-2, 10))
# Out:
#     <script type="text/javascript">
#       var mergeNodes = function(a, b) {
#         return [].slice.call(a).concat([].slice.call(b));
#       }; // http://stackoverflow.com/questions/914783/javascript-nodelist/17262552#17262552
#       function interactUpdate(div){
#          var outputs = div.getElementsByTagName("div");
#          //var controls = div.getElementsByTagName("input");
#          var controls = mergeNodes(div.getElementsByTagName("input"), div.getElementsByTagName("select"));
#          function nameCompare(a,b) {
#             return a.getAttribute("name").localeCompare(b.getAttribute("name"));
#          }
#          controls.sort(nameCompare);
#
#          var value = "";
#          for(i=0; i<controls.length; i++){
#            if((controls[i].type == "range") || controls[i].checked){
#              value = value + controls[i].getAttribute("name") + controls[i].value;
#            }
#            if(controls[i].type == "select-one"){
# ...

# %% [markdown]
# This algorythm works for a two dimensional system with periodic boundary conditions, so you can imagine it as a torus. The algorythm works like this: We start by diagonalizing the Hamiltonian. When we have the complete eigensystem of the Hamiltonian we can construct an operator $P$ that projects onto the states with negative eigenvalue. So basically we are projecting on the filled states. Then we use this operator $P$ to project the operators $e^{i\Theta}$ and $e^{i\Phi}$ onto the filled states. $\Theta$ and $\Phi$ are the position on the torus in terms of angles. We define
#
# $Pe^{i\Theta}P = \left( \begin{array}{cc} 0 & 0 \\ 0 & U \end{array} \right)$
#
# and
#
# $Pe^{i\Phi}P = \left( \begin{array}{cc} 0 & 0 \\ 0 & V \end{array} \right)$.
#
# The Chern number $m$ can then be calculated from:
#
# $ \text{tr}\left(\log\left(UVU^\dagger V^\dagger\right)\right) = 2\pi i \text{ } m + r .$
#
# In that equation, you can already see, that $m$ is always an integer, because $\text{tr}(\log(O)) = \log(\det(O)),$ for any $O$ and the determinant $\det(UVU^\dagger V^\dagger)=\det(U)\det^*(U)\det(V)\det^*(V)$ must be real.
#
# We have a plot of the cummulative sum of the logarythms of the eigenvalues of $UVU^\dagger V^\dagger$ in the complex plane. In our system you can see the Chern number change at $\mu = 0$.

# %% [markdown]
# # The costs of every operation

# %% [markdown]
# # A special thing about 1D

# %% [markdown]
# You might remember studying the SSH chain back in week one. This is a similar system to the Majorana chain, but it is characterized by chiral symmetry rather than particle-hole symmetry.
#
# A 1D Bloch Hamiltonian $H(k)$ with chiral symmetry has the form
#
# $$
# H(k) = \begin{pmatrix} 0 & h(k) \\
# h^\dagger(k) & 0\end{pmatrix}
# $$
#
# with $h(k) = h_0 + t_L e^{ik} + t_R e^{-ik}$ a matrix containing the onsite term $h_0$, the left hopping $t_L$ and the right hopping $t_R$.
#
# If you look up the table, this Hamiltonian is characterized by a $\mathbb{Z}$ topological invariant. What is this invariant?
#
# We need to find an integer quantity which can only change as long as the gap of $H(k)$ closes. Now, $H(k)$ can only have a zero eigenvalue if $h(k)$ does, that is if $\det [h(k)]=0$. For a gapped Hamiltonian $\det [h(k)]$ will in general be a complex number other than zero for, all values of $k$ in $[0,2\pi]$.
#
# Let us now try to picure the path that $h(k)$ does in the complex plane as $k$ is varied from $0$ to $2\pi$. This path must be closed, because $\det [h(0)]$ must be equal to $\det [h(2\pi)]$, and avoid the origin. We may therefore ask: how many times does the path do around the origin? This number must be integer, and it cannot change unless we make the path go through zero. It is our $\mathbb{Z}$ topological invariant, because we can distinguish a clockwise path from an counterclockwise path, and it is known as the [winding number](http://en.wikipedia.org/wiki/Winding_number).
#
# Its mathematical expression is more obscure than its meaning:
#
# $$
# Q(H) = \frac{1}{2\pi i}\,\int_0^{2\pi} dk\,\frac{d}{dk}\,\log\,\det[h(k)]
# $$
#
# There is however a neat way to compute $Q(H)$ without passing through this integral.
#
# As $k$ varies from $0$ to $\pi$, $e^{ik}$ goes around the unit circle in the complex plane. Let's now make a substitution $e^{ik}\,\to\,z$, with $z$ a complex number. The determinant $\det[h(k)]$ becomes a polynomial function in $z$, $f(z) = \det[h_0 + z\, t_L + z^{-1}\, t_R]$. We now need to compute the following integral on the unit circle
#
# $$
# Q(H) = \frac{1}{2\pi i}\,\oint dz \,\frac{d}{dz} \log f(z) = \frac{1}{2\pi i}\,\oint\,dz\,\frac{f'(z)}{f(z)}
# $$
#
# We can now use a nice result from complex analysis, the [argument principle](http://en.wikipedia.org/wiki/Argument_principle). it tells us that each zero of $f(z)$ inside the unit circle contributes $+1$ to the value of $Q(H)$, and each zero contributes $-1$. Hence by counting the number of zeros and poles of $f(z)$ inside the unit circle we immediately get the winding number. Hence we have reduced the calculation of the topological invariant to the solution of the eigenproblem, $\det[h_0 + z\, t_L + z^{-1}\, t_R]=0$.

# %%
def random_sys(N=4):
    
    H0 = randn(N, N)
    H0j = 1j * randn(N, N)
    onsite = H0 + H0j
    
    t = randn(N, N)
    tj = 1j * randn(N, N)
    lefthopping = t + tj

    t = randn(N, N)
    tj = 1j * randn(N, N)
    righthopping = t + tj
    
    return onsite, lefthopping, righthopping

def find_singularities(onsite, lefthopping, righthopping):
    # We will have a generalized eigenvalue problem. The two matrices alone do not have much of a physical meaning, 
    # so their names are also meaningless: mat1, mat2. 
    n = len(onsite)
    # create the matrices with the correct shape (and data type complex. Yes, suddenly python cares about data types). 
    #At this point their entries are not correct yet.
    mat1 = np.identity(2 * n, dtype=complex)
    mat2 = np.identity(2 * n, dtype=complex)
    #Set correct entries
    mat1[:n, :n] = onsite
    mat1[:n, n:] = np.identity(n, dtype=complex)
    mat1[n:, :n] = lefthopping
    mat1[n:, n:] = 0.0
    
    mat2[:n, :n] = -righthopping
    
    eigs = sc.linalg.eigvals(mat2, mat1)
    eigs = eigs[abs(eigs)<1.0]
    return eigs

def winding_plot(onsite, lefthopping, righthopping):
    singularities = find_singularities(onsite, lefthopping, righthopping)
    winding = len(singularities) - len(onsite)
    
    aux = np.exp(1j * np.linspace(-np.pi, np.pi, 30))
    fig = plt.figure(figsize=(4, 3.5))
    ax = fig.add_subplot(111)
    ax.plot(np.real(singularities), np.imag(singularities), 'ro')
    ax.plot([0],[0], 'bo')
    ax.plot(np.real(aux), np.imag(aux), 'k--')
    ax.set_title('Winding number: $%1.0f$' % winding)
    ax.set_xlim([-1, 1])
    ax.set_ylim([-1, 1])
    ax.set_xticks([-1, 0, 1])
    ax.set_yticks([-1, 0, 1])
    ax.set_xticklabels(['$-1$', '$0$', '$1$'])
    ax.set_yticklabels(['$-i$', '$0$', '$i$'])
    return fig

# %%
np.random.seed(30)
onsite, lefthopping, righthopping = random_sys()
StaticInteract(lambda scale: winding_plot(4 * onsite * 1.2**-abs(scale), lefthopping * 1.2**scale, righthopping * 1.2**-scale), 
                scale=RangeWidget(-10, 10, default=0))
# Out:
#     <script type="text/javascript">
#       var mergeNodes = function(a, b) {
#         return [].slice.call(a).concat([].slice.call(b));
#       }; // http://stackoverflow.com/questions/914783/javascript-nodelist/17262552#17262552
#       function interactUpdate(div){
#          var outputs = div.getElementsByTagName("div");
#          //var controls = div.getElementsByTagName("input");
#          var controls = mergeNodes(div.getElementsByTagName("input"), div.getElementsByTagName("select"));
#          function nameCompare(a,b) {
#             return a.getAttribute("name").localeCompare(b.getAttribute("name"));
#          }
#          controls.sort(nameCompare);
#
#          var value = "";
#          for(i=0; i<controls.length; i++){
#            if((controls[i].type == "range") || controls[i].checked){
#              value = value + controls[i].getAttribute("name") + controls[i].value;
#            }
#            if(controls[i].type == "select-one"){
# ...

# %% [markdown]
# In the graph above you see the values of $z$, where $f(z)$ has singularities in the complex plain. We show the singularities inside the unit circle. The scaling changes the amplitudes of the onsite term, the left- and the right hopping. When the slider is all the way on the left, the left hopping dominates the Hamiltonian, in the middle the onsite term dominates and on the right the right hopping dominates.

# %% [markdown]
# # Differences between approaches

# %% [markdown]
# # Conclusions

# %%
MoocVideo("9qCSXEfSlqE", src_location="8.2-summary")
# Out:
# MoocVideo(**{'download_video': 'true', 'display_name': '', 'sub': '9qCSXEfSlqE', 'youtube': '1.00:9qCSXEfSlqE', 'show_captions': 'true', 'youtube_id_1_0': '9qCSXEfSlqE', 'source': 'http://delftxdownloads.tudelft.nl/TOPOCMx-QuantumKnots/TOPOCMx-8.2-summary-video.720.mp4', 'download_track': 'true'})

# %% [markdown]
# Questions about what you just learned? Ask them below!

# %%
MoocDiscussion("Questions", "Topological invariants")
