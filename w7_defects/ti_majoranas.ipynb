# %%
# %run ../code/init_mooc_nb.ipy

import scipy.sparse.linalg as sl
import tinyarray as ta

sigma0 = np.array([[1, 0], [0, 1]])
sigmax = np.array([[0, 1], [1, 0]])
sigmay = np.array([[0, -1j], [1j, 0]])
sigmaz = np.array([[1, 0], [0, -1]])


my = np.kron(sigmay,0.5*(sigma0+sigmaz))
s0s0sz = ta.array(np.kron(np.kron(sigma0, sigma0), sigmaz))
s0szsz = ta.array(np.kron(np.kron(sigma0, sigmaz), sigmaz))
mysz = ta.array(np.kron(my, sigma0))
s0s0sx = ta.array(np.kron(np.kron(sigma0, sigma0), sigmax))
s0s0sy = ta.array(np.kron(np.kron(sigma0, sigma0), sigmay))
szsxsz = ta.array(np.kron(np.kron(sigmaz, sigmax), sigmaz))
s0sysz = ta.array(np.kron(np.kron(sigma0, sigmay), sigmaz))
sxsxsz = ta.array(np.kron(np.kron(sigmax, sigmax), sigmaz))
sysxsz = ta.array(np.kron(np.kron(sigmay, sigmax), sigmaz))

class SimpleNamespace(object):
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)


def make_qshe_sc(l=40, w=10, lead=False):
    def shape(pos):
        (x, y) = pos
        return (1.0 * y**2 / l**2 + 1.0 * x**2 / w**2) <= 0.25
    
    def onsite(site, par):
        (x, y) = site.pos
        A, B, D, M = par.A/2, par.B, par.D, par.M
        return (M - 4 * B) * s0szsz - 4 * D * s0s0sz + par.gaps(x, y)[1] * mysz + par.gaps(x, y)[0] * s0s0sx

    def hopx(site1, site2, par):
        A, B, D, M = par.A/2, par.B, par.D, par.M
        return B * s0szsz + D * s0s0sz + 1j * A * szsxsz

    def hopy(site1, site2, par):
        A, B, D, M = par.A/2, par.B, par.D, par.M
        return B * s0szsz + D * s0s0sz - 1j * A * s0sysz
    
    lat = kwant.lattice.square()
    sys = kwant.Builder()
    sys[lat.shape(shape, (0, 0))] = onsite
    sys[kwant.HoppingKind((1, 0), lat)] = hopx
    sys[kwant.HoppingKind((0, 1), lat)] = hopy
    
    if lead:
        sym = kwant.TranslationalSymmetry((0, 1))
        lead = kwant.Builder(sym)
        lead[lat(0, 0)] = 1.5 * par.B * np.kron(np.kron(sigma0, sigmaz), sigmaz)
        lead[kwant.HoppingKind((0, 1), lat)] = -par.B * np.kron(np.kron(sigma0, sigmaz), sigmaz)
        sys.attach_lead(lead)        
        sys.attach_lead(lead.reversed())
    return sys.finalized()


def make_qshe_sc_ribbon(w=3):
    def ribbon_shape(pos):
        (x, y) = pos
        return (0 <= x < w)
    
    def onsite(site, par):
        (x, y) = site.pos
        A, B, D, M = par.A/2, par.B, par.D, par.M
        return (M - 4 * B) * s0szsz - 4 * D * s0s0sz + par.gaps(x, y)[1] * mysz + par.gaps(x, y)[0] * s0s0sx

    def hopx(site1, site2, par):
        A, B, D, M = par.A/2, par.B, par.D, par.M
        return B * s0szsz + D * s0s0sz + 1j * A * szsxsz

    def hopy(site1, site2, par):
        A, B, D, M = par.A/2, par.B, par.D, par.M
        return B * s0szsz + D * s0s0sz - 1j * A * s0sysz
    
    
    lat = kwant.lattice.square()
    sym = kwant.TranslationalSymmetry((0, 1))
    sys = kwant.Builder(sym)

    
    sys[lat.shape(ribbon_shape, (0, 0))] = onsite
    sys[kwant.HoppingKind((1,0), lat)] = hopx
    sys[kwant.HoppingKind((0,1), lat)] = hopy
    
    return sys.finalized()

def make_2d_pwave(w, l):
    def shape(pos):
        (x, y) = pos
        return (1.0 * y**2 / l**2 + 1.0 * x**2 / w**2) <= 0.25
    
    def hopx(site1, site2, par):
        (x1, y1) = site1.pos
        (x2, y2) = site2.pos
        phi = par.phase(0.5 * (x1 + x2), 0.5 * (y1 + y2))
        return -par.t * sigmaz + 1j * par.delta * \
                (np.cos(phi) * sigmax + np.sin(phi) * sigmay)
    
    def hopy(site1, site2, par):
        (x1, y1) = site1.pos
        (x2, y2) = site2.pos
        phi = par.phase(0.5 * (x1 + x2), 0.5 * (y1 + y2))
        return -par.t * sigmaz - 1j * par.delta * \
                (np.cos(np.pi/2 + phi) * sigmax + np.sin(np.pi/2 + phi) * sigmay)
    
    def onsite(site1, par):
        return (4 * par.t - par.mu) * sigmaz 
    
    lat = kwant.lattice.square()
    sys = kwant.Builder()
    sys[lat.shape(shape, (w/2 - 1, 0))] = onsite
    sys[kwant.HoppingKind((1, 0), lat)] = hopx
    sys[kwant.HoppingKind((0, 1), lat)] = hopy
    
    return sys.finalized()

def bhz_slab(l, w, h):
    lat = kwant.lattice.general(np.identity(3))
    sys = kwant.Builder()
    
    def shape(pos):
        (x, y, z) = pos
        return (0 <= z < h) and (1.0 * y**2 / l**2 + 1.0 * x**2 / w**2) <= 0.25
    
    def onsite(site, par):
        A1, A2, B1, B2, D1, D2, C, M, delta = par.A1, par.A2, par.B1, par.B2, par.D1, par.D2, par.C, par.M, par.delta
        (x, y, z) = site.pos
        phi = par.phase(x, y)
        return (C + 2 * D1 + 4 * D2) * s0s0sz + (M + 2 * B1 + 4 * B2) * s0szsz + \
                delta * (np.cos(phi) * s0s0sx + np.sin(phi) * s0s0sy)

    def hopx(site1, site2, par):
        A1, A2, B1, B2, D1, D2, C, M = par.A1, par.A2, par.B1, par.B2, par.D1, par.D2, par.C, par.M
        return - D2 * s0s0sz - B2 * s0szsz + A2 * 0.5j * sxsxsz

    def hopy(site1, site2, par):
        A1, A2, B1, B2, D1, D2, C, M = par.A1, par.A2, par.B1, par.B2, par.D1, par.D2, par.C, par.M
        return - D2 * s0s0sz - B2 * s0szsz + A2 * 0.5j * sysxsz

    def hopz(site1, site2, par):
        A1, A2, B1, B2, D1, D2, C, M = par.A1, par.A2, par.B1, par.B2, par.D1, par.D2, par.C, par.M
        return - D1 * s0s0sz - B1 * s0szsz + A1 * 0.5j * szsxsz

    sys[lat.shape(shape, (0,0,0))] = lambda site, par: onsite(site, par) 
    sys[kwant.HoppingKind((1,0,0), lat)] = lambda site1, site2, par: hopx(site1, site2, par)
    sys[kwant.HoppingKind((0,1,0), lat)] = lambda site1, site2, par: hopy(site1, site2, par)
    sys[kwant.HoppingKind((0,0,1), lat)] = lambda site1, site2, par: hopz(site1, site2, par)
        
    return sys.finalized()
# Out:
# Performing the necessary imports.
#
# from __future__ import division, print_function
# import numpy as np
# import matplotlib
# import kwant
#
# import ipywidgets
# from IPython.html.widgets import interact
# from ipywidgets import StaticInteract, RangeWidget, DropDownWidget
# from IPython.display import display_html
# from matplotlib import pyplot as plt
#
# import pfaffian as pf
# from edx_components import *
# <script type=text/javascript>
# /* Add a button for showing or hiding input */
# on = "Show input";
# off = "Hide input";
# function onoff(){
#   currentvalue = document.getElementById('onoff').value;
#   if(currentvalue == off){
#     document.getElementById("onoff").value=on;
#       $('div.input').hide();
#   }else{
#     document.getElementById("onoff").value=off;
#       $('div.input').show();
#   }
# }
#
# /* Launch first notebook cell on start */
# function launch_first_cell (evt) {
#   if (!launch_first_cell.executed
#       && IPython.notebook.kernel
#   ) {
#     IPython.notebook.get_cells()[0].execute();
#     launch_first_cell.executed = true;
#   }
# }
#
# $([IPython.events]).on('status_started.Kernel notebook_loaded.Notebook', launch_first_cell);
# </script>
#
# <p>Press this button to show/hide the code used in the notebook:
# <input type="button" class="ui-button ui-widget ui-state-default ui-corner-all ui-button-text-only" value="Hide input" id="onoff" onclick="onoff();"></p>
# <script type=text/javascript>
# $(document).ready(function (){if(!("IPython" in window)){onoff();}})
# </script>

# %% [markdown]
# #Table of Contents
# * [Introduction](#Introduction)
# * [Different types of bulk-edge correspondence](#Different-types-of-bulk-edge-correspondence)
# * [Turning the helical edge into a topological superconductor](#Turning-the-helical-edge-into-a-topological-superconductor)
# * [Vortices in topological superconductors](#Vortices-in-topological-superconductors)
# * [Vortices in 3D topological insulator](#Vortices-in-3D-topological-insulator)
# * [Conclusions](#Conclusions)

# %% [markdown]
# # Introduction

# %% [markdown]
# # Different types of bulk-edge correspondence

# %% [markdown]
# # Turning the helical edge into a topological superconductor

# %% [markdown]
# In the past weeks, we have studied two systems in appearance very different, but where topology showed up in a very similar way.
#
# First, let's consider the quantum spin-Hall insulator. As we saw two weeks ago, it is characterized by a fermion parity pump: if you take a Corbino disk made out of a quantum spin-Hall insulator and change the flux by half of a normal flux quantum, that is by $h/2e$, one unit of fermion parity is transferred from one edge to the other of the sample.
#
# Let's now consider a one-dimensional topological superconductor, that we studied in week two and three. There, we saw that if such a system is closed into a Josephson ring, and the flux through the ring is advanced by one superconducting quantum $h/2e$, the fermion parity at the Josephson junction connecting the two ends changes from even to odd, or viceversa. This is the $4π$ Josephson effect, one of the main signatures of topological superconductivity.
#
# Note that the necessary flux is equal to $h/2e$ in both cases, since a superconducting flux quantum $h/2e$ is half of the normal quantum $h/e$.
#
# This suggest that once you have a quantum-spin Hall insulator, you are only one small step away from topological superconductivity and Majoranas. The only ingredient that is missing is to introduce superconducting pairing on the quantum spin-Hall edge.
#
# But this is easy to add, for instance by putting a superconductor on top of the outer edge of our quantum spin-Hall Corbino disk:

# %% [markdown]
# ![](figures/qsh_josephson_ring.png)

# %% [markdown]
# The superconductor covers the entire quantum spin-Hall edge except for a small segment, which acts as a Josephson junction with a phase difference given by $\phi = 2e\Phi/\hbar$.  We imagine that the superconductor gaps out the helical edge by proximity, meaning that Cooper pair can tunnel in and out from the superconductor into the edge. As we will soon see in detail, in order for this to happen a conventional $s$-wave superconductor is enough.
#
# Let's not do our pumping experiment again, increasing the flux $\Phi$ through the ring by $h/2e$. We know that one unit of fermion parity must be transferred from the inner edge of the disk to the outer edge. However, the only place where we can find a zero-energy state is now the Josephson junction, because the rest of the edge is gapped.
#
# From the point of view of the superconducting junction, this means that advancing the phase difference by $2\pi$, the ground state fermion parity changes. Recalling what we learned in our second and third weeks, we can say that the Josephson effect is $4\pi$-periodic.

# %% [markdown]
# **TO DO: Add numerics of the Andreev spectrum of the junction**

# %% [markdown]
# ## Majoranas on the quantum spin-Hall edge

# %% [markdown]
# We know that the $4\pi$-periodicity of the Josephson effect can always be associated with the presence of Majorana zero modes at the two superconducting interfaces of the Josephson junctions.
#
# If you compare the system above with the Josephson ring studied in week three, however, you will notice an important difference. In that case the Josephson junction was formed by an insulating barrier, while in our case the two superconducting interfaces are connected by the quantum spin-Hall edge.
#
# This means that our Majoranas are connected by a gapless system, and therefore always strongly coupled. In order to see unpaired Majoranas, or at least weakly coupled ones, we need to gap out the segment of the edge forming the Josephson junction.
#
# Now, the new gap cannot really be another piece of superconductor, otherwise we would form two Josephson junction in series, whereas we want only one.
#
# We know that the edge modes of the quantum spin-Hall insulator are protected by time-reversal symmetry and do not care about potential barriers or impurities. Hence, to gap the edge we need to break the symmetry. This can be done by adding a local magnetic field, or a magnet, to the segment of the edge between the two superconductors:

# %% [markdown]
# ![](figures/qsh_majoranas.png)

# %% [markdown]
# In the sketch above, you see the cartoon of two Majoranas with decaying wavefunction, each one situated at the interface between the magnet and the superconductor.
#
# Note that the magnet and the superconductor both introduce a gap in the helical edge, but with a completely different physical mechanism. The magnet flips the spin of an incoming electron, or hole, while the superconductor turns an incoming electron with spin up into an outgoing hole with spin down. These two different types of reflection processes combine together to form a Majorana bound state.

# %% [markdown]
# Let's give a look at the effect of a Zeeman term to the spectrum of the Josephson junction.

# %%
l = 60
w = 60
sys2 = make_qshe_sc(l, w)
num_states = 10

par = SimpleNamespace(A=0.5, B=1.00, D=0.1, M=0.5, gaps=lambda x, y: np.array([(y<0)*0.0, (y>=0)*0.0]))
ham = sys2.hamiltonian_submatrix(args=[par,], sparse=True)
energies0, states0 = sl.eigsh(ham, sigma=0, k=num_states)


par = SimpleNamespace(A=0.5, B=1.00, D=0.1, M=0.5, gaps=lambda x, y: np.array([(y<0)*0.2, (y>=0)*0.3]))
ham = sys2.hamiltonian_submatrix(args=[par,], sparse=True)
energies, states = sl.eigsh(ham, sigma=0, k=num_states)


phi = np.linspace(-np.pi, np.pi, 51)
x = (w + 0.5) / 2 * np.cos(phi)
y = (l + 0.5) / 2 * np.sin(phi)

densities = (np.linalg.norm(states.reshape(-1, 8, num_states), axis=1)**2)
densities0 = (np.linalg.norm(states0.reshape(-1, 8, num_states), axis=1)**2)

fig = plt.figure(figsize=(9, 3.5))
ax1 = fig.add_subplot(122)
gap_B = ax1.fill_between(x[:26], 0, y[:26], facecolor='gold', alpha=0.1)
gap_Sc = ax1.fill_between(x[26:], 0, y[26:], facecolor='blue', alpha=0.1)
kwant.plotter.map(sys2, densities[:,0], colorbar=False, ax=ax1, cmap='gist_heat_r')
plt.plot(x, y, 'k-', lw=2)
plt.annotate('$E_Z$', xytext=(-w/20, l/5), xy=(0, l/3), fontsize=16,
            arrowprops=dict(arrowstyle="-", facecolor='black', lw=0))
plt.annotate('$\Delta$', xytext=(-w/20, -l/4), xy=(0, -l/3), fontsize=16,
            arrowprops=dict(arrowstyle="-", facecolor='black', lw=0))
ax1.set_yticks([])
ax1.set_xticks([])
ax1.set_ylim(-l/2-3, l/2+3)
ax1.set_xlim(-w/2-3, w/2+3)
pot = int(np.log(abs(energies0[0])) / np.log(10.0)) - 1
fac = abs(energies0[0])*10**(-pot)
ax1.set_title('Majoranas, $E = %1.1f \cdot 10^{%1.0f}$' %(fac, pot) )

ax0 = fig.add_subplot(121)
kwant.plotter.map(sys2, densities0[:,0], colorbar=False, ax=ax0, cmap='gist_heat_r')
ax0.set_yticks([])
ax0.set_xticks([])
ax0.set_ylim(-l/2-3, l/2+3)
ax0.set_xlim(-w/2-3, w/2+3)
pot = int(np.log(abs(energies[0])) / np.log(10.0)) - 1
fac = abs(energies[0])*10**(-pot)
ax0.set_title('Edge state, $E = %1.1f \cdot 10^{%1.0f}$' %(fac, pot))
plt.plot(x, y, 'k-', lw=2)
plt.show()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:220: SparseEfficiencyWarning: splu requires CSC matrix format
#   warn('splu requires CSC matrix format', SparseEfficiencyWarning)

# %% [markdown]
# # Vortices in topological superconductors

# %% [markdown]
# ## 2D $p$-wave superconductors
#
# So far you have only seen Majorana appearing in 1D systems, however they can appear also in 2D systems. How? It turns out that the idea we used to construct 2D Chern insulators, in week 4, by coupling together 1D Kitaev chains, can also be used to construct 2D topological superconductors.
#
# Not really suprised, are you? At that point, we told you to forget that the Kitaev model was really a superconductor. Now you can remember that and it won't surprise you that if we paste 1D superconductors together then we get a 2D superconductor.
#
# So let's look back at the Hamiltonian we obtained for a Chern insulator by coupling a stack of Kitaev chains:
#
# $$H_\textrm{2D}(\mathbf{k})=-(2t\cos{k_x}+\mu)\,\tau_z+\Delta\sin{k_x}\tau_y-2\gamma\,(\cos{k_y}\tau_z+\sin{k_y}\,\tau_x).$$
#
# Those of us who want to be careful, would want to check that the above Hamiltonian is indeed a superconductor, and in particular that the terms coupling different chains that we added back then to the Kitaev chain did not spoil its particle-hole symmetry.
#
# And indeed if we consider the operator $\mathcal{P}=\tau_x \mathcal{K}$ with $\mathcal{K}$ the complex conjugation operator, we find that the Bloch Hamiltonian obeys $H_\textrm{2D}(\mathbf{k}) = -\tau_x H^*_\textrm{2D}(-\mathbf{k}) \tau_x$, precisely the symmetry obeyed by the Kitaev chain, extended to two dimensions (If you do not remember how to apply an anti-unitary symmetry in momentum space, you can go back to week 1 where you find the original derivation).
#
# The reinterpretation of the Hamiltonian $H$ as a superconductor does not take away from the fact that the Hamiltonian is still a Chern insulator, except that the system is now physically different - a superconductor rather than an insulator. In particular, the system is still characterized by a bulk Chern number which determines the presence of chiral edge states.
#
# The Hamiltonian above is quite anisotropic - it looks different in the $x$ and $y$ directions, a consequence of the way we derived it in week four. For our purposes, howeverm, it is convenient to make it look isotropic.
#
# But the system still has chiral edge states and also a Chern number topological invariant in the bulk. However, $H$ is quite anisotropic between the $x$ and $y$ directions, which is not an essential requirement for the Chern insulator character. So we tweak the coefficients in $H$ to make it more isotropic, without closing the gap an hence without changing its topological properties.
#
# In this way we arrive at the Hamiltonian of a so-called $p$-wave superconductor:
#
# $$H(k_x,k_y)=-[2t\,(\cos{k_x}+\cos{k_y})+\mu]\,\tau_z+\Delta\,(\sin{k_x}\tau_y-\sin{k_y}\tau_x).$$
#
# Apart from looking more symmetric between the $x$ and $y$ directions, the Hamiltonian clearly separates normal hopping, proportional to $t$, and superconducting pairing, proportional to $\Delta$. This becomes more prominent by expanding the Bloch Hamiltonian around $\mathbf{k}=\mathbf{0}$, so that
#
# $$H(k_x,k_y)\approx [2t\,(k_x^2+k_y^2)-\mu+4 t]\tau_z+[i \Delta(k_x+i k_y)\tau_++h.c],$$
#
# where $\tau_+=(\tau_x+i\tau_y)/2$. The first term in $H_{pwave}$ proportional to $t$, should remind you of parabolic dispersion of electrons, while the term proportional to $\Delta$ is superconducting because they are proportional to $c^\dagger c^\dagger$ in the second quantized notation.
#
# Why do we call this superconductor a $p$-wave one? By trying to represent the superconducting pairing in angular momentum representation, we could convince ourselves that the Cooper pairs in this superconductor are in the $p$-wave angular momentum channel. Even without working out the deatils, this should sound plausible because if you write the momentum in polar coordinates, you obtain $(k_x+i k_y)=|k|e^{i\theta}\propto Y_{l=1,m=1}(\theta=0,\phi)$.
#
# The Hamiltonian above is a canonical example of a 2D topological superconductor. It has a Chern numner which takes integer values, and can support chiral edge states, for instance when $\Delta\ll t$ and $\mu < 0$. A chiral edge state can be described by a simple effective Hamiltonian, equivalent to that of a quantum Hall system:
#
# $$H_\textrm{edge}=v k$$
#
# with $v$ the velocity and $k$ the momentum along the edge.

# %% [markdown]
# ## Vortices in 2D p-wave superconductors
#
# The phase $\phi$ of the pair-potential $\Delta=|\Delta|e^{i\phi}$ of a  two-dimensional superconductor is arbitrary i.e. it can be changed without any measurable consequence. So if we consider such a superconductor in a corbino geometry then we can imagine a situation where the phase $\phi$ varies along the angle of the corbino geometry so as to wind i.e. $\phi=\theta$.
#
# TO DO: Figure of a corbino geometry - showing phase winding and edge modes.
#
# We can write the Hamiltonian of a superconductor with a varying phase as:
#
# $$H_{pwave}\approx [-2t\nabla^2-\mu+4 t]\tau_z+\frac{|\Delta|}{2}[\{e^{i\phi},\partial_x+i\partial_y\}\tau_++h.c.],$$
#
# where $\{,\}$ is the anti-commutator that ensures that the Hamiltonian is Hermitean despite the spatially varying phase.
# By applying a unitary transformation $U=e^{i\phi (1+\tau_z)/2}$, we can eliminate the phase of the order parameter.
#
# Applying the same unitary transformation to the edge Hamiltonian, we see that
#
# $$H_{edge}\rightarrow U H_{edge}U^\dagger \approx v\{i\partial_x -\partial_x\phi (1+\langle\tau_z\rangle)/2\},$$
#
# where $\langle\tau_z\rangle=0$ is the expectation with respect to the $k_x=0$ eigenstate.
# With this substitution, since $\partial_x\phi=\pi/L$ for an edge with length $L$, we see that the insertion of a vortex shifts the energy of the edge state by
#
# $$E_{edge}(k_x)\rightarrow v(k_x+\pi/L).$$
#
# The allowed quantized values of $k_x$ are spaced by $\delta k_x=2\pi/L$. Therefore the insertion of a vortex shifts the spectrum between  $E_n=2n \pi/L$ and $E_n=(2n+1)\pi/L$. You might start by guessing that the first is a spectrum without the vortex and the latter one is the vortex.
#
# It's actually the other way around. To understand this, we notice that the spectrum $E_n=2n\pi/L$ has a non-degenerate zero energy state at $n=0$. This state must obey the particle-hole symmetry of the superconductor $\mathcal{P}$, which means that the eigenstate must be a Majorana mode! A Majorana mode is stable to all continuous changes of the edge, including shrinking down the inner circumference of the Corbino geometry to a point. Of course, if there is no vortex, we should be able to get rid of the hole by  shrinking down the inner edge of the Corbino geometry to a point.
#
# > This means that the spectrum $E_n=2n\pi/L$, corresponds to the spectrum with a vortex. Thus we have established that not only does the $p_x+ip_y$ superconductor have chiral edge states like a quantum Hall system, but it also supports a zero-energy Majorana bound state in the core of a vortex.
#
# You could also come to this conclusion by explicitly solving $H_{pwave}\psi=0$ for a vortex using rotational symmetry after doing a lot of algebra. The numerical simulation below confirms the above conclusion as well.

# %%
par = SimpleNamespace(t=1.0, mu=0.4, delta=0.5, phase=lambda x,y: np.angle(x+1j*y))
l = 60
w = 60
sys = make_2d_pwave(w,l)

ham = sys.hamiltonian_submatrix(args=[par,], sparse=True)
num_states = 10
energies, states = sl.eigsh(ham, sigma=0, k=num_states)

densities = (np.linalg.norm(states.reshape(-1, 2, num_states), axis=1)**0.5)
kwant.plotter.map(sys, densities[:,0], cmap='gist_heat_r')
plt.show()

# %% [markdown]
# # Vortices in 3D topological insulator

# %% [markdown]
# Spinless chiral p-wave superconductors are not easy to find in nature. Turns out that we can get pretty close by starting with 3D topolgical insulator (TI). For this we first need to turn the surface of a 3D TI into a superconductor. We can do this by the so-called proximity effect by placing a superconductor next to the TI. By using analogy with the semiconducting nanowire from week 1,  we can write the Bogoliubov de Gennes Hamiltonian for the TI together with singlet superconductivity as:
#
# $$H_{BdG}=\{{\bf \sigma}\cdot {\bf k}-\mu\}\tau_z+\Delta \tau_x.$$
#
# Let us first consider the case $\mu\gg \Delta$ so that only states on one fermi surface far from the Dirac point contribute. In this case, we should focus on the electron and hole like states at the fermi surface
#
# $$\psi_+({\bf k})=\dots\,\quad \textrm{ and }\psi_-({\bf k})=\mathcal{P}\psi_+(-{\bf k}).$$
#
# By computing the matrix elements of $H_{BdG}$ in this basis, we can check that
#
# $$H_{BdG}\approx \{|\bf k|-\mu\}\tau_z+\Delta ({\bf k}\cdot{\bf \tau}),$$
#
# which the Hamiltonian of a $p-$wave superconductor.
#
# We can now expect that if we place a vortex in the 3D TI, similar to the p-wave superconductor, it will also support a zero-energy Majorana mode.
#
# Now you might wonder is this only valid at  large $\mu\gg \Delta$. All you have to do is to now compute the energy spectrum of $H_{BdG}({\bf k})$, which is given by
#
# $$E_{\pm}({\bf k})=\dots,$$
#
# which clearly does not close as a function of $\mu$.
#
# > Therefore like the chiral p-wave the vortex of the 3D TI supports Majorana modes. However, the system is quite different. It preserves time-reversal invariance and has no edge states!

# %%
l, w, h = 10, 10, 25
sys = bhz_slab(l, w, h)

par = SimpleNamespace(A1=0.5, A2=0.5, B1=0.5, B2=0.5, C=-0.2, D1=0.1, D2=0.0, M=-0.2, 
                      delta=0.15, phase=lambda x,y: 1 * np.angle(x+1j*y))

ham = sys.hamiltonian_submatrix(args=[par,], sparse=True)
num_states = 10
energies, states = sl.eigsh(ham, sigma=0, k=num_states)

densities = (np.linalg.norm(states.reshape(-1, 8, num_states), axis=1)**2)

fig = plt.figure(figsize=(9, 3.5))

ax0 = fig.add_subplot(121, projection='3d')
kwant.plot(sys, ax=ax0, site_size=0.3*np.linspace(1, 1, len(densities[:, 0])))
ax0.set_xlim(-w/2-2, w/2+2)
ax0.set_ylim(-l/2-2, l/2+2)
ax0.set_yticks([])
ax0.set_xticks([])
ax0.set_zlim3d([0, h])
ax0.set_zticks([0, h])
ax0.set_zticklabels(['$0$', '$%d$' %h])
plt.title('System')
densities /= np.max(densities, axis=0, keepdims=True)

ax1 = fig.add_subplot(122, projection='3d')
kwant.plotter.plot(sys, site_size=densities[:, 0], site_color=densities[:, 0], ax=ax1,
                   cmap='gist_heat_r', colorbar=False, site_lw=0)
ax1.set_xlim(-w/2-2, w/2+2)
ax1.set_ylim(-l/2-2, l/2+2)
ax1.set_yticks([])
ax1.set_xticks([])
ax1.set_zlim3d([0, h])
ax1.set_zticks([0, h])
ax1.set_zticklabels(['$0$', '$%d$' %h])
pot = int(np.log(abs(energies[0]))/np.log(10.0)) - 1
fac = abs(energies[0])*10**(-pot)
plt.title('Majoranas, $E = %1.1f \cdot 10^{%1.0f}$' %(fac, pot))
plt.show()

# %% [markdown]
# # Conclusions

# %% [markdown]
# Questions about what you just learned? Ask them below!

# %%
MoocDiscussion("Questions", "Majoranas in topological insulators")
# Out:
# MoocDiscussion(**{'discussion_category': 'Questions', 'discussion_target': 'Majoranas in topological insulators', 'display_name': 'Majoranas in topological insulators', 'discussion_id': '243b53c9a4fe3481da813e6be3c13abb'})
