# %%
# %run ../code/init_mooc_nb.ipy      
import scipy.sparse.linalg as sl
# Out:
# Performing the necessary imports.
#
# from __future__ import division, print_function
# import numpy as np
# import matplotlib
# import kwant
#
# import ipywidgets
# from IPython.html.widgets import interact
# from ipywidgets import StaticInteract, RangeWidget, DropDownWidget
# from IPython.display import display_html
# from matplotlib import pyplot as plt
#
# import pfaffian as pf
# from edx_components import *
# <script type=text/javascript>
# /* Add a button for showing or hiding input */
# on = "Show input";
# off = "Hide input";
# function onoff(){
#   currentvalue = document.getElementById('onoff').value;
#   if(currentvalue == off){
#     document.getElementById("onoff").value=on;
#       $('div.input').hide();
#   }else{
#     document.getElementById("onoff").value=off;
#       $('div.input').show();
#   }
# }
#
# /* Launch first notebook cell on start */
# function launch_first_cell (evt) {
#   if (!launch_first_cell.executed
#       && IPython.notebook.kernel
#   ) {
#     IPython.notebook.get_cells()[0].execute();
#     launch_first_cell.executed = true;
#   }
# }
#
# $([IPython.events]).on('status_started.Kernel notebook_loaded.Notebook', launch_first_cell);
# </script>
#
# <p>Press this button to show/hide the code used in the notebook:
# <input type="button" class="ui-button ui-widget ui-state-default ui-corner-all ui-button-text-only" value="Hide input" id="onoff" onclick="onoff();"></p>
# <script type=text/javascript>
# $(document).ready(function (){if(!("IPython" in window)){onoff();}})
# </script>

# %% [markdown]
# #Table of Contents

# %%
import tinyarray as ta

sigma0 = np.array([[1, 0], [0, 1]])
sigmax = np.array([[0, 1], [1, 0]])
sigmay = np.array([[0, -1j], [1j, 0]])
sigmaz = np.array([[1, 0], [0, -1]])


my = np.kron(sigmay,0.5*(sigma0+sigmaz))
s0s0sz = ta.array(np.kron(np.kron(sigma0, sigma0), sigmaz))
s0szsz = ta.array(np.kron(np.kron(sigma0, sigmaz), sigmaz))
mysz = ta.array(np.kron(my, sigma0))
s0s0sx = ta.array(np.kron(np.kron(sigma0, sigma0), sigmax))
szsxsz = ta.array(np.kron(np.kron(sigmaz, sigmax), sigmaz))
s0sysz = ta.array(np.kron(np.kron(sigma0, sigmay), sigmaz))

# %%
class SimpleNamespace(object):
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)


def make_qshe_sc(l=40, w=10, lead=False):
    def shape(pos):
        (x, y) = pos
        return (1.0 * y**2 / l**2 + 1.0 * x**2 / w**2) <= 0.25
    
    def onsite(site, par):
        (x, y) = site.pos
        A, B, D, M = par.A/2, par.B, par.D, par.M
        return (M - 4 * B) * s0szsz - 4 * D * s0s0sz + par.gaps(x, y)[1] * mysz + par.gaps(x, y)[0] * s0s0sx

    def hopx(site1, site2, par):
        A, B, D, M = par.A/2, par.B, par.D, par.M
        return B * s0szsz + D * s0s0sz + 1j * A * szsxsz

    def hopy(site1, site2, par):
        A, B, D, M = par.A/2, par.B, par.D, par.M
        return B * s0szsz + D * s0s0sz - 1j * A * s0sysz
    
    lat = kwant.lattice.square()
    sys = kwant.Builder()
    sys[lat.shape(shape, (0, 0))] = onsite
    sys[kwant.HoppingKind((1, 0), lat)] = hopx
    sys[kwant.HoppingKind((0, 1), lat)] = hopy
    
    if lead:
        sym = kwant.TranslationalSymmetry((0, 1))
        lead = kwant.Builder(sym)
        lead[lat(0, 0)] = 1.5 * par.B * np.kron(np.kron(sigma0, sigmaz), sigmaz)
        lead[kwant.HoppingKind((0, 1), lat)] = -par.B * np.kron(np.kron(sigma0, sigmaz), sigmaz)
        sys.attach_lead(lead)        
        sys.attach_lead(lead.reversed())
    return sys.finalized()


def make_qshe_sc_ribbon(w=3):
    def ribbon_shape(pos):
        (x, y) = pos
        return (0 <= x < w)
    
    def onsite(site, par):
        (x, y) = site.pos
        A, B, D, M = par.A/2, par.B, par.D, par.M
        return (M - 4 * B) * s0szsz - 4 * D * s0s0sz + par.gaps(x, y)[1] * mysz + par.gaps(x, y)[0] * s0s0sx

    def hopx(site1, site2, par):
        A, B, D, M = par.A/2, par.B, par.D, par.M
        return B * s0szsz + D * s0s0sz + 1j * A * szsxsz

    def hopy(site1, site2, par):
        A, B, D, M = par.A/2, par.B, par.D, par.M
        return B * s0szsz + D * s0s0sz - 1j * A * s0sysz
    
    
    lat = kwant.lattice.square()
    sym = kwant.TranslationalSymmetry((0, 1))
    sys = kwant.Builder(sym)

    
    sys[lat.shape(ribbon_shape, (0, 0))] = onsite
    sys[kwant.HoppingKind((1,0), lat)] = hopx
    sys[kwant.HoppingKind((0,1), lat)] = hopy
    
    return sys.finalized()

def make_2d_pwave(w, l):
    def shape(pos):
        (x, y) = pos
        return (1.0 * y**2 / l**2 + 1.0 * x**2 / w**2) <= 0.25
    
    def hopx(site1, site2, par):
        (x1, y1) = site1.pos
        (x2, y2) = site2.pos
        phi = par.phase(0.5 * (x1 + x2), 0.5 * (y1 + y2))
        return -par.t * sigmaz + 1j * par.delta * \
                (np.cos(phi) * sigmax + np.sin(phi) * sigmay)
    
    def hopy(site1, site2, par):
        (x1, y1) = site1.pos
        (x2, y2) = site2.pos
        phi = par.phase(0.5 * (x1 + x2), 0.5 * (y1 + y2))
        return -par.t * sigmaz - 1j * par.delta * \
                (np.cos(np.pi/2 + phi) * sigmax + np.sin(np.pi/2 + phi) * sigmay)
    
    def onsite(site1, par):
        return (4 * par.t - par.mu) * sigmaz 
    
    lat = kwant.lattice.square()
    sys = kwant.Builder()
    sys[lat.shape(shape, (w/2 - 1, 0))] = onsite
    sys[kwant.HoppingKind((1, 0), lat)] = hopx
    sys[kwant.HoppingKind((0, 1), lat)] = hopy
    
    return sys.finalized()

# %%
par = SimpleNamespace(t=1.0, mu=0.4, delta=0.5, phase=lambda x,y: np.angle(x+1j*y))
l = 60
w = 60
sys4 = make_2d_pwave(w,l)

ham = sys4.hamiltonian_submatrix(args=[par,], sparse=True)
num_states = 10
energies, states = sl.eigsh(ham, sigma=0, k=num_states)

# %%
densities = (np.linalg.norm(states.reshape(-1, 2, num_states), axis=1)**0.5)
kwant.plotter.map(sys4, densities[:,0])
plt.show()

# %%
abs(energies)
# Out:
# array([ 0.  ,  0.  ,  0.04,  0.04,  0.07,  0.07,  0.11,  0.11,  0.13,  0.13])

# %%
par = SimpleNamespace(A=0.5, B=1.00, D=0.1, M=0.5, gaps=lambda x, y: np.array([(x<0)*0.2, (x>=0)*0.3]))
l = 60
w = 60

sys2 = make_qshe_sc(l, w)
num_states = 10
ham = sys2.hamiltonian_submatrix(args=[par,], sparse=True)
energies, states = sl.eigsh(ham, sigma=0, k=num_states)

# %%
densities = (np.linalg.norm(states.reshape(-1, 8, num_states), axis=1)**2)
kwant.plotter.map(sys2, densities[:,2])
plt.show()

# %%
#kwant.plot(sys)
#plt.show
np.sort(abs(energies))[2]
# Out:
# 0.077571348164989382

# %%
w = 30
par = SimpleNamespace(A=0.5, B=1.00, D=0.2, M=0.5, gaps=lambda x, y: np.array([0.0, 0.3]))
sys3 = make_qshe_sc_ribbon(w)
fig = plt.figure()
ax = fig.add_subplot(111)
kwant.plotter.bands(sys3, args=[par,], ax=ax)
plt.ylim(-1.0, 1.0)
plt.xlim(-np.pi/2, np.pi/2)
plt.show()
