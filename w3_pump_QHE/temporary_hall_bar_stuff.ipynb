# %%
# %run ../code/init_mooc_nb.ipy
# Out:
# Performing the necessary imports.
#
# from __future__ import division, print_function
# import numpy as np
# import matplotlib
# import kwant
#
# import ipywidgets
# from IPython.html.widgets import interact
# from ipywidgets import StaticInteract, RangeWidget, DropDownWidget
# from IPython.display import display_html
# from matplotlib import pyplot as plt
#
# import pfaffian as pf
# from edx_components import *
# <script type=text/javascript>
# /* Add a button for showing or hiding input */
# on = "Show input";
# off = "Hide input";
# function onoff(){
#   currentvalue = document.getElementById('onoff').value;
#   if(currentvalue == off){
#     document.getElementById("onoff").value=on;
#       $('div.input').hide();
#   }else{
#     document.getElementById("onoff").value=off;
#       $('div.input').show();
#   }
# }
#
# /* Launch first notebook cell on start */
# function launch_first_cell (evt) {
#   if (!launch_first_cell.executed
#       && IPython.notebook.kernel
#   ) {
# ...

# %% [markdown]
# #Table of Contents
# * [Hall Bar Codes](#Hall-Bar-Codes)
# 	* &nbsp;
# 		* [bands in lead 0](#bands-in-lead-0)
# * [Plot of sth](#Plot-of-sth)
# 	* [Ribbon](#Ribbon)
# * [Ribbon](#Ribbon)
# * [Butterfly](#Butterfly)

# %% [markdown]
# # Hall Bar Codes

# %%
def qhe_hall_bar(L=50, W=10, w_lead=10):
    """Create a hall bar system. 
    
    Square lattice, one orbital per site.
    Returns finalized kwant system.
    
    Arguments required in onsite/hoppings: 
        t, mu, mu_lead
    """
    
    L = 2*(L//2)
    W = 2*(W//2)
    w_lead = 2*(w_lead//2)
    
    # bar shape
    def bar(pos):
        (x, y) = pos
        return (x >= -L/2 and x <= L/2) and (y >= -W/2 and y <= W/2)

    # Onsite and hoppings
    def onsite(site, par):
        (x,y) = site.pos
        return 4*par.t - par.mu   
    
    def hopping_Ax(target, source, par):
        xt, yt = target.pos
        xs, ys = source.pos
        return -par.t * np.exp(-0.5j * par.B * (xt + xs) * (yt - ys))

    def hopping_Ay(target, source, par):
        xt, yt = target.pos
        xs, ys = source.pos
        return -par.t * np.exp(0.5j * par.B * (xt - xs) * (yt + ys))

    def make_lead_hop_y(x0):
        def hopping_Ay(target, source, par):
            xt, yt = target.pos
            xs, ys = source.pos
            return -par.t * np.exp(-1j * par.B * x0 * (yt - ys))
        return hopping_Ay
       
    # Building system
    lat = kwant.lattice.square()
    sys = kwant.Builder()
    
    sys[lat.shape(bar, (0, 0))] = onsite
    sys[lat.neighbors()] = hopping_Ax 
    
    # Attaching leads
    sym_lead = kwant.TranslationalSymmetry((-1, 0))
    lead = kwant.Builder(sym_lead)
    

    def lead_shape(pos):
        (x, y) = pos
        return (-w_lead / 2 <= y <= w_lead / 2)
    
    lead_onsite = lambda site, par: 4 * par.t - par.mu_lead

    sym_lead_vertical = kwant.TranslationalSymmetry((0,1))
    lead_vertical1 = kwant.Builder(sym_lead_vertical)
    lead_vertical2 = kwant.Builder(sym_lead_vertical)
    
    def lead_shape_vertical1(pos):
        (x, y) = pos
        return (-L/4 - w_lead/2 <= x <= -L/4 + w_lead/2)
    
    def lead_shape_vertical2(pos):
        (x, y) = pos
        return (+L/4 - w_lead/2 <= x <= +L/4 + w_lead/2)
    
    lead_vertical1[lat.shape(lead_shape_vertical1, (-L/4 , 0))] = lead_onsite
    lead_vertical1[lat.neighbors()] = hopping_Ax
    lead_vertical2[lat.shape(lead_shape_vertical2, (L/4, 0))] = lead_onsite
    lead_vertical2[lat.neighbors()] = hopping_Ax

    sys.attach_lead(lead_vertical1)
    sys.attach_lead(lead_vertical2)
    
    sys.attach_lead(lead_vertical1.reversed())
    sys.attach_lead(lead_vertical2.reversed())
    
    lead[lat.shape(lead_shape, (-1, 0))] = lead_onsite
    lead[kwant.builder.HoppingKind((1, 0), lat)] = hopping_Ay
    lead[kwant.builder.HoppingKind((0, 1), lat)] = make_lead_hop_y(-L/2)

    sys.attach_lead(lead)

    lead = kwant.Builder(sym_lead)
    lead[lat.shape(lead_shape, (-1, 0))] = lead_onsite
    lead[kwant.builder.HoppingKind((1, 0), lat)] = hopping_Ay
    lead[kwant.builder.HoppingKind((0, 1), lat)] = make_lead_hop_y(L/2)

    sys.attach_lead(lead.reversed())

    return sys.finalized()

def calculate_sigmas(G):
#     smat = smat.data
#     smat = abs(smat)**2
    # reduce by one dimension G -> G[temp, temp]
    temp = [0, 1, 3, 4, 5]
    G = G[temp, :]
    G = G[:, temp]
    # invert R = G^-1
    # find out whether it is a numpy object
    r = np.linalg.inv(G)
    # Voltages follow: V = R I[temp]
    V = r.dot(np.array([0, 0, 0, 1, -1]))
    # Completely solved the six terminal system. 
    # Consider the 2x2 conductance now: Use I = sigma U
    E_x = V[0] - V[1] - V[3]
    E_y = V[0] + V[1] - V[3]
    #formula above
    sigma_xx = E_x / (E_x**2 + E_y**2)
    sigma_xy = E_y / (E_x**2 + E_y**2)
    return sigma_xx, sigma_xy

# %%
sys = qhe_hall_bar(L=120, W=70, w_lead=30)
kwant.plot(sys);

# %% [markdown]
# ### bands in lead 0

# %%
par = SimpleNamespace(t=1.0, mu=0.4, mu_lead=0.4, B=-0.1)
kwant.plotter.bands(sys.leads[4], args = [par], show = False);
plt.ylim(0,1)
# Out:
# (0, 1)

# %%
wf = kwant.wave_function(sys, energy=0.0, args=[par])

data = sum(abs(x)**2 for x in wf(4))
kwant.plotter.map(sys, data);

# %%
print smatrix.transmission(0,1)
# Out:
# 2.0

# %%
s = smatrix
G = np.array([[s.transmission(i, j) for i in range(len(sys.leads))] for j in range(len(sys.leads))])

# %%
sigmas1 = []
sigmas2 = []
Bs = np.linspace(-.2,0,50)

for par.B in Bs:
    s = kwant.smatrix(sys, args=[par])
    G = np.array([[s.transmission(i, j) for i in range(len(sys.leads))] for j in range(len(sys.leads))])
    sigma = calculate_sigmas(G)
    sigmas1.append(sigma[0])
    sigmas2.append(sigma[0])

# %%
plt.plot(Bs,sigmas1);

# %%
plt.plot(Bs,sigmas2);

# %% [markdown]
# # Plot of sth

# %%
ldos = kwant.ldos(sys, energy=0.0, args=[par])
kwant.plotter.map(sys, ldos);

# %% [markdown]
# ## Ribbon

# %%
def qhe_ribbon(W, periodic=False):
    """
    W = 2*(W//2)
    
    def ribbon_shape(pos):
        (x, y) = pos
        return (-W / 2 <= y <= W / 2)
    
    def onsite(site, par):
        (x,y) = site.pos
        return 4*par.t - par.mu
    
    def hopping(target, source, par):
        xt, yt = target.pos
        xs, ys = source.pos
        return -par.t * np.exp(-0.5j * par.B * (xt - xs) * (yt + ys))
    
    def hopping_periodic(target, source, par):
        xt, yt = target.pos
        xs, ys = source.pos
        return -par.t * np.exp(-0.5j * int(par.B) * 2 * np.pi / (W + 1) * (xt - xs) * (yt + ys))        
    
    lat = kwant.lattice.square()
    sym_sys = kwant.TranslationalSymmetry((-1, 0))
    sys = kwant.Builder(sym_sys)
    
    sys[lat.shape(ribbon_shape, (0, 0))] = onsite
    
    if periodic:
        sys[lat.neighbors()] = hopping_periodic
        sys[lat(0, - W / 2 ), lat(0, + W / 2)] = hopping_periodic
    else:
        sys[lat.neighbors()] = hopping
    
    return sys.finalized()

# %% [markdown]
# # Ribbon

# %%
sys = qhe_ribbon(20, periodic=False)
par = SimpleNamespace(t=1.0, mu=0.0, B=0.05)

kwant.plotter.bands(sys, args=[par], show=False);
plt.ylim(0,1)
# Out:
# (0, 1)

# %% [markdown]
# # Butterfly

# %%
sys = qhe_ribbon(200, periodic=True)

par = SimpleNamespace(t=1.0, mu=0.0, B=1)
kwant.plotter.bands(sys, args=[par], show=False);

# %%
L = 200
par = SimpleNamespace(t=1.0, mu=0.0, B=1)
energies = []
sys = qhe_ribbon(L, periodic=True)
for par.B in range(0,L+1):
    energies.append(kwant.physics.Bands(sys, args=[par])(0))
plt.plot(energies, 'k.');
