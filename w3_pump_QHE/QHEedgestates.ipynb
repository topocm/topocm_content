# %%
# %run ../code/init_mooc_nb.ipy
#This is the one that needs fixing

def qhe_hall_bar(L=50, W=10, w_lead=10):
    """Create a hall bar system. 
    
    Square lattice, one orbital per site.
    Returns finalized kwant system.
    
    Arguments required in onsite/hoppings: 
        t, mu, mu_lead
    """
    
    L = 2*(L//2)
    W = 2*(W//2)
    w_lead = 2*(w_lead//2)
    
    # bar shape
    def bar(pos):
        (x, y) = pos
        return (x >= -L/2 and x <= L/2) and (y >= -W/2 and y <= W/2)

    # Onsite and hoppings
    def onsite(site, par):
        (x,y) = site.pos
        return 4*par.t - par.mu   
    
    def hopping(target, source, par):
        xt, yt = target.pos
        xs, ys = source.pos
        return -par.t * np.exp(-0.5j * par.B * (xt - xs) * (yt + ys))
            
    # Building system
    lat = kwant.lattice.square()
    sys = kwant.Builder()
    
    sys[lat.shape(bar, (0, 0))] = onsite
    sys[lat.neighbors()] = hopping 
    
    # Attaching leads
    sym_lead = kwant.TranslationalSymmetry((-1, 0))
    lead = kwant.Builder(sym_lead)

    def lead_shape(pos):
        (x, y) = pos
        return (-w_lead / 2 <= y <= w_lead / 2)

    lead[lat.shape(lead_shape, (-1, 0))] = lambda site, par: 4 * par.t - par.mu_lead
    lead[lat.neighbors()] = lambda target, source, par: -par.t

    sym_lead_vertical = kwant.TranslationalSymmetry((0,1))
    lead_vertical1 = kwant.Builder(sym_lead_vertical)
    lead_vertical2 = kwant.Builder(sym_lead_vertical)
    
    def lead_shape_vertical1(pos):
        (x, y) = pos
        return (-L/4 - w_lead/4 <= x <= -L/4 + w_lead/4)
    
    def lead_shape_vertical2(pos):
        (x, y) = pos
        return (+L/4 - w_lead/4 <= x <= +L/4 + w_lead/4)
    
    lead_vertical1[lat.shape(lead_shape_vertical1, (-L/4 , 0))] = lambda site, par: 4 * par.t - par.mu_lead
    lead_vertical1[lat.neighbors()] = lambda target, source, par: -par.t
    lead_vertical2[lat.shape(lead_shape_vertical2, (L/4, 0))] = lambda site, par: 4 * par.t - par.mu_lead
    lead_vertical2[lat.neighbors()] = lambda target, source, par: -par.t

    sys.attach_lead(lead_vertical1)
    sys.attach_lead(lead_vertical2)
    
    sys.attach_lead(lead_vertical1.reversed())
    sys.attach_lead(lead_vertical2.reversed())
    
    sys.attach_lead(lead)
    sys.attach_lead(lead.reversed())
    
    return sys.finalized()


def qhe_ribbon(W, periodic=False):
    """ Creates blabla bla system
    
    If we have periodic boundary conditions, the flux through a single 
    unit cell is quantized.
    """
    W = 2*(W//2)
    
    def ribbon_shape(pos):
        (x, y) = pos
        return (-W / 2 <= y <= W / 2)
    
    def onsite(site, par):
        (x,y) = site.pos
        return 4*par.t - par.mu
    
    def hopping(target, source, par):
        xt, yt = target.pos
        xs, ys = source.pos
        return -par.t * np.exp(-0.5j * par.B * (xt - xs) * (yt + ys))
    
    def hopping_periodic(target, source, par):
        xt, yt = target.pos
        xs, ys = source.pos
        return -par.t * np.exp(-0.5j * int(par.B) * 2 * np.pi / (W + 1) * (xt - xs) * (yt + ys))        
    
    lat = kwant.lattice.square()
    sym_sys = kwant.TranslationalSymmetry((-1, 0))
    sys = kwant.Builder(sym_sys)
    
    sys[lat.shape(ribbon_shape, (0, 0))] = onsite
    
    if periodic:
        sys[lat.neighbors()] = hopping_periodic
        sys[lat(0, - W / 2 ), lat(0, + W / 2)] = hopping_periodic
    else:
        sys[lat.neighbors()] = hopping
    
    return sys.finalized()

def qhe_corbino(r_out=100, r_in=65, w_lead=10):
    """Create corbino disk. 
    
    Square lattice, one orbital per site.
    Returns finalized kwant system.
    
    Arguments required in onsite/hoppings: 
        t, mu, mu_lead, B, phi
    """
    # ring shape
    def ring(pos):
        (x, y) = pos
        rsq = x ** 2 + y ** 2
        return (r_in ** 2 < rsq < r_out ** 2)

    # Onsite and hoppings
    def onsite(site, par):
        (x,y) = site.pos
        return 4*par.t - par.mu   
    
    def crosses_branchcut(hop):
        xt, yt = hop[0].pos
        xs, ys = hop[1].pos
        return yt < 0 and xt > 0.5 and xs < 0.5 

    def hopping(target, source, par):
        xt, yt = target.pos
        xs, ys = source.pos
        # Check for correctness!
        return -par.t * np.exp(-0.5j * par.B * (xt - xs) * (yt + ys))
    
    def branchcut_hopping(target, source, par):
        return hopping(target, source, par) * np.exp(1j * par.phi)
            
    # Building system
    lat = kwant.lattice.square()
    sys = kwant.Builder()
    
    sys[lat.shape(ring, (0, r_in + 1))] = onsite
    sys[lat.neighbors()] = hopping 
    
    # adding special hoppings
    def hops_across_cut(sys):
        for hop in kwant.builder.HoppingKind((1, 0), lat, lat)(sys):
            if crosses_branchcut(hop):
                yield hop
    sys[hops_across_cut] = branchcut_hopping
    
    # Attaching leads
    sym_lead = kwant.TranslationalSymmetry((-1, 0))
    lead = kwant.Builder(sym_lead)

    def lead_shape(pos):
        (x, y) = pos
        return (-w_lead / 2 < y < w_lead / 2)

    lead[lat.shape(lead_shape, (0, 0))] = lambda site, par: 4 * par.t - par.mu_lead
    lead[lat.neighbors()] = lambda target, source, par: -par.t

    #### Attach the leads and return the system. ####
    sys.attach_lead(lead)
    sys.attach_lead(lead, origin=lat(0,0))

    return sys.finalized()
# Out:
# Performing the necessary imports.
#
# from __future__ import division, print_function
# import numpy as np
# import matplotlib
# import kwant
#
# import ipywidgets
# from IPython.html.widgets import interact
# from ipywidgets import StaticInteract, RangeWidget, DropDownWidget
# from IPython.display import display_html
# from matplotlib import pyplot as plt
#
# import pfaffian as pf
# from edx_components import *
# <script type=text/javascript>
# /* Add a button for showing or hiding input */
# on = "Show input";
# off = "Hide input";
# function onoff(){
#   currentvalue = document.getElementById('onoff').value;
#   if(currentvalue == off){
#     document.getElementById("onoff").value=on;
#       $('div.input').hide();
#   }else{
#     document.getElementById("onoff").value=off;
#       $('div.input').show();
#   }
# }
#
# /* Launch first notebook cell on start */
# function launch_first_cell (evt) {
#   if (!launch_first_cell.executed
#       && IPython.notebook.kernel
#   ) {
# ...

# %% [markdown]
# #Table of Contents
# * [Where do the pumped electrons come from and go to?](#Where-do-the-pumped-electrons-come-from-and-go-to?)
# * [A closer look on the chiral edge states](#A-closer-look-on-the-chiral-edge-states)
# * [The innocent anomaly of the chiral edges](#The-innocent-anomaly-of-the-chiral-edges)
# * [Quantization of Hall Conductance from edge states](#Quantization-of-Hall-Conductance-from-edge-states)
# * [Topological quantum phase transitions and robustness to disorder ](#Topological-quantum-phase-transitions-and-robustness-to-disorder)
# * [Summary](#Summary)

# %% [markdown]
# ## Quantum Hall effect: edge states and quantized Hall conductance
#
# * Landau levels in a slowly varying potential: chiral edge states
# * Chiral anomaly: Bulk-edge correspondence of the quantum Hall effect
# * Hall conductance from edge states
# * Topological quantum phase transitions and robustness to disorder

# %% [markdown]
# # Where do the pumped electrons come from and go to?

# %% [markdown]
# You have just seen that Laughlin's argument explains the quantization of the Hall conductance in terms of a pump which moves electrons through the bulk of a Hall cylinder, from one edge to the other of the cylinder.
#
# Compare the situation with the simple electron pump which you studied earlier in the lecture. There, the pump moved electrons from one metallic lead to the other. Clearly the pump worked thanks to the availability of electronic states at the Fermi level in the two metallic leads. Otherwise, it would have no electrons to take and no place where to drop them. Without the metallic leads, the pump would be like an empty carousel.
#
# When applied to the Hall cylinder, this simple reasoning shows that Laughlin's argument necessairly implies the presence of **electronic states localized at the edges** of the sample.
#
# It is in fact very easy to convince ourselves that such states must exist. We just need to think about the classical trajectory of an electron with velocity $v$ moving in a perpendicular magnetic field $B$. This trajectory is a circular orbit with radius given by $r_c = mv/eB$, the *cyclotron radius*.
#
# What happens to the classical trajectory of an electron when the center of the orbit is too close to the edge of the cylinder, say closer than a cyclotron radius? It is easier drawn than said:
#
# ![](figures/skipping_orbits.png)

# %% [markdown]
# The electrons cannot exit the sample, and need to bounce back inside. This creates a so-called **skipping orbit**. In a real sample, there will be a confining electrostatic potential which keeps the electrons inside the Hall bar, or cylinder. The combination of a strong magnetic field in the bulk and a confining potential creates at the edges trajectories which are not closed, but travel along the full extent of the edges.
#
# > On the lower edge there are only left-moving states, while on the upper edge only right moving ones. On each each edge there are only states moving in one direction, and the direction is opposite for opposite edges. These strange states obtained at the edges are often referred to as a **chiral edge states**.
#
# The chirality of the edges is determined by the orientation of the magnetic field (out of the plane vs. into the plane), and it would be reversed at both edges if the magnetic field was reversed.
#
# The cartoon above is purely based on classical physics, and needs to be supplemented with quantum considerations before it can give quantitative predictions. We will soon see that the quantum version of the cartoon above can give an explanation of the quantized Hall effect, complementary to Laughlin's argument.
#
# But before we move on to that, we should realize that the picture above is in fact a manifestation of the **bulk-boundary correspondence**. Chiral edge states could not exist without the bulk of the quantum Hall sample.

# %% [markdown]
# # A closer look on the chiral edge states

# %% [markdown]
# So let's look more in detail at the edges of a Hall system. In term of geometry, the Hall cylinder that we considered for the Laughlin argument is in fact equivalent to a ribbon on the $(x, y)$ plane, with a finite width $W$ on the vertical direction, and periodic boundary conditions $x\equiv x+L$ on the $x$ direction ($L$ the circumference of the cylinder).
#
# We already mentioned that in order to confine the electrons on this strip of finite width $W$, there must be a potential barrier $V(x)$. We do not really care about the particular shape of the potential. Generically, it will be very flat for $0\lesssim x \lesssim W$ and very steep right outside this interval:

# %% [markdown]
# ![](figures/confining_potential.png)

# %% [markdown]
# You already know how the energy level look like if we neglect the confining potential, that is if we only consider the bulk of the ribbon, away from the edges. In this case we can safely set $V(x)=0$, and we obtain Landau levels - corresponding to the cyclotron orbits in the classical sketch drawn above.
#
# The energies of the Landau levels can in fact be obtained with a classic back-of-the-envelope calculation. An electron performing a cyclotron orbit at velocity $v$ has angular momentum $L=mvr_c=eB r^2_c$. In quantum mechanics, however, only orbits with a quantized angular momentum $L=n\hbar$ will be allowed. From the equality $r^2_c = n\hbar/eB$ one obtains that only some discrete values are allowed for the radius, $r_n = \sqrt{n} l_B$, where $l_B = \sqrt{\hbar/eB}$ is called the **magnetic length**.
#
# All cyclotron orbits, independently of the radius, are performed at the same freqeuncy $\omega_c=eB/m$. The energy of the electron in this quantized orbit is equal to $L\omega_c = n\hbar\omega_c$. All the energy levels are shifted up with respect to the bottom of the potential by the zero-point motion of the harmonic oscillator, $\hbar\omega_c/2$.
#
# As you know already, the wave functions corresponding to these states are centered at positions $y_0 = \hbar c k/eB$, where $k$ is the momentum along $x$. Away from $y_0$, the wave function decays very rapidly. The energy is independent of $y_0$, so we can draw the following sketch of the energy as a function of $y_0$:

# %% [markdown]
# ![](figures/landau_levels.png)

# %% [markdown]
# This picture, however, breaks down when $y_0$ is close to the edges. By “close” here we mean a few magnetic lengths. These states start to be very sensitive to the confining potential, and their energies will be affected. The precise form of the spectrum is non universal and depends on the particular shape $V(y)$. In general, however, we should expect the energy $E(y_0)$ to be increased by an amount proprtional to $V(y_0)$ with respect to the original Landau level.

# %% [markdown]
# ![](figures/landau_levels_bending.png)

# %% [markdown]
# You see that, as a result of the bending of the Landau levels towards the edges of the sample, there are states at the Fermi level if this is placed in the middle of the bulk gap! They are marked by the red dots in the figure, and are localized within a few magnetic lengths from the edges.
#
# We can take a “picture” of the edge states by plotting the local density of states at an energy $E_F$ in our ribbon:

# %%
# Plot of LDOS of a Hall ribbon, showing edge states.

# %% [markdown]
# What is the energy dispersion of the edge states? First of all, $y_0 = \hbar c k/eB$ is linearly related to the momentum. Close to the Fermi level we can always approximate the dispersion $E(y_0)$ of the edge states as a straight line. We then obtain, for each edge, a linear relation between energy and momentum,
#
# $$E = \hbar v (k-k_F)$$
#
# Here, $k_F$ is the Fermi momentum which in the case of our ribbon is equal to $k_F = 2\pi N / L$, with $N$ the number of electrons in the system.
#
# Because the slope of the potential is just the local electric field $\mathcal{E}_y=-\partial_y V(y)$ perpendicular to the edge of the sample, the velocity $v$ of the edge states can be simply interpreted as the [drift velocity](http://en.wikipedia.org/wiki/Guiding_center) of a skipping state,
#
# $$v = c\mathcal{E}_y/B\,.$$
#
# The velocity is opposite at the two edges because the local electric field $\mathcal{E}$ created by the confining potential always points towards the interior of the sample.

# %%
# Plot of energy dispersion E(k) of a quantum Hall ribbon.
W = 20
par = SimpleNamespace(t=1, mu = 0.5, B=0.15)
sys = qhe_ribbon(W)

kwant.plotter.bands(sys, args=[par], show=False)
plt.plot([-4, 4], [0, 0], 'k--')
plt.ylim([-0.5, 0.5])
plt.xlim([-np.pi, np.pi])
plt.xlabel('$k$')
plt.ylabel('$E$')
plt.show()

# %% [markdown]
# # The innocent anomaly of the chiral edges

# %% [markdown]
# The chiral edge states can be described in such simple terms, that you might doubt the fact that they cannot exist without a bulk. After all, couldn't we just build a theory of a single chiral edge states, neglecting the the bulk of the quantum Hall system and the existence of the other edge? Can't a truly one-dimensional system just show the same behavior of the chiral edge states of the quantum Hall effect?
#
# Let's consider the equation $E=\hbar v (k-k_F)$ which describes these chiral states. We can imagine that a constant electric field $\mathcal{E}$ can be applied along the edge, parallel to the momentum $k$. (In our hall cylinder, this can be done by threading a time-dependent flux through the cylinder, as you have seen in the previou spart of the lecture).
#
# The momentum $k$ changes acoording to the equation $\hbar \dot{k} = -e\mathcal{E}$. After a time $t$, the energy of a state with momentum $k$ has changed to $\hbar v (k - k_F - eEt/\hbar)$. This increase corresponds to a time-dependent shift of the Fermi momentum, $k_F\,\to\,k_F + e\mathcal{E}t/\hbar$. But this means that
#
# $$\dot{N} = \mathcal{E}L/\Phi_0$$
#
# with $\Phi_0=hc/e$ a flux quantum! The number of electrons is changing! In other words, **charge is not conserved** in a theory which only considers a chiral edge state. In particular, after a time such that $\mathcal{E}L t = \Phi_0$, exactly one electron seemed to have popped out of nowhere at the edge.

# %% [markdown]
# At this point we might be worried. Electrons come out of thin air in our theory! We must have made a mistake.
#
# What did we do wrong? Nothing. This is just how the Laughlin pump manifests itself if you only look at one edge. The number of electrons at one edge can increase, because it is being depleted from the other edge, which is not included in the theory, and pumped through the bulk until it appears.
#
# > This property of the edge is referred to as the **chiral anomaly**. The chiral anomaly tells us that we cannot have a consistent theory for chiral edge states, which at the same time conserves electric charge. This can happen in the quantum Hall system because the charge appearing at one edge is depleted from the other edge. Thus, chiral edge states or anything else that exhibits a chiral anomaly are an example of the bulk edge correspondence, since they can only appear at the edge of a two dimensional system and never in isolation.

# %%
W = 20
par = SimpleNamespace(t=1, mu = 0.3, mu_lead=0.3, B=0.15, phi=0.0)
sys = qhe_corbino(2*W, W)

fig = plt.figure(figsize=[9, 3.5])

ax0 = fig.add_subplot(1,2,1)
ldos = kwant.ldos(sys, energy=0.0, args=[par])
kwant.plotter.map(sys, ldos, num_lead_cells=20, colorbar=False, ax=ax0);

ax1 = fig.add_subplot(1,2,2)
ldos = kwant.ldos(sys, energy=0.14, args=[par])
kwant.plotter.map(sys, ldos, num_lead_cells=20, colorbar=False, ax=ax1);

# %% [markdown]
# # Quantization of Hall Conductance from edge states

# %% [markdown]
# To conclude our case about chiral edge states, we will now show that both signatures of the quantum Hall effect can be explained solely in terms of the edge states. In principle, this exercise can be done in any of the sample geometries that you have seen so far: the 6-terminal Hall bar, the Hall cylinder, and the Corbino geometry. We will choose the latter for the sake of convenience.
#
# So let's take again our Corbino disk immersed in an external magnetic field. With respect to last time, we now apply a small voltage difference $V$ between the edges, and there is no flux flowing in the middle of the Corbino.

# %% [markdown]
# ![](figures/corbino_voltage.png)

# %% [markdown]
# In this new drawing, we have also added arrows to indicate that we now know that each edge of the Corbino supports one chiral  state. For instance we can imagine that the Fermi level $E_F$ is in the bulk gap between the first and the second Landau level. We consider the case that the system is in equilibrium, and we ask: what is the equilibrium current flowing *around* the ring? What is the total current flowing *between the edges*?
#
# Let's first consider the case $V=0$. Clearly, the Fermi level is then the same at both edges. There are as many electrons going around the ring clockwise on the outer edge, as there are going around counterclockwise on the inner edge. In this case there is no net current flowing around the ring.
#
# A small voltage difference $V$ will create a small imbalance in the electron population between the edges. At equilibrium we can speak of a difference between the Fermi levels (or the chemical potential difference) between the two edges. The chemical potential difference is equal to $eV$.

# %% [markdown]
# * The conductance behaviour that we derived from the pumping picture for quantum hall can also be derived just by studying the edge states. To do this we consider the Hall bar in an annulus or "Corbino geometry" and apply a voltage difference between the two edges.
# Because of the voltage difference, the electrons at the two edges are at different chemical potentials $\mu_L$ and $\mu_R=\mu_L+e V$. [Note: we will ignore Coulomb interactions for this discussion, which complicate the discussion slightly by requiring us to think about an electrochemical potential]
# * TO DO: Draw a corbino - geometry with a voltage difference between the two edges.
#
# * The situation of the different chemical potentials $\mu_L\neq \mu_R$ is stable i.e. does not change in time by itself, which implies that the densities at each edge respectively $n_L$ and $n_R$ are constate. Thus, the longitudinal current which transfers charge between the edges must vanish.
#
# * The electrons at the two edges have opposite velocities $v$ and $-v$ and thus they carry current in opposite directions. Using Landauers formula, the currents carried by each edge should be $I_L=\frac{e^2}{h}(\mu_L-\mu)$ and $I_R=\frac{e^2}{h}(\mu_R-\mu)$. Since the edges both contribute to the Hall current in the perpendicular direction, the Hall current is written as $$I_H=\sum_{p=1}^n I_{L,p}-I_{R,p}=\sum_{p=1}^n\frac{e^2}{h}V=\frac{n e^2}{h}V.$$
#
# > Thus, the relevant electromagnetic response i.e. the longitudinal conductivity $\sigma_{xx}=0$ and $\sigma_{xy}=ne^2/h$ can both be derived directly from considering the chiral edge states alone.

# %% [markdown]
# # Topological quantum phase transitions and robustness to disorder

# %% [markdown]
# * The integer quantum hall effect is characterized by a quantized Hall conductance $\sigma_{xy}=n e^2/h$ where the integer $n$ is the topological index characterizing this phase. The bulk edge correspondence is realized by there being $n$ chiral edge modes corresponding to this state.
#
# * As expected for topological phases, changing the integer $n$ that characterizes the phase requires a closing of a gap at the fermi level. This can be accomplished by tuning the chemical potential $\mu$ from $$\mu>  n\omega_c \rightarrow \mu < n\omega_c.$$ At the transition point at $\mu\sim n\omega_c$, all the bulk Landau level states are at the chemical potential $\mu$. This is the bulk gap closure that one expects at the phase transition, since there are gapless excitations in the bulk relative to the chemical potential. This is a model of a quantum hall phase transition.
#
# * An important question that our discussion so far has left unanswered is whether this physics is robust to arbitrary perturbations such as disorder. This question is somewhat complicated and will have to wait till 9.1 to answer completely, though we will be able to understand periodic perturbations next week. However, it should be clear that the strictly topological features such as the bulk edge correspondence arising from the chiral edge states will survive disorder. On the other hand features such as all the bulk Landau levels being at exactly the same energy, are in some sense artifacts of the specific Hamiltonian we constructed and are destroyed, so that one obtains bulk Landau levels at a range of energies. This would suggest that there are ranges of chemical potential $\mu$ in the bulk Landau levels where the system is gapless and therefore does not have a well-defined quantum number. This turns out to be false in a subtle way that requires a careful analysis of disorder that must be left for later.

# %% [markdown]
# # Summary

# %% [markdown]
# Bert Halperin from Harvard University will summarize the lecture.

# %%
MoocVideo("o64UzQ3wYaU")
# Out:
# MoocVideo(**{'download_video': 'true', 'display_name': '', 'sub': 'o64UzQ3wYaU', 'youtube': '1.00:o64UzQ3wYaU', 'show_captions': 'true', 'youtube_id_1_0': 'o64UzQ3wYaU', 'download_track': 'true'})

# %%
MoocDiscussion("Questions", "Chiral edge states")
# Out:
# MoocDiscussion(**{'discussion_category': 'Questions', 'discussion_target': 'Chiral edge states', 'display_name': 'Chiral edge states', 'discussion_id': '2183a03779e43a20f9a63b44c3ea24e7'})
